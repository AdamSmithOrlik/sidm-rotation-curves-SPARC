# %%
import numpy as np 
import pandas as pd
import os
from readData import *
from baryonFit import HernquistFit, DehnenFit

import matplotlib.pyplot as plt

# %% [markdown]
# # Get all galaxy ids

# %%
galaxy_ids = get_galaxy_ids()

# %% [markdown]
# # Generate all lmfit fits assuming gamma = 0.5

# %%
plot_path = os.getcwd() + "/plots/fits/"
data_path = os.getcwd() + "/data/fit_data/"

results = []
failed = []

for galaxy_id in galaxy_ids:
    try:
        fitter = HernquistFit(galaxy_id, gamma_star=0.5, method="lmfit")
        M_b_fit, a_fit = fitter.M_b_fit, fitter.a_fit
        chisqr = fitter.result.chisqr
        redchisqr = fitter.result.redchi
    except Exception as e:
        failed.append(galaxy_id)
        print(f"Error fitting galaxy {galaxy_id}. Skipping...")
        continue
    
    results.append([galaxy_id, M_b_fit, a_fit, chisqr, redchisqr])
    
    rmax = fitter.r_vals.max() * 2 # kpc
    r_vals = np.geomspace(0.1, rmax, 100)
    vc_fit = fitter.vc(r_vals)
    
    plt.figure(figsize=(6,4))
    plt.plot(r_vals, vc_fit, label='Hernquist Fit', color='C0', alpha=0.7, zorder=0)
    plt.errorbar(fitter.r_vals, fitter.vc_baryons, yerr=fitter.data["errV"], fmt='o', label='Data', color='k', zorder=1, markersize=4, alpha=0.5)
    plt.xlabel('Radius [kpc]')
    plt.ylabel('Circular Velocity [km/s]')
    plt.title(f'Galaxy {galaxy_id} Hernquist Fit')
    plt.legend()
    plt.savefig(os.path.join(plot_path, f"{galaxy_id}_hernquist_fit.png"))
    plt.close()
    
    
results_df = pd.DataFrame(results, columns=["GalaxyID", "M_b_fit", "a_fit", "ChiSq", "RedChiSq"])
results_df.to_csv(os.path.join(data_path, "hernquist_fit_results.csv"), index=False)
print("Fitting complete. Results saved.")
np.savetxt(os.path.join(data_path, "failed_fits.txt"), failed, fmt="%s")
# Out:
# Fitting with lmfit took 0.0110 seconds
# Fitted parameters for galaxy NGC5371 using lmfit:
#   M_b = 3.93e+11 solar masses
#   a   = 10.53 kpc
#   chi-squared = 6127.4849
# Fitting with lmfit took 0.3429 seconds
# Fitted parameters for galaxy UGC05829 using lmfit:
#   M_b = 1.13e+21 solar masses
#   a   = 5497424.38 kpc
#   chi-squared = 185.9626
# Fitting with lmfit took 0.0151 seconds
# Fitted parameters for galaxy NGC5005 using lmfit:
#   M_b = 1.48e+11 solar masses
#   a   = 2.37 kpc
#   chi-squared = 2086.7819
# Error fitting galaxy UGCA444 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0034 seconds
# Error fitting galaxy UGCA444. Skipping...
# Fitting with lmfit took 0.0068 seconds
# Fitted parameters for galaxy NGC1003 using lmfit:
#   M_b = 1.22e+10 solar masses
#   a   = 4.40 kpc
#   chi-squared = 264.3338
# Error fitting galaxy UGC07559 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0090 seconds
# Error fitting galaxy UGC07559. Skipping...
# Fitting with lmfit took 0.0145 seconds
# Fitted parameters for galaxy NGC0100 using lmfit:
#   M_b = 8.77e+09 solar masses
#   a   = 6.44 kpc
#   chi-squared = 175.7649
# Fitting with lmfit took 0.0136 seconds
# Fitted parameters for galaxy UGC07261 using lmfit:
#   M_b = 9.08e+09 solar masses
#   a   = 6.71 kpc
#   chi-squared = 56.9246
# Fitting with lmfit took 0.0158 seconds
# Fitted parameters for galaxy NGC6195 using lmfit:
#   M_b = 3.62e+11 solar masses
#   a   = 6.59 kpc
#   chi-squared = 1696.3066
# Error fitting galaxy UGC01281 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0035 seconds
# Error fitting galaxy UGC01281. Skipping...
# Fitting with lmfit took 0.0071 seconds
# Fitted parameters for galaxy UGC05414 using lmfit:
#   M_b = 4.03e+10 solar masses
#   a   = 20.19 kpc
#   chi-squared = 13.6038
# Error fitting galaxy UGC08837 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0051 seconds
# Error fitting galaxy UGC08837. Skipping...
# Fitting with lmfit took 0.0163 seconds
# Fitted parameters for galaxy UGC11820 using lmfit:
#   M_b = 3.62e+10 solar masses
#   a   = 25.10 kpc
#   chi-squared = 41.8301
# Error fitting galaxy UGC06667 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0070 seconds
# Error fitting galaxy UGC06667. Skipping...
# Fitting with lmfit took 0.0157 seconds
# Fitted parameters for galaxy NGC4183 using lmfit:
#   M_b = 3.62e+10 solar masses
#   a   = 11.25 kpc
#   chi-squared = 486.0619
# Fitting with lmfit took 0.0131 seconds
# Fitted parameters for galaxy UGC08699 using lmfit:
#   M_b = 3.44e+10 solar masses
#   a   = 0.95 kpc
#   chi-squared = 3646.6844
# Error fitting galaxy F583-4 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0083 seconds
# Error fitting galaxy F583-4. Skipping...
# Error fitting galaxy UGC07399 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0083 seconds
# Error fitting galaxy UGC07399. Skipping...
# Fitting with lmfit took 0.0093 seconds
# Fitted parameters for galaxy NGC2841 using lmfit:
#   M_b = 1.88e+11 solar masses
#   a   = 3.93 kpc
#   chi-squared = 1549.8922
# Fitting with lmfit took 0.0163 seconds
# Fitted parameters for galaxy F567-2 using lmfit:
#   M_b = 2.99e+10 solar masses
#   a   = 25.63 kpc
#   chi-squared = 27.0324
# Fitting with lmfit took 0.0056 seconds
# Fitted parameters for galaxy NGC2403 using lmfit:
#   M_b = 2.02e+10 solar masses
#   a   = 4.09 kpc
#   chi-squared = 724.1293
# Fitting with lmfit took 0.0152 seconds
# Fitted parameters for galaxy NGC4010 using lmfit:
#   M_b = 8.43e+10 solar masses
#   a   = 14.37 kpc
#   chi-squared = 317.2203
# Fitting with lmfit took 0.0066 seconds
# Fitted parameters for galaxy F574-1 using lmfit:
#   M_b = 6.06e+10 solar masses
#   a   = 28.07 kpc
#   chi-squared = 42.8113
# Fitting with lmfit took 0.0143 seconds
# Fitted parameters for galaxy NGC0300 using lmfit:
#   M_b = 9.57e+09 solar masses
#   a   = 7.02 kpc
#   chi-squared = 93.2350
# Error fitting galaxy NGC3741 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0034 seconds
# Error fitting galaxy NGC3741. Skipping...
# Error fitting galaxy NGC4214 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0075 seconds
# Error fitting galaxy NGC4214. Skipping...
# Error fitting galaxy PGC51017 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0031 seconds
# Error fitting galaxy PGC51017. Skipping...
# Error fitting galaxy CamB with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0054 seconds
# Error fitting galaxy CamB. Skipping...
# Error fitting galaxy UGC07866 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0043 seconds
# Error fitting galaxy UGC07866. Skipping...
# Fitting with lmfit took 0.7084 seconds
# Fitted parameters for galaxy F574-2 using lmfit:
#   M_b = 2.00e+21 solar masses
#   a   = 8205622.82 kpc
#   chi-squared = 9.6531
# Error fitting galaxy NGC2915 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0034 seconds
# Error fitting galaxy NGC2915. Skipping...
# Error fitting galaxy UGC08490 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0031 seconds
# Error fitting galaxy UGC08490. Skipping...
# Fitting with lmfit took 0.6136 seconds
# Fitted parameters for galaxy UGC07524 using lmfit:
#   M_b = 4.79e+20 solar masses
#   a   = 3388066.94 kpc
#   chi-squared = 37.1897
# Error fitting galaxy UGC05721 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0084 seconds
# Error fitting galaxy UGC05721. Skipping...
# Fitting with lmfit took 0.0154 seconds
# Fitted parameters for galaxy ESO563-G021 using lmfit:
#   M_b = 5.98e+11 solar masses
#   a   = 19.72 kpc
#   chi-squared = 6465.8269
# Fitting with lmfit took 0.0113 seconds
# Fitted parameters for galaxy UGC00191 using lmfit:
#   M_b = 2.30e+10 solar masses
#   a   = 13.69 kpc
#   chi-squared = 8.1229
# Fitting with lmfit took 0.0060 seconds
# Fitted parameters for galaxy ESO116-G012 using lmfit:
#   M_b = 1.73e+10 solar masses
#   a   = 7.32 kpc
#   chi-squared = 120.8667
# Fitting with lmfit took 0.0142 seconds
# Fitted parameters for galaxy NGC3521 using lmfit:
#   M_b = 9.24e+10 solar masses
#   a   = 2.66 kpc
#   chi-squared = 2255.8545
# Fitting with lmfit took 0.0057 seconds
# Fitted parameters for galaxy NGC5985 using lmfit:
#   M_b = 4.12e+11 solar masses
#   a   = 17.92 kpc
#   chi-squared = 1275.5836
# Error fitting galaxy UGC05918 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0063 seconds
# Error fitting galaxy UGC05918. Skipping...
# Fitting with lmfit took 0.0059 seconds
# Fitted parameters for galaxy UGC06930 using lmfit:
#   M_b = 4.75e+10 solar masses
#   a   = 15.37 kpc
#   chi-squared = 52.0509
# Fitting with lmfit took 0.0142 seconds
# Fitted parameters for galaxy NGC1090 using lmfit:
#   M_b = 1.06e+11 solar masses
#   a   = 8.57 kpc
#   chi-squared = 581.2130
# Fitting with lmfit took 0.0386 seconds
# Fitted parameters for galaxy UGC07323 using lmfit:
#   M_b = 3.32e+12 solar masses
#   a   = 164.63 kpc
#   chi-squared = 9.7867
# Fitting with lmfit took 0.0165 seconds
# Fitted parameters for galaxy UGC07125 using lmfit:
#   M_b = 3.74e+10 solar masses
#   a   = 22.58 kpc
#   chi-squared = 97.5632
# Fitting with lmfit took 0.0057 seconds
# Fitted parameters for galaxy UGC02259 using lmfit:
#   M_b = 1.52e+10 solar masses
#   a   = 11.45 kpc
#   chi-squared = 20.0597
# Fitting with lmfit took 0.0139 seconds
# Fitted parameters for galaxy NGC3893 using lmfit:
#   M_b = 5.76e+10 solar masses
#   a   = 2.68 kpc
#   chi-squared = 161.9304
# Fitting with lmfit took 0.0060 seconds
# Fitted parameters for galaxy NGC3726 using lmfit:
#   M_b = 9.34e+10 solar masses
#   a   = 6.86 kpc
#   chi-squared = 985.7623
# Error fitting galaxy NGC2366 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0082 seconds
# Error fitting galaxy NGC2366. Skipping...
# Fitting with lmfit took 0.0186 seconds
# Fitted parameters for galaxy UGC04325 using lmfit:
#   M_b = 1.20e+11 solar masses
#   a   = 30.75 kpc
#   chi-squared = 59.9442
# Fitting with lmfit took 0.0060 seconds
# Fitted parameters for galaxy UGC12506 using lmfit:
#   M_b = 3.21e+11 solar masses
#   a   = 22.51 kpc
#   chi-squared = 1558.4982
# Fitting with lmfit took 0.0062 seconds
# Fitted parameters for galaxy UGC11455 using lmfit:
#   M_b = 7.05e+11 solar masses
#   a   = 18.13 kpc
#   chi-squared = 15684.1633
# Error fitting galaxy NGC1705 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0033 seconds
# Error fitting galaxy NGC1705. Skipping...
# Error fitting galaxy F563-V1 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0035 seconds
# Error fitting galaxy F563-V1. Skipping...
# Fitting with lmfit took 0.0118 seconds
# Fitted parameters for galaxy F561-1 using lmfit:
#   M_b = 7.09e+11 solar masses
#   a   = 109.70 kpc
#   chi-squared = 5.9847
# Fitting with lmfit took 0.0141 seconds
# Fitted parameters for galaxy UGC06818 using lmfit:
#   M_b = 6.51e+09 solar masses
#   a   = 6.58 kpc
#   chi-squared = 3.6104
# Fitting with lmfit took 0.0163 seconds
# Fitted parameters for galaxy UGC07089 using lmfit:
#   M_b = 3.47e+10 solar masses
#   a   = 17.65 kpc
#   chi-squared = 46.1198
# Fitting with lmfit took 0.0149 seconds
# Fitted parameters for galaxy UGC05253 using lmfit:
#   M_b = 1.16e+11 solar masses
#   a   = 2.01 kpc
#   chi-squared = 6576.6666
# Error fitting galaxy UGC04305 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0034 seconds
# Error fitting galaxy UGC04305. Skipping...
# Fitting with lmfit took 0.0081 seconds
# Fitted parameters for galaxy UGC06446 using lmfit:
#   M_b = 2.68e+10 solar masses
#   a   = 18.70 kpc
#   chi-squared = 44.2811
# Fitting with lmfit took 0.0137 seconds
# Fitted parameters for galaxy NGC3953 using lmfit:
#   M_b = 3.03e+11 solar masses
#   a   = 11.26 kpc
#   chi-squared = 170.1938
# Error fitting galaxy NGC6789 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0039 seconds
# Error fitting galaxy NGC6789. Skipping...
# Error fitting galaxy UGC07232 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0031 seconds
# Error fitting galaxy UGC07232. Skipping...
# Fitting with lmfit took 0.0078 seconds
# Fitted parameters for galaxy UGC03546 using lmfit:
#   M_b = 5.67e+10 solar masses
#   a   = 0.70 kpc
#   chi-squared = 5696.1377
# Fitting with lmfit took 0.0055 seconds
# Fitted parameters for galaxy NGC6503 using lmfit:
#   M_b = 1.27e+10 solar masses
#   a   = 1.94 kpc
#   chi-squared = 1310.8694
# Fitting with lmfit took 0.0060 seconds
# Fitted parameters for galaxy UGC05005 using lmfit:
#   M_b = 4.44e+10 solar masses
#   a   = 25.69 kpc
#   chi-squared = 17.2500
# Error fitting galaxy UGC07690 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0034 seconds
# Error fitting galaxy UGC07690. Skipping...
# Fitting with lmfit took 0.0140 seconds
# Fitted parameters for galaxy UGC00634 using lmfit:
#   M_b = 2.50e+10 solar masses
#   a   = 13.99 kpc
#   chi-squared = 11.3575
# Error fitting galaxy DDO154 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0080 seconds
# Error fitting galaxy DDO154. Skipping...
# Error fitting galaxy UGC07603 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0055 seconds
# Error fitting galaxy UGC07603. Skipping...
# Fitting with lmfit took 0.0157 seconds
# Fitted parameters for galaxy NGC3992 using lmfit:
#   M_b = 2.53e+11 solar masses
#   a   = 9.34 kpc
#   chi-squared = 1065.4669
# Fitting with lmfit took 0.0060 seconds
# Fitted parameters for galaxy NGC4088 using lmfit:
#   M_b = 1.77e+11 solar masses
#   a   = 7.57 kpc
#   chi-squared = 3826.5938
# Fitting with lmfit took 0.0066 seconds
# Fitted parameters for galaxy F579-V1 using lmfit:
#   M_b = 7.51e+10 solar masses
#   a   = 22.07 kpc
#   chi-squared = 61.9849
# Error fitting galaxy ESO444-G084 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0033 seconds
# Error fitting galaxy ESO444-G084. Skipping...
# Error fitting galaxy F565-V2 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0035 seconds
# Error fitting galaxy F565-V2. Skipping...
# Fitting with lmfit took 0.0071 seconds
# Fitted parameters for galaxy UGC10310 using lmfit:
#   M_b = 1.45e+11 solar masses
#   a   = 44.83 kpc
#   chi-squared = 16.7061
# Fitting with lmfit took 0.0143 seconds
# Fitted parameters for galaxy NGC5055 using lmfit:
#   M_b = 1.27e+11 solar masses
#   a   = 3.52 kpc
#   chi-squared = 1411.1978
# Fitting with lmfit took 0.0137 seconds
# Fitted parameters for galaxy NGC0801 using lmfit:
#   M_b = 2.88e+11 solar masses
#   a   = 7.54 kpc
#   chi-squared = 518.6948
# Fitting with lmfit took 0.0156 seconds
# Fitted parameters for galaxy F563-1 using lmfit:
#   M_b = 5.13e+10 solar masses
#   a   = 35.03 kpc
#   chi-squared = 13.7231
# Fitting with lmfit took 0.0091 seconds
# Fitted parameters for galaxy NGC6946 using lmfit:
#   M_b = 6.01e+10 solar masses
#   a   = 2.62 kpc
#   chi-squared = 20203.6394
# Fitting with lmfit took 0.0149 seconds
# Fitted parameters for galaxy UGC06614 using lmfit:
#   M_b = 1.02e+11 solar masses
#   a   = 2.69 kpc
#   chi-squared = 670.5675
# Fitting with lmfit took 0.0133 seconds
# Fitted parameters for galaxy NGC3769 using lmfit:
#   M_b = 2.03e+10 solar masses
#   a   = 2.39 kpc
#   chi-squared = 77.9712
# Fitting with lmfit took 0.0093 seconds
# Fitted parameters for galaxy NGC3917 using lmfit:
#   M_b = 1.32e+11 solar masses
#   a   = 21.25 kpc
#   chi-squared = 651.2756
# Fitting with lmfit took 0.0163 seconds
# Fitted parameters for galaxy UGC05999 using lmfit:
#   M_b = 1.46e+11 solar masses
#   a   = 48.78 kpc
#   chi-squared = 31.2061
# Fitting with lmfit took 0.0057 seconds
# Fitted parameters for galaxy NGC4085 using lmfit:
#   M_b = 6.51e+10 solar masses
#   a   = 5.97 kpc
#   chi-squared = 106.4660
# Fitting with lmfit took 0.0134 seconds
# Fitted parameters for galaxy NGC3198 using lmfit:
#   M_b = 6.39e+10 solar masses
#   a   = 8.60 kpc
#   chi-squared = 2195.8132
# Fitting with lmfit took 0.0161 seconds
# Fitted parameters for galaxy F568-3 using lmfit:
#   M_b = 2.76e+11 solar masses
#   a   = 66.53 kpc
#   chi-squared = 41.5299
# Fitting with lmfit took 0.0142 seconds
# Fitted parameters for galaxy NGC5033 using lmfit:
#   M_b = 8.21e+10 solar masses
#   a   = 1.45 kpc
#   chi-squared = 642.1289
# Fitting with lmfit took 0.0157 seconds
# Fitted parameters for galaxy UGC11557 using lmfit:
#   M_b = 7.00e+10 solar masses
#   a   = 14.39 kpc
#   chi-squared = 108.0097
# Fitting with lmfit took 0.0157 seconds
# Fitted parameters for galaxy UGC02885 using lmfit:
#   M_b = 3.49e+11 solar masses
#   a   = 6.49 kpc
#   chi-squared = 4042.8834
# Error fitting galaxy KK98-251 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0034 seconds
# Error fitting galaxy KK98-251. Skipping...
# Fitting with lmfit took 0.0061 seconds
# Fitted parameters for galaxy NGC5907 using lmfit:
#   M_b = 2.26e+11 solar masses
#   a   = 10.22 kpc
#   chi-squared = 1063.7738
# Fitting with lmfit took 0.0060 seconds
# Fitted parameters for galaxy UGC06917 using lmfit:
#   M_b = 3.08e+10 solar masses
#   a   = 11.47 kpc
#   chi-squared = 24.0821
# Error fitting galaxy UGC09992 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0034 seconds
# Error fitting galaxy UGC09992. Skipping...
# Fitting with lmfit took 0.0062 seconds
# Fitted parameters for galaxy UGC04499 using lmfit:
#   M_b = 1.93e+10 solar masses
#   a   = 12.54 kpc
#   chi-squared = 6.8385
# Fitting with lmfit took 0.0131 seconds
# Fitted parameters for galaxy NGC0289 using lmfit:
#   M_b = 8.42e+10 solar masses
#   a   = 3.96 kpc
#   chi-squared = 1823.2676
# Fitting with lmfit took 0.0060 seconds
# Fitted parameters for galaxy UGC06983 using lmfit:
#   M_b = 2.45e+10 solar masses
#   a   = 10.45 kpc
#   chi-squared = 116.3834
# Fitting with lmfit took 0.0058 seconds
# Fitted parameters for galaxy UGC06973 using lmfit:
#   M_b = 3.39e+10 solar masses
#   a   = 0.19 kpc
#   chi-squared = 10.8465
# Fitting with lmfit took 0.0171 seconds
# Fitted parameters for galaxy UGC02487 using lmfit:
#   M_b = 4.05e+11 solar masses
#   a   = 6.34 kpc
#   chi-squared = 481.5514
# Fitting with lmfit took 0.0141 seconds
# Fitted parameters for galaxy UGC09037 using lmfit:
#   M_b = 1.09e+11 solar masses
#   a   = 8.74 kpc
#   chi-squared = 103.9996
# Fitting with lmfit took 0.0054 seconds
# Fitted parameters for galaxy NGC4051 using lmfit:
#   M_b = 1.34e+11 solar masses
#   a   = 8.66 kpc
#   chi-squared = 1382.2970
# Fitting with lmfit took 0.0138 seconds
# Fitted parameters for galaxy F571-8 using lmfit:
#   M_b = 9.70e+09 solar masses
#   a   = 2.08 kpc
#   chi-squared = 541.0819
# Error fitting galaxy D564-8 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0034 seconds
# Error fitting galaxy D564-8. Skipping...
# Error fitting galaxy UGC00891 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0031 seconds
# Error fitting galaxy UGC00891. Skipping...
# Fitting with lmfit took 0.0062 seconds
# Fitted parameters for galaxy NGC2998 using lmfit:
#   M_b = 2.27e+11 solar masses
#   a   = 11.51 kpc
#   chi-squared = 1199.8944
# Fitting with lmfit took 0.0063 seconds
# Fitted parameters for galaxy NGC0055 using lmfit:
#   M_b = 3.23e+10 solar masses
#   a   = 14.10 kpc
#   chi-squared = 52.9700
# Fitting with lmfit took 0.0151 seconds
# Fitted parameters for galaxy NGC2683 using lmfit:
#   M_b = 6.10e+10 solar masses
#   a   = 2.10 kpc
#   chi-squared = 788.9936
# Fitting with lmfit took 0.0106 seconds
# Fitted parameters for galaxy UGC12632 using lmfit:
#   M_b = 9.07e+11 solar masses
#   a   = 163.40 kpc
#   chi-squared = 11.4319
# Fitting with lmfit took 0.0187 seconds
# Fitted parameters for galaxy F563-V2 using lmfit:
#   M_b = 4.24e+11 solar masses
#   a   = 77.74 kpc
#   chi-squared = 51.2977
# Fitting with lmfit took 0.0152 seconds
# Fitted parameters for galaxy NGC5585 using lmfit:
#   M_b = 9.11e+09 solar masses
#   a   = 5.08 kpc
#   chi-squared = 19.4845
# Fitting with lmfit took 0.6224 seconds
# Fitted parameters for galaxy NGC2976 using lmfit:
#   M_b = 7.47e+20 solar masses
#   a   = 1361350.73 kpc
#   chi-squared = 884.2672
# Fitting with lmfit took 0.0136 seconds
# Fitted parameters for galaxy NGC7814 using lmfit:
#   M_b = 5.54e+10 solar masses
#   a   = 0.72 kpc
#   chi-squared = 100.5925
# Fitting with lmfit took 0.0157 seconds
# Fitted parameters for galaxy UGC05716 using lmfit:
#   M_b = 1.62e+10 solar masses
#   a   = 17.52 kpc
#   chi-squared = 16.4336
# Fitting with lmfit took 0.0060 seconds
# Fitted parameters for galaxy F571-V1 using lmfit:
#   M_b = 2.65e+10 solar masses
#   a   = 20.07 kpc
#   chi-squared = 21.4782
# Error fitting galaxy F583-1 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0033 seconds
# Error fitting galaxy F583-1. Skipping...
# Fitting with lmfit took 0.0056 seconds
# Fitted parameters for galaxy UGC11914 using lmfit:
#   M_b = 1.33e+11 solar masses
#   a   = 2.33 kpc
#   chi-squared = 1690.2614
# Fitting with lmfit took 0.0150 seconds
# Fitted parameters for galaxy NGC0891 using lmfit:
#   M_b = 1.17e+11 solar masses
#   a   = 1.91 kpc
#   chi-squared = 677.7046
# Fitting with lmfit took 0.0120 seconds
# Fitted parameters for galaxy DDO170 using lmfit:
#   M_b = 1.69e+10 solar masses
#   a   = 19.35 kpc
#   chi-squared = 23.1520
# Fitting with lmfit took 0.0062 seconds
# Fitted parameters for galaxy F568-V1 using lmfit:
#   M_b = 4.54e+10 solar masses
#   a   = 24.63 kpc
#   chi-squared = 27.3446
# Fitting with lmfit took 0.0177 seconds
# Fitted parameters for galaxy ESO079-G014 using lmfit:
#   M_b = 7.34e+11 solar masses
#   a   = 53.91 kpc
#   chi-squared = 235.5677
# Fitting with lmfit took 0.0092 seconds
# Fitted parameters for galaxy UGC06787 using lmfit:
#   M_b = 6.53e+10 solar masses
#   a   = 0.95 kpc
#   chi-squared = 2512.6527
# Error fitting galaxy D631-7 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0033 seconds
# Error fitting galaxy D631-7. Skipping...
# Fitting with lmfit took 0.0053 seconds
# Fitted parameters for galaxy NGC2955 using lmfit:
#   M_b = 3.21e+11 solar masses
#   a   = 5.74 kpc
#   chi-squared = 798.0779
# Fitting with lmfit took 0.0128 seconds
# Fitted parameters for galaxy UGC03580 using lmfit:
#   M_b = 1.35e+10 solar masses
#   a   = 1.59 kpc
#   chi-squared = 632.5701
# Fitting with lmfit took 0.0135 seconds
# Fitted parameters for galaxy NGC4100 using lmfit:
#   M_b = 7.57e+10 solar masses
#   a   = 5.50 kpc
#   chi-squared = 4134.5373
# Fitting with lmfit took 0.0144 seconds
# Fitted parameters for galaxy UGC06786 using lmfit:
#   M_b = 5.30e+10 solar masses
#   a   = 1.70 kpc
#   chi-squared = 3344.8648
# Fitting with lmfit took 0.0062 seconds
# Fitted parameters for galaxy UGC00128 using lmfit:
#   M_b = 6.41e+10 solar masses
#   a   = 27.85 kpc
#   chi-squared = 245.7509
# Error fitting galaxy NGC4068 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0084 seconds
# Error fitting galaxy NGC4068. Skipping...
# Fitting with lmfit took 0.4775 seconds
# Fitted parameters for galaxy UGC00731 using lmfit:
#   M_b = 1.70e+21 solar masses
#   a   = 7987858.73 kpc
#   chi-squared = 179.6800
# Error fitting galaxy UGC07608 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0037 seconds
# Error fitting galaxy UGC07608. Skipping...
# Fitting with lmfit took 0.0177 seconds
# Fitted parameters for galaxy UGC05750 using lmfit:
#   M_b = 1.78e+11 solar masses
#   a   = 72.88 kpc
#   chi-squared = 58.2679
# Error fitting galaxy UGCA442 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0034 seconds
# Error fitting galaxy UGCA442. Skipping...
# Error fitting galaxy UGC04278 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0031 seconds
# Error fitting galaxy UGC04278. Skipping...
# Fitting with lmfit took 0.0073 seconds
# Fitted parameters for galaxy UGC07151 using lmfit:
#   M_b = 1.54e+10 solar masses
#   a   = 8.42 kpc
#   chi-squared = 15.7191
# Fitting with lmfit took 0.0059 seconds
# Fitted parameters for galaxy NGC3972 using lmfit:
#   M_b = 1.29e+11 solar masses
#   a   = 19.29 kpc
#   chi-squared = 129.8786
# Fitting with lmfit took 0.4793 seconds
# Fitted parameters for galaxy F568-1 using lmfit:
#   M_b = 2.43e+21 solar masses
#   a   = 6413099.68 kpc
#   chi-squared = 62.6505
# Fitting with lmfit took 0.0154 seconds
# Fitted parameters for galaxy NGC7793 using lmfit:
#   M_b = 2.15e+10 solar masses
#   a   = 4.94 kpc
#   chi-squared = 652.6764
# Fitting with lmfit took 0.0067 seconds
# Fitted parameters for galaxy NGC3877 using lmfit:
#   M_b = 5.76e+11 solar masses
#   a   = 24.81 kpc
#   chi-squared = 785.0039
# Fitting with lmfit took 0.0141 seconds
# Fitted parameters for galaxy NGC6674 using lmfit:
#   M_b = 1.92e+11 solar masses
#   a   = 6.09 kpc
#   chi-squared = 186.8443
# Fitting with lmfit took 0.0144 seconds
# Fitted parameters for galaxy NGC6015 using lmfit:
#   M_b = 5.07e+10 solar masses
#   a   = 6.12 kpc
#   chi-squared = 2425.9343
# Fitting with lmfit took 0.0135 seconds
# Fitted parameters for galaxy UGC12732 using lmfit:
#   M_b = 2.32e+11 solar masses
#   a   = 76.28 kpc
#   chi-squared = 97.0299
# Error fitting galaxy DDO168 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0090 seconds
# Error fitting galaxy DDO168. Skipping...
# Fitting with lmfit took 0.0141 seconds
# Fitted parameters for galaxy NGC2903 using lmfit:
#   M_b = 7.01e+10 solar masses
#   a   = 2.19 kpc
#   chi-squared = 8063.7771
# Fitting with lmfit took 0.0135 seconds
# Fitted parameters for galaxy UGC02455 using lmfit:
#   M_b = 1.28e+10 solar masses
#   a   = 4.15 kpc
#   chi-squared = 84.3475
# Fitting with lmfit took 0.0224 seconds
# Fitted parameters for galaxy UGC02023 using lmfit:
#   M_b = 2.30e+11 solar masses
#   a   = 54.22 kpc
#   chi-squared = 18.9969
# Error fitting galaxy DDO064 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0056 seconds
# Error fitting galaxy DDO064. Skipping...
# Fitting with lmfit took 0.0148 seconds
# Fitted parameters for galaxy UGC05986 using lmfit:
#   M_b = 1.44e+10 solar masses
#   a   = 6.20 kpc
#   chi-squared = 289.4022
# Error fitting galaxy UGCA281 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0081 seconds
# Error fitting galaxy UGCA281. Skipping...
# Fitting with lmfit took 0.0125 seconds
# Fitted parameters for galaxy UGC06399 using lmfit:
#   M_b = 4.48e+10 solar masses
#   a   = 22.50 kpc
#   chi-squared = 18.1256
# Fitting with lmfit took 0.0062 seconds
# Fitted parameters for galaxy UGC09133 using lmfit:
#   M_b = 2.07e+11 solar masses
#   a   = 2.76 kpc
#   chi-squared = 3525.2941
# Fitting with lmfit took 0.0145 seconds
# Fitted parameters for galaxy NGC0024 using lmfit:
#   M_b = 9.44e+09 solar masses
#   a   = 4.27 kpc
#   chi-squared = 734.0411
# Error fitting galaxy UGC08550 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0047 seconds
# Error fitting galaxy UGC08550. Skipping...
# Fitting with lmfit took 0.0068 seconds
# Fitted parameters for galaxy UGC02953 using lmfit:
#   M_b = 1.91e+11 solar masses
#   a   = 3.03 kpc
#   chi-squared = 14810.5847
# Fitting with lmfit took 0.0103 seconds
# Fitted parameters for galaxy NGC4138 using lmfit:
#   M_b = 3.11e+10 solar masses
#   a   = 0.79 kpc
#   chi-squared = 72.8820
# Fitting with lmfit took 0.0142 seconds
# Fitted parameters for galaxy NGC0247 using lmfit:
#   M_b = 1.63e+11 solar masses
#   a   = 44.66 kpc
#   chi-squared = 108.6064
# Fitting with lmfit took 0.0081 seconds
# Fitted parameters for galaxy IC4202 using lmfit:
#   M_b = 2.45e+11 solar masses
#   a   = 8.29 kpc
#   chi-squared = 1591.5552
# Fitting with lmfit took 0.0118 seconds
# Fitted parameters for galaxy UGC08286 using lmfit:
#   M_b = 9.60e+09 solar masses
#   a   = 8.93 kpc
#   chi-squared = 53.6338
# Error fitting galaxy IC2574 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0060 seconds
# Error fitting galaxy IC2574. Skipping...
# Fitting with lmfit took 0.0115 seconds
# Fitted parameters for galaxy NGC4559 using lmfit:
#   M_b = 3.99e+10 solar masses
#   a   = 6.69 kpc
#   chi-squared = 241.8984
# Fitting with lmfit took 0.0151 seconds
# Fitted parameters for galaxy UGC01230 using lmfit:
#   M_b = 5.47e+10 solar masses
#   a   = 23.09 kpc
#   chi-squared = 36.8171
# Error fitting galaxy UGC07577 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0034 seconds
# Error fitting galaxy UGC07577. Skipping...
# Fitting with lmfit took 0.0082 seconds
# Fitted parameters for galaxy UGC06628 using lmfit:
#   M_b = 1.69e+11 solar masses
#   a   = 45.22 kpc
#   chi-squared = 4.2573
# Fitting with lmfit took 0.0149 seconds
# Fitted parameters for galaxy NGC4013 using lmfit:
#   M_b = 5.56e+10 solar masses
#   a   = 0.83 kpc
#   chi-squared = 1519.6201
# Fitting with lmfit took 0.0123 seconds
# Fitted parameters for galaxy UGC03205 using lmfit:
#   M_b = 1.21e+11 solar masses
#   a   = 4.50 kpc
#   chi-squared = 3090.0147
# Fitting with lmfit took 0.0067 seconds
# Fitted parameters for galaxy NGC7331 using lmfit:
#   M_b = 1.98e+11 solar masses
#   a   = 2.79 kpc
#   chi-squared = 1533.2518
# Fitting with lmfit took 0.0134 seconds
# Fitted parameters for galaxy UGC02916 using lmfit:
#   M_b = 1.24e+11 solar masses
#   a   = 2.81 kpc
#   chi-squared = 5885.7809
# Fitting with lmfit took 0.0061 seconds
# Fitted parameters for galaxy UGC06923 using lmfit:
#   M_b = 9.20e+09 solar masses
#   a   = 4.44 kpc
#   chi-squared = 4.1797
# Error fitting galaxy UGC04483 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0034 seconds
# Error fitting galaxy UGC04483. Skipping...
# Fitting with lmfit took 0.0128 seconds
# Fitted parameters for galaxy NGC4217 using lmfit:
#   M_b = 1.04e+11 solar masses
#   a   = 2.75 kpc
#   chi-squared = 5711.9802
# Error fitting galaxy NGC3109 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0034 seconds
# Error fitting galaxy NGC3109. Skipping...
# Error fitting galaxy UGC05764 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0036 seconds
# Error fitting galaxy UGC05764. Skipping...
# Fitting with lmfit took 0.0053 seconds
# Fitted parameters for galaxy NGC3949 using lmfit:
#   M_b = 6.22e+10 solar masses
#   a   = 3.82 kpc
#   chi-squared = 302.3422
# Error fitting galaxy D512-2 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0084 seconds
# Error fitting galaxy D512-2. Skipping...
# Fitting with lmfit took 0.0059 seconds
# Fitted parameters for galaxy NGC4389 using lmfit:
#   M_b = 9.71e+10 solar masses
#   a   = 8.58 kpc
#   chi-squared = 71.7691
# Fitting with lmfit took 0.0062 seconds
# Fitted parameters for galaxy NGC4157 using lmfit:
#   M_b = 1.20e+11 solar masses
#   a   = 4.91 kpc
#   chi-squared = 3523.8003
# Fitting with lmfit took 0.0138 seconds
# Fitted parameters for galaxy DDO161 using lmfit:
#   M_b = 1.14e+10 solar masses
#   a   = 10.83 kpc
#   chi-squared = 115.1368
# Fitting complete. Results saved.

# %% [markdown]
# # Generate lmfit with Gamma Fits

# %%
plot_path = os.getcwd() + "/plots/fits/"
data_path = os.getcwd() + "/data/fit_data/"

gamma_data = pd.read_csv(data_path + "gamma_fits.csv")

results = []
failed = []

for galaxy_id in galaxy_ids:
    gamma_s, gamma_b = gamma_data[gamma_data["GalaxyID"] == galaxy_id][["Gamma_disk", "Gamma_bulge"]].values[0]
    try:
        # Set gamma_bulge = 0 
        fitter = HernquistFit(galaxy_id, gamma_star=gamma_s, gamma_bulge=0.0, method="lmfit")
        M_b_fit, a_fit = fitter.M_b_fit, fitter.a_fit
        chisqr = fitter.result.chisqr
        redchisqr = fitter.result.redchi
    except Exception as e:
        failed.append(galaxy_id)
        print(f"Error fitting galaxy {galaxy_id}. Skipping...")
        continue
    
    results.append([galaxy_id, M_b_fit, a_fit, chisqr, redchisqr])
    
    rmax = fitter.r_vals.max() * 2 # kpc
    r_vals = np.geomspace(0.1, rmax, 100)
    vc_fit = fitter.vc(r_vals)
    
    # plt.figure(figsize=(6,4))
    # plt.plot(r_vals, vc_fit, label='Hernquist Fit', color='C0', alpha=0.7, zorder=0)
    # plt.errorbar(fitter.r_vals, fitter.vc_baryons, yerr=fitter.data["errV"], fmt='o', label='Data', color='k', zorder=1, markersize=4, alpha=0.5)
    # plt.xlabel('Radius [kpc]')
    # plt.ylabel('Circular Velocity [km/s]')
    # plt.title(f'Galaxy {galaxy_id} Hernquist Fit')
    # plt.legend()
    # plt.savefig(os.path.join(plot_path, f"{galaxy_id}_hernquist_fit.png"))
    # plt.close()
    
    
results_df = pd.DataFrame(results, columns=["GalaxyID", "M_b_fit", "a_fit", "ChiSq", "RedChiSq"])
results_df.to_csv(os.path.join(data_path, "hernquist_fit_disk_gas.csv"), index=False)
print("Fitting complete. Results saved.")
np.savetxt(os.path.join(data_path, "failed_fits_gamma.txt"), failed, fmt="%s")
# Out:
# Fitting with lmfit took 0.0211 seconds
# Fitted parameters for galaxy NGC5371 using lmfit:
#   M_b = 3.38e+11 solar masses
#   a   = 10.72 kpc
#   chi-squared = 5220.8497
# Fitting with lmfit took 0.3205 seconds
# Fitted parameters for galaxy UGC05829 using lmfit:
#   M_b = 1.14e+21 solar masses
#   a   = 5515868.85 kpc
#   chi-squared = 182.8182
# Fitting with lmfit took 0.0137 seconds
# Fitted parameters for galaxy NGC5005 using lmfit:
#   M_b = 3.04e+11 solar masses
#   a   = 7.39 kpc
#   chi-squared = 1667.2293
# Error fitting galaxy UGCA444 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0086 seconds
# Fitted parameters for galaxy UGCA444 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGCA444. Skipping...
# Fitting with lmfit took 0.0056 seconds
# Fitted parameters for galaxy NGC1003 using lmfit:
#   M_b = 1.38e+10 solar masses
#   a   = 3.72 kpc
#   chi-squared = 364.9235
# Error fitting galaxy UGC07559 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0032 seconds
# Fitted parameters for galaxy UGC07559 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC07559. Skipping...
# Fitting with lmfit took 0.0061 seconds
# Fitted parameters for galaxy NGC0100 using lmfit:
#   M_b = 8.59e+09 solar masses
#   a   = 6.53 kpc
#   chi-squared = 165.7252
# Fitting with lmfit took 0.0063 seconds
# Fitted parameters for galaxy UGC07261 using lmfit:
#   M_b = 9.00e+09 solar masses
#   a   = 6.45 kpc
#   chi-squared = 61.3186
# Fitting with lmfit took 0.0066 seconds
# Fitted parameters for galaxy NGC6195 using lmfit:
#   M_b = 9.30e+11 solar masses
#   a   = 38.45 kpc
#   chi-squared = 4153.6219
# Error fitting galaxy UGC01281 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0031 seconds
# Fitted parameters for galaxy UGC01281 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC01281. Skipping...
# Fitting with lmfit took 0.0066 seconds
# Fitted parameters for galaxy UGC05414 using lmfit:
#   M_b = 4.06e+10 solar masses
#   a   = 20.31 kpc
#   chi-squared = 13.6017
# Error fitting galaxy UGC08837 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0032 seconds
# Fitted parameters for galaxy UGC08837 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC08837. Skipping...
# Fitting with lmfit took 0.0069 seconds
# Fitted parameters for galaxy UGC11820 using lmfit:
#   M_b = 1.95e+10 solar masses
#   a   = 14.00 kpc
#   chi-squared = 53.0099
# Error fitting galaxy UGC06667 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0031 seconds
# Fitted parameters for galaxy UGC06667 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC06667. Skipping...
# Fitting with lmfit took 0.0059 seconds
# Fitted parameters for galaxy NGC4183 using lmfit:
#   M_b = 3.72e+10 solar masses
#   a   = 10.80 kpc
#   chi-squared = 525.8543
# Fitting with lmfit took 0.0053 seconds
# Fitted parameters for galaxy UGC08699 using lmfit:
#   M_b = 7.17e+10 solar masses
#   a   = 5.62 kpc
#   chi-squared = 3302.3339
# Error fitting galaxy F583-4 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0056 seconds
# Fitted parameters for galaxy F583-4 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy F583-4. Skipping...
# Error fitting galaxy UGC07399 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0100 seconds
# Fitted parameters for galaxy UGC07399 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC07399. Skipping...
# Fitting with lmfit took 0.0158 seconds
# Fitted parameters for galaxy NGC2841 using lmfit:
#   M_b = 2.93e+11 solar masses
#   a   = 6.90 kpc
#   chi-squared = 18971.1585
# Fitting with lmfit took 0.0090 seconds
# Fitted parameters for galaxy F567-2 using lmfit:
#   M_b = 2.94e+10 solar masses
#   a   = 25.14 kpc
#   chi-squared = 26.7707
# Fitting with lmfit took 0.0108 seconds
# Fitted parameters for galaxy NGC2403 using lmfit:
#   M_b = 2.10e+10 solar masses
#   a   = 3.90 kpc
#   chi-squared = 900.7827
# Fitting with lmfit took 0.0091 seconds
# Fitted parameters for galaxy NGC4010 using lmfit:
#   M_b = 8.12e+10 solar masses
#   a   = 14.74 kpc
#   chi-squared = 289.2748
# Fitting with lmfit took 0.0089 seconds
# Fitted parameters for galaxy F574-1 using lmfit:
#   M_b = 6.11e+10 solar masses
#   a   = 28.32 kpc
#   chi-squared = 42.6380
# Fitting with lmfit took 0.0121 seconds
# Fitted parameters for galaxy NGC0300 using lmfit:
#   M_b = 9.62e+09 solar masses
#   a   = 6.84 kpc
#   chi-squared = 93.7773
# Error fitting galaxy NGC3741 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0081 seconds
# Fitted parameters for galaxy NGC3741 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy NGC3741. Skipping...
# Error fitting galaxy NGC4214 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0083 seconds
# Fitted parameters for galaxy NGC4214 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy NGC4214. Skipping...
# Error fitting galaxy PGC51017 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0035 seconds
# Fitted parameters for galaxy PGC51017 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy PGC51017. Skipping...
# Error fitting galaxy CamB with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0035 seconds
# Fitted parameters for galaxy CamB using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy CamB. Skipping...
# Error fitting galaxy UGC07866 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0035 seconds
# Fitted parameters for galaxy UGC07866 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC07866. Skipping...
# Fitting with lmfit took 0.6556 seconds
# Fitted parameters for galaxy F574-2 using lmfit:
#   M_b = 2.06e+21 solar masses
#   a   = 8346615.54 kpc
#   chi-squared = 9.8206
# Error fitting galaxy NGC2915 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0082 seconds
# Fitted parameters for galaxy NGC2915 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy NGC2915. Skipping...
# Fitting with lmfit took 0.0180 seconds
# Fitted parameters for galaxy UGC08490 using lmfit:
#   M_b = 2.75e+09 solar masses
#   a   = 1.93 kpc
#   chi-squared = 53.1502
# Fitting with lmfit took 0.9679 seconds
# Fitted parameters for galaxy UGC07524 using lmfit:
#   M_b = 7.92e+20 solar masses
#   a   = 4389783.52 kpc
#   chi-squared = 37.6527
# Error fitting galaxy UGC05721 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0082 seconds
# Fitted parameters for galaxy UGC05721 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC05721. Skipping...
# Fitting with lmfit took 0.0149 seconds
# Fitted parameters for galaxy ESO563-G021 using lmfit:
#   M_b = 3.60e+11 solar masses
#   a   = 22.13 kpc
#   chi-squared = 2394.8364
# Fitting with lmfit took 0.0145 seconds
# Fitted parameters for galaxy UGC00191 using lmfit:
#   M_b = 1.97e+10 solar masses
#   a   = 11.04 kpc
#   chi-squared = 9.3859
# Fitting with lmfit took 0.0162 seconds
# Fitted parameters for galaxy ESO116-G012 using lmfit:
#   M_b = 1.72e+10 solar masses
#   a   = 7.48 kpc
#   chi-squared = 114.2688
# Fitting with lmfit took 0.0134 seconds
# Fitted parameters for galaxy NGC3521 using lmfit:
#   M_b = 8.98e+10 solar masses
#   a   = 2.66 kpc
#   chi-squared = 2160.2044
# Fitting with lmfit took 0.0140 seconds
# Fitted parameters for galaxy NGC5985 using lmfit:
#   M_b = 4.17e+11 solar masses
#   a   = 29.83 kpc
#   chi-squared = 1647.8425
# Error fitting galaxy UGC05918 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0084 seconds
# Fitted parameters for galaxy UGC05918 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC05918. Skipping...
# Fitting with lmfit took 0.0145 seconds
# Fitted parameters for galaxy UGC06930 using lmfit:
#   M_b = 4.72e+10 solar masses
#   a   = 15.03 kpc
#   chi-squared = 52.7696
# Fitting with lmfit took 0.0063 seconds
# Fitted parameters for galaxy NGC1090 using lmfit:
#   M_b = 1.06e+11 solar masses
#   a   = 8.57 kpc
#   chi-squared = 576.6668
# Fitting with lmfit took 0.0153 seconds
# Fitted parameters for galaxy UGC07323 using lmfit:
#   M_b = 3.49e+12 solar masses
#   a   = 169.17 kpc
#   chi-squared = 9.7513
# Fitting with lmfit took 0.0102 seconds
# Fitted parameters for galaxy UGC07125 using lmfit:
#   M_b = 3.71e+10 solar masses
#   a   = 22.41 kpc
#   chi-squared = 97.4349
# Fitting with lmfit took 0.0067 seconds
# Fitted parameters for galaxy UGC02259 using lmfit:
#   M_b = 1.53e+10 solar masses
#   a   = 11.59 kpc
#   chi-squared = 19.7772
# Fitting with lmfit took 0.0051 seconds
# Fitted parameters for galaxy NGC3893 using lmfit:
#   M_b = 5.34e+10 solar masses
#   a   = 2.73 kpc
#   chi-squared = 137.1529
# Fitting with lmfit took 0.0056 seconds
# Fitted parameters for galaxy NGC3726 using lmfit:
#   M_b = 1.03e+11 solar masses
#   a   = 6.66 kpc
#   chi-squared = 1143.7152
# Error fitting galaxy NGC2366 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0032 seconds
# Fitted parameters for galaxy NGC2366 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy NGC2366. Skipping...
# Fitting with lmfit took 0.0068 seconds
# Fitted parameters for galaxy UGC04325 using lmfit:
#   M_b = 1.19e+11 solar masses
#   a   = 30.35 kpc
#   chi-squared = 60.3093
# Fitting with lmfit took 0.0144 seconds
# Fitted parameters for galaxy UGC12506 using lmfit:
#   M_b = 3.18e+11 solar masses
#   a   = 22.64 kpc
#   chi-squared = 1515.6337
# Fitting with lmfit took 0.0066 seconds
# Fitted parameters for galaxy UGC11455 using lmfit:
#   M_b = 5.73e+11 solar masses
#   a   = 18.45 kpc
#   chi-squared = 12151.8805
# Error fitting galaxy NGC1705 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0032 seconds
# Fitted parameters for galaxy NGC1705 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy NGC1705. Skipping...
# Error fitting galaxy F563-V1 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0032 seconds
# Fitted parameters for galaxy F563-V1 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy F563-V1. Skipping...
# Fitting with lmfit took 0.0097 seconds
# Fitted parameters for galaxy F561-1 using lmfit:
#   M_b = 7.37e+11 solar masses
#   a   = 112.27 kpc
#   chi-squared = 5.9260
# Error fitting galaxy UGC06818 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0031 seconds
# Fitted parameters for galaxy UGC06818 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC06818. Skipping...
# Fitting with lmfit took 0.0061 seconds
# Fitted parameters for galaxy UGC07089 using lmfit:
#   M_b = 3.49e+10 solar masses
#   a   = 18.07 kpc
#   chi-squared = 43.7384
# Fitting with lmfit took 0.0062 seconds
# Fitted parameters for galaxy UGC05253 using lmfit:
#   M_b = 1.29e+11 solar masses
#   a   = 15.36 kpc
#   chi-squared = 5593.5736
# Fitting with lmfit took 0.0065 seconds
# Fitted parameters for galaxy UGC04305 using lmfit:
#   M_b = 3.57e+10 solar masses
#   a   = 19.74 kpc
#   chi-squared = 76.1736
# Fitting with lmfit took 0.0068 seconds
# Fitted parameters for galaxy UGC06446 using lmfit:
#   M_b = 2.47e+10 solar masses
#   a   = 17.49 kpc
#   chi-squared = 44.0343
# Fitting with lmfit took 0.0056 seconds
# Fitted parameters for galaxy NGC3953 using lmfit:
#   M_b = 3.27e+11 solar masses
#   a   = 11.19 kpc
#   chi-squared = 189.4622
# Error fitting galaxy NGC6789 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0032 seconds
# Fitted parameters for galaxy NGC6789 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy NGC6789. Skipping...
# Error fitting galaxy UGC07232 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0031 seconds
# Fitted parameters for galaxy UGC07232 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC07232. Skipping...
# Fitting with lmfit took 0.0058 seconds
# Fitted parameters for galaxy UGC03546 using lmfit:
#   M_b = 9.01e+10 solar masses
#   a   = 4.82 kpc
#   chi-squared = 5018.6310
# Fitting with lmfit took 0.0061 seconds
# Fitted parameters for galaxy NGC6503 using lmfit:
#   M_b = 1.16e+10 solar masses
#   a   = 2.01 kpc
#   chi-squared = 1108.9565
# Fitting with lmfit took 0.0060 seconds
# Fitted parameters for galaxy UGC05005 using lmfit:
#   M_b = 4.49e+10 solar masses
#   a   = 26.03 kpc
#   chi-squared = 16.8740
# Error fitting galaxy UGC07690 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0033 seconds
# Fitted parameters for galaxy UGC07690 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC07690. Skipping...
# Fitting with lmfit took 0.0124 seconds
# Fitted parameters for galaxy UGC00634 using lmfit:
#   M_b = 2.53e+10 solar masses
#   a   = 14.24 kpc
#   chi-squared = 11.5347
# Error fitting galaxy DDO154 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0082 seconds
# Fitted parameters for galaxy DDO154 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy DDO154. Skipping...
# Error fitting galaxy UGC07603 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0103 seconds
# Fitted parameters for galaxy UGC07603 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC07603. Skipping...
# Fitting with lmfit took 0.0183 seconds
# Fitted parameters for galaxy NGC3992 using lmfit:
#   M_b = 2.82e+11 solar masses
#   a   = 9.10 kpc
#   chi-squared = 1229.5917
# Fitting with lmfit took 0.0149 seconds
# Fitted parameters for galaxy NGC4088 using lmfit:
#   M_b = 1.57e+11 solar masses
#   a   = 7.75 kpc
#   chi-squared = 3238.9718
# Fitting with lmfit took 0.0160 seconds
# Fitted parameters for galaxy F579-V1 using lmfit:
#   M_b = 7.60e+10 solar masses
#   a   = 21.50 kpc
#   chi-squared = 67.1424
# Error fitting galaxy ESO444-G084 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0052 seconds
# Fitted parameters for galaxy ESO444-G084 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy ESO444-G084. Skipping...
# Error fitting galaxy F565-V2 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0081 seconds
# Fitted parameters for galaxy F565-V2 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy F565-V2. Skipping...
# Fitting with lmfit took 0.0136 seconds
# Fitted parameters for galaxy UGC10310 using lmfit:
#   M_b = 1.24e+11 solar masses
#   a   = 40.32 kpc
#   chi-squared = 17.1645
# Fitting with lmfit took 0.0119 seconds
# Fitted parameters for galaxy NGC5055 using lmfit:
#   M_b = 7.57e+10 solar masses
#   a   = 3.89 kpc
#   chi-squared = 457.5369
# Fitting with lmfit took 0.0113 seconds
# Fitted parameters for galaxy NGC0801 using lmfit:
#   M_b = 3.56e+11 solar masses
#   a   = 7.33 kpc
#   chi-squared = 609.3896
# Fitting with lmfit took 0.0149 seconds
# Fitted parameters for galaxy F563-1 using lmfit:
#   M_b = 5.02e+10 solar masses
#   a   = 34.43 kpc
#   chi-squared = 13.7236
# Fitting with lmfit took 0.0132 seconds
# Fitted parameters for galaxy NGC6946 using lmfit:
#   M_b = 9.18e+10 solar masses
#   a   = 5.73 kpc
#   chi-squared = 8874.9698
# Fitting with lmfit took 0.0154 seconds
# Fitted parameters for galaxy UGC06614 using lmfit:
#   M_b = 1.82e+11 solar masses
#   a   = 31.48 kpc
#   chi-squared = 998.0956
# Fitting with lmfit took 0.0062 seconds
# Fitted parameters for galaxy NGC3769 using lmfit:
#   M_b = 1.84e+10 solar masses
#   a   = 2.55 kpc
#   chi-squared = 58.9953
# Fitting with lmfit took 0.0118 seconds
# Fitted parameters for galaxy NGC3917 using lmfit:
#   M_b = 1.40e+11 solar masses
#   a   = 20.71 kpc
#   chi-squared = 728.5801
# Fitting with lmfit took 0.0086 seconds
# Fitted parameters for galaxy UGC05999 using lmfit:
#   M_b = 1.56e+11 solar masses
#   a   = 51.14 kpc
#   chi-squared = 31.0632
# Fitting with lmfit took 0.0059 seconds
# Fitted parameters for galaxy NGC4085 using lmfit:
#   M_b = 5.06e+10 solar masses
#   a   = 6.13 kpc
#   chi-squared = 78.4185
# Fitting with lmfit took 0.0057 seconds
# Fitted parameters for galaxy NGC3198 using lmfit:
#   M_b = 6.44e+10 solar masses
#   a   = 8.56 kpc
#   chi-squared = 2241.9287
# Fitting with lmfit took 0.0072 seconds
# Fitted parameters for galaxy F568-3 using lmfit:
#   M_b = 2.89e+11 solar masses
#   a   = 68.75 kpc
#   chi-squared = 41.0210
# Fitting with lmfit took 0.0076 seconds
# Fitted parameters for galaxy NGC5033 using lmfit:
#   M_b = 7.23e+10 solar masses
#   a   = 4.63 kpc
#   chi-squared = 1817.1004
# Fitting with lmfit took 0.0095 seconds
# Fitted parameters for galaxy UGC11557 using lmfit:
#   M_b = 6.83e+10 solar masses
#   a   = 14.74 kpc
#   chi-squared = 97.9973
# Fitting with lmfit took 0.0131 seconds
# Fitted parameters for galaxy UGC02885 using lmfit:
#   M_b = 5.34e+11 solar masses
#   a   = 21.74 kpc
#   chi-squared = 846.6994
# Error fitting galaxy KK98-251 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0084 seconds
# Fitted parameters for galaxy KK98-251 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy KK98-251. Skipping...
# Fitting with lmfit took 0.0181 seconds
# Fitted parameters for galaxy NGC5907 using lmfit:
#   M_b = 2.50e+11 solar masses
#   a   = 9.78 kpc
#   chi-squared = 1374.2558
# Fitting with lmfit took 0.0058 seconds
# Fitted parameters for galaxy UGC06917 using lmfit:
#   M_b = 3.07e+10 solar masses
#   a   = 11.26 kpc
#   chi-squared = 23.9804
# Error fitting galaxy UGC09992 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0032 seconds
# Fitted parameters for galaxy UGC09992 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC09992. Skipping...
# Fitting with lmfit took 0.0059 seconds
# Fitted parameters for galaxy UGC04499 using lmfit:
#   M_b = 1.96e+10 solar masses
#   a   = 12.74 kpc
#   chi-squared = 6.8634
# Fitting with lmfit took 0.0053 seconds
# Fitted parameters for galaxy NGC0289 using lmfit:
#   M_b = 8.42e+10 solar masses
#   a   = 3.96 kpc
#   chi-squared = 1824.3613
# Fitting with lmfit took 0.0067 seconds
# Fitted parameters for galaxy UGC06983 using lmfit:
#   M_b = 2.36e+10 solar masses
#   a   = 9.66 kpc
#   chi-squared = 116.7919
# Fitting with lmfit took 0.0053 seconds
# Fitted parameters for galaxy UGC06973 using lmfit:
#   M_b = 1.52e+10 solar masses
#   a   = 0.32 kpc
#   chi-squared = 3.2071
# Fitting with lmfit took 0.0071 seconds
# Fitted parameters for galaxy UGC02487 using lmfit:
#   M_b = 4.92e+11 solar masses
#   a   = 10.30 kpc
#   chi-squared = 1748.5493
# Fitting with lmfit took 0.0053 seconds
# Fitted parameters for galaxy UGC09037 using lmfit:
#   M_b = 9.45e+10 solar masses
#   a   = 11.97 kpc
#   chi-squared = 88.4787
# Fitting with lmfit took 0.0056 seconds
# Fitted parameters for galaxy NGC4051 using lmfit:
#   M_b = 1.30e+11 solar masses
#   a   = 8.72 kpc
#   chi-squared = 1328.8332
# Fitting with lmfit took 0.0071 seconds
# Fitted parameters for galaxy F571-8 using lmfit:
#   M_b = 5.08e+09 solar masses
#   a   = 2.15 kpc
#   chi-squared = 251.3024
# Error fitting galaxy D564-8 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0032 seconds
# Fitted parameters for galaxy D564-8 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy D564-8. Skipping...
# Error fitting galaxy UGC00891 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0032 seconds
# Fitted parameters for galaxy UGC00891 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC00891. Skipping...
# Fitting with lmfit took 0.0059 seconds
# Fitted parameters for galaxy NGC2998 using lmfit:
#   M_b = 2.34e+11 solar masses
#   a   = 11.42 kpc
#   chi-squared = 1277.9663
# Fitting with lmfit took 0.0070 seconds
# Fitted parameters for galaxy NGC0055 using lmfit:
#   M_b = 2.99e+10 solar masses
#   a   = 14.78 kpc
#   chi-squared = 82.0306
# Fitting with lmfit took 0.0114 seconds
# Fitted parameters for galaxy NGC2683 using lmfit:
#   M_b = 6.62e+10 solar masses
#   a   = 2.46 kpc
#   chi-squared = 1141.9315
# Fitting with lmfit took 0.0183 seconds
# Fitted parameters for galaxy UGC12632 using lmfit:
#   M_b = 1.11e+12 solar masses
#   a   = 182.62 kpc
#   chi-squared = 11.4995
# Fitting with lmfit took 0.0199 seconds
# Fitted parameters for galaxy F563-V2 using lmfit:
#   M_b = 3.37e+11 solar masses
#   a   = 67.57 kpc
#   chi-squared = 53.2364
# Fitting with lmfit took 0.0094 seconds
# Fitted parameters for galaxy NGC5585 using lmfit:
#   M_b = 9.11e+09 solar masses
#   a   = 5.78 kpc
#   chi-squared = 21.3499
# Fitting with lmfit took 0.4902 seconds
# Fitted parameters for galaxy NGC2976 using lmfit:
#   M_b = 7.96e+20 solar masses
#   a   = 1345297.56 kpc
#   chi-squared = 931.9121
# Fitting with lmfit took 0.0151 seconds
# Fitted parameters for galaxy NGC7814 using lmfit:
#   M_b = 3.66e+10 solar masses
#   a   = 5.86 kpc
#   chi-squared = 874.9286
# Fitting with lmfit took 0.0060 seconds
# Fitted parameters for galaxy UGC05716 using lmfit:
#   M_b = 1.49e+10 solar masses
#   a   = 16.26 kpc
#   chi-squared = 16.6563
# Fitting with lmfit took 0.0076 seconds
# Fitted parameters for galaxy F571-V1 using lmfit:
#   M_b = 2.65e+10 solar masses
#   a   = 20.06 kpc
#   chi-squared = 21.4822
# Error fitting galaxy F583-1 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0038 seconds
# Fitted parameters for galaxy F583-1 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy F583-1. Skipping...
# Fitting with lmfit took 0.0073 seconds
# Fitted parameters for galaxy UGC11914 using lmfit:
#   M_b = 3.78e+11 solar masses
#   a   = 13.75 kpc
#   chi-squared = 5534.7926
# Fitting with lmfit took 0.0064 seconds
# Fitted parameters for galaxy NGC0891 using lmfit:
#   M_b = 7.19e+10 solar masses
#   a   = 4.22 kpc
#   chi-squared = 3317.3199
# Fitting with lmfit took 0.0065 seconds
# Fitted parameters for galaxy DDO170 using lmfit:
#   M_b = 1.73e+10 solar masses
#   a   = 19.77 kpc
#   chi-squared = 23.5699
# Fitting with lmfit took 0.0067 seconds
# Fitted parameters for galaxy F568-V1 using lmfit:
#   M_b = 4.36e+10 solar masses
#   a   = 23.54 kpc
#   chi-squared = 27.1950
# Fitting with lmfit took 0.0066 seconds
# Fitted parameters for galaxy ESO079-G014 using lmfit:
#   M_b = 7.33e+11 solar masses
#   a   = 54.12 kpc
#   chi-squared = 233.6733
# Fitting with lmfit took 0.0062 seconds
# Fitted parameters for galaxy UGC06787 using lmfit:
#   M_b = 1.43e+11 solar masses
#   a   = 9.77 kpc
#   chi-squared = 13985.6105
# Error fitting galaxy D631-7 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0031 seconds
# Fitted parameters for galaxy D631-7 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy D631-7. Skipping...
# Fitting with lmfit took 0.0058 seconds
# Fitted parameters for galaxy NGC2955 using lmfit:
#   M_b = 3.70e+11 solar masses
#   a   = 18.02 kpc
#   chi-squared = 2894.2158
# Fitting with lmfit took 0.0056 seconds
# Fitted parameters for galaxy UGC03580 using lmfit:
#   M_b = 2.60e+10 solar masses
#   a   = 4.51 kpc
#   chi-squared = 1975.8255
# Fitting with lmfit took 0.0058 seconds
# Fitted parameters for galaxy NGC4100 using lmfit:
#   M_b = 7.92e+10 solar masses
#   a   = 5.46 kpc
#   chi-squared = 4402.6319
# Fitting with lmfit took 0.0059 seconds
# Fitted parameters for galaxy UGC06786 using lmfit:
#   M_b = 8.07e+10 solar masses
#   a   = 8.88 kpc
#   chi-squared = 10323.6338
# Fitting with lmfit took 0.0059 seconds
# Fitted parameters for galaxy UGC00128 using lmfit:
#   M_b = 6.30e+10 solar masses
#   a   = 26.44 kpc
#   chi-squared = 239.0884
# Error fitting galaxy NGC4068 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0095 seconds
# Fitted parameters for galaxy NGC4068 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy NGC4068. Skipping...
# Fitting with lmfit took 0.4825 seconds
# Fitted parameters for galaxy UGC00731 using lmfit:
#   M_b = 1.75e+21 solar masses
#   a   = 8109186.96 kpc
#   chi-squared = 181.0041
# Error fitting galaxy UGC07608 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0081 seconds
# Fitted parameters for galaxy UGC07608 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC07608. Skipping...
# Fitting with lmfit took 0.0190 seconds
# Fitted parameters for galaxy UGC05750 using lmfit:
#   M_b = 1.78e+11 solar masses
#   a   = 72.84 kpc
#   chi-squared = 58.3011
# Error fitting galaxy UGCA442 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0079 seconds
# Fitted parameters for galaxy UGCA442 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGCA442. Skipping...
# Error fitting galaxy UGC04278 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0079 seconds
# Fitted parameters for galaxy UGC04278 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC04278. Skipping...
# Fitting with lmfit took 0.0143 seconds
# Fitted parameters for galaxy UGC07151 using lmfit:
#   M_b = 1.51e+10 solar masses
#   a   = 6.50 kpc
#   chi-squared = 29.7413
# Fitting with lmfit took 0.0060 seconds
# Fitted parameters for galaxy NGC3972 using lmfit:
#   M_b = 1.28e+11 solar masses
#   a   = 19.36 kpc
#   chi-squared = 128.5412
# Fitting with lmfit took 0.5927 seconds
# Fitted parameters for galaxy F568-1 using lmfit:
#   M_b = 1.68e+21 solar masses
#   a   = 5259447.18 kpc
#   chi-squared = 60.1066
# Fitting with lmfit took 0.0069 seconds
# Fitted parameters for galaxy NGC7793 using lmfit:
#   M_b = 2.30e+10 solar masses
#   a   = 4.79 kpc
#   chi-squared = 756.7556
# Fitting with lmfit took 0.0080 seconds
# Fitted parameters for galaxy NGC3877 using lmfit:
#   M_b = 4.08e+11 solar masses
#   a   = 26.21 kpc
#   chi-squared = 509.8967
# Fitting with lmfit took 0.0098 seconds
# Fitted parameters for galaxy NGC6674 using lmfit:
#   M_b = 3.80e+11 solar masses
#   a   = 10.02 kpc
#   chi-squared = 4387.5384
# Fitting with lmfit took 0.0079 seconds
# Fitted parameters for galaxy NGC6015 using lmfit:
#   M_b = 5.90e+10 solar masses
#   a   = 5.71 kpc
#   chi-squared = 3568.4485
# Fitting with lmfit took 0.0096 seconds
# Fitted parameters for galaxy UGC12732 using lmfit:
#   M_b = 1.69e+11 solar masses
#   a   = 62.96 kpc
#   chi-squared = 100.1937
# Error fitting galaxy DDO168 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0036 seconds
# Fitted parameters for galaxy DDO168 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy DDO168. Skipping...
# Fitting with lmfit took 0.0091 seconds
# Fitted parameters for galaxy NGC2903 using lmfit:
#   M_b = 4.88e+10 solar masses
#   a   = 2.26 kpc
#   chi-squared = 5102.6402
# Fitting with lmfit took 0.0057 seconds
# Fitted parameters for galaxy UGC02455 using lmfit:
#   M_b = 1.16e+10 solar masses
#   a   = 4.84 kpc
#   chi-squared = 50.1966
# Fitting with lmfit took 0.0092 seconds
# Fitted parameters for galaxy UGC02023 using lmfit:
#   M_b = 2.40e+11 solar masses
#   a   = 55.73 kpc
#   chi-squared = 18.8696
# Error fitting galaxy DDO064 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0038 seconds
# Fitted parameters for galaxy DDO064 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy DDO064. Skipping...
# Fitting with lmfit took 0.0058 seconds
# Fitted parameters for galaxy UGC05986 using lmfit:
#   M_b = 1.47e+10 solar masses
#   a   = 6.10 kpc
#   chi-squared = 306.1919
# Error fitting galaxy UGCA281 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0031 seconds
# Fitted parameters for galaxy UGCA281 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGCA281. Skipping...
# Fitting with lmfit took 0.0058 seconds
# Fitted parameters for galaxy UGC06399 using lmfit:
#   M_b = 4.32e+10 solar masses
#   a   = 21.51 kpc
#   chi-squared = 19.0774
# Fitting with lmfit took 0.0059 seconds
# Fitted parameters for galaxy UGC09133 using lmfit:
#   M_b = 3.19e+11 solar masses
#   a   = 9.99 kpc
#   chi-squared = 21484.1253
# Fitting with lmfit took 0.0084 seconds
# Fitted parameters for galaxy NGC0024 using lmfit:
#   M_b = 1.27e+10 solar masses
#   a   = 3.95 kpc
#   chi-squared = 1191.6182
# Error fitting galaxy UGC08550 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0031 seconds
# Fitted parameters for galaxy UGC08550 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC08550. Skipping...
# Fitting with lmfit took 0.0062 seconds
# Fitted parameters for galaxy UGC02953 using lmfit:
#   M_b = 3.04e+11 solar masses
#   a   = 7.93 kpc
#   chi-squared = 80597.9071
# Fitting with lmfit took 0.0053 seconds
# Fitted parameters for galaxy NGC4138 using lmfit:
#   M_b = 2.75e+10 solar masses
#   a   = 1.12 kpc
#   chi-squared = 124.3816
# Fitting with lmfit took 0.0068 seconds
# Fitted parameters for galaxy NGC0247 using lmfit:
#   M_b = 1.23e+11 solar masses
#   a   = 32.46 kpc
#   chi-squared = 115.2829
# Fitting with lmfit took 0.0070 seconds
# Fitted parameters for galaxy IC4202 using lmfit:
#   M_b = 9.70e+11 solar masses
#   a   = 55.38 kpc
#   chi-squared = 5419.3572
# Fitting with lmfit took 0.0060 seconds
# Fitted parameters for galaxy UGC08286 using lmfit:
#   M_b = 9.23e+09 solar masses
#   a   = 8.22 kpc
#   chi-squared = 60.5245
# Error fitting galaxy IC2574 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0033 seconds
# Fitted parameters for galaxy IC2574 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy IC2574. Skipping...
# Fitting with lmfit took 0.0054 seconds
# Fitted parameters for galaxy NGC4559 using lmfit:
#   M_b = 3.94e+10 solar masses
#   a   = 6.82 kpc
#   chi-squared = 222.9136
# Fitting with lmfit took 0.0065 seconds
# Fitted parameters for galaxy UGC01230 using lmfit:
#   M_b = 5.44e+10 solar masses
#   a   = 22.87 kpc
#   chi-squared = 36.7656
# Error fitting galaxy UGC07577 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0031 seconds
# Fitted parameters for galaxy UGC07577 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC07577. Skipping...
# Fitting with lmfit took 0.0079 seconds
# Fitted parameters for galaxy UGC06628 using lmfit:
#   M_b = 1.62e+11 solar masses
#   a   = 43.88 kpc
#   chi-squared = 4.2518
# Fitting with lmfit took 0.0051 seconds
# Fitted parameters for galaxy NGC4013 using lmfit:
#   M_b = 4.95e+10 solar masses
#   a   = 1.02 kpc
#   chi-squared = 2227.2393
# Fitting with lmfit took 0.0071 seconds
# Fitted parameters for galaxy UGC03205 using lmfit:
#   M_b = 1.75e+11 solar masses
#   a   = 11.71 kpc
#   chi-squared = 15404.3126
# Fitting with lmfit took 0.0059 seconds
# Fitted parameters for galaxy NGC7331 using lmfit:
#   M_b = 1.71e+11 solar masses
#   a   = 3.27 kpc
#   chi-squared = 1830.9461
# Fitting with lmfit took 0.0067 seconds
# Fitted parameters for galaxy UGC02916 using lmfit:
#   M_b = 4.98e+11 solar masses
#   a   = 47.55 kpc
#   chi-squared = 1274.2318
# Fitting with lmfit took 0.0056 seconds
# Fitted parameters for galaxy UGC06923 using lmfit:
#   M_b = 9.17e+09 solar masses
#   a   = 4.51 kpc
#   chi-squared = 4.1813
# Error fitting galaxy UGC04483 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0032 seconds
# Fitted parameters for galaxy UGC04483 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC04483. Skipping...
# Fitting with lmfit took 0.0077 seconds
# Fitted parameters for galaxy NGC4217 using lmfit:
#   M_b = 7.72e+10 solar masses
#   a   = 14.04 kpc
#   chi-squared = 2198.8659
# Error fitting galaxy NGC3109 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0031 seconds
# Fitted parameters for galaxy NGC3109 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy NGC3109. Skipping...
# Error fitting galaxy UGC05764 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0032 seconds
# Fitted parameters for galaxy UGC05764 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy UGC05764. Skipping...
# Fitting with lmfit took 0.0053 seconds
# Fitted parameters for galaxy NGC3949 using lmfit:
#   M_b = 6.10e+10 solar masses
#   a   = 3.84 kpc
#   chi-squared = 291.9901
# Error fitting galaxy D512-2 with lmfit: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# Fitting with lmfit took 0.0032 seconds
# Fitted parameters for galaxy D512-2 using lmfit:
#   M_b = nan solar masses
#   a   = nan kpc
#   chi-squared = nan
# Error fitting galaxy D512-2. Skipping...
# Fitting with lmfit took 0.1026 seconds
# Fitted parameters for galaxy NGC4389 using lmfit:
#   M_b = 6.45e+10 solar masses
#   a   = 8.98 kpc
#   chi-squared = 43.2716
# Fitting with lmfit took 0.0100 seconds
# Fitted parameters for galaxy NGC4157 using lmfit:
#   M_b = 1.26e+11 solar masses
#   a   = 5.43 kpc
#   chi-squared = 4698.4161
# Fitting with lmfit took 0.0059 seconds
# Fitted parameters for galaxy DDO161 using lmfit:
#   M_b = 1.17e+10 solar masses
#   a   = 11.18 kpc
#   chi-squared = 115.4850
# Fitting complete. Results saved.

# %% [markdown]
# # Generate lmfit with Gamma and Bulge

# %%
bulge_list = []

for gal in galaxy_ids:
    df, _, _ = get_rc_data(gal)
    vbul = df.Vbul.values 
    
    if np.any(vbul > 0):
        bulge_list.append(gal)

print("Total number of galaxies:", len(galaxy_ids))
print("Number of galaxies with bulge component:", len(bulge_list))
print("Galaxies with bulge component:", bulge_list)
# Out:
# Total number of galaxies: 175
# Number of galaxies with bulge component: 32
# Galaxies with bulge component: ['NGC5005', 'NGC6195', 'UGC08699', 'NGC2841', 'NGC5985', 'UGC05253', 'UGC03546', 'NGC6946', 'UGC06614', 'NGC5033', 'UGC02885', 'UGC06973', 'UGC02487', 'NGC2683', 'NGC7814', 'UGC11914', 'NGC0891', 'UGC06787', 'NGC2955', 'UGC03580', 'UGC06786', 'NGC6674', 'UGC09133', 'UGC02953', 'NGC4138', 'IC4202', 'NGC4013', 'UGC03205', 'NGC7331', 'UGC02916', 'NGC4217', 'NGC4157']

# %%
plot_path = os.getcwd() + "/plots/fits/"
data_path = os.getcwd() + "/data/fit_data/"

gamma_data = pd.read_csv(data_path + "gamma_fits.csv")

results = []
failed = []

for galaxy_id in galaxy_ids: 
    gamma_s, gamma_b = gamma_data[gamma_data["GalaxyID"] == galaxy_id][["Gamma_disk", "Gamma_bulge"]].values[0]
    try:
        fitter = HernquistFit(galaxy_id, gamma_star=gamma_s, gamma_bulge=gamma_b, method="lmfit")
        M_b_fit, a_fit = fitter.M_b_fit, fitter.a_fit
        chisqr = fitter.error
        
        M_b_fit_b, a_fit_b = fitter.M_b_fit_bulge, fitter.a_fit_bulge
        chisqr_b = fitter.error_bulge
    except Exception as e:
        failed.append(galaxy_id)
        print(f"Error fitting galaxy {galaxy_id}. Skipping...")
        continue
    
    results.append([galaxy_id, M_b_fit, a_fit, chisqr, M_b_fit_b, a_fit_b, chisqr_b])
    
    # r_vals = fitter.r_vals
    # rmax = r_vals.max() * 2 # kpc
    # ri = np.geomspace(0.1, rmax, 100)
    
    # vc_dg_data = fitter.vc_disk_gas
    # vc_bulge_data = fitter.vc_bulge
    
    # vc_dg_model = fitter.vc(ri, M_b=M_b_fit, a=a_fit)
    # vc_bulge_model = fitter.vc(ri, M_b=M_b_fit_b, a=a_fit_b)
    
    
    # plt.figure(figsize=(6,4))

    # plt.scatter(r_vals, vc_dg_data, label='Disk+Gas', color='C0', s=10)
    # plt.plot(ri, vc_dg_model, label='Disk+Gas Hernquist', color='C0', alpha=0.7)
    # plt.scatter(r_vals, vc_bulge_data, label='Bulge', color='C1', s=10)
    # plt.plot(ri, vc_bulge_model, label='Bulge Hernquist', color='C1', alpha=0.7)
    # plt.xlabel('Radius (kpc)')
    # plt.ylabel('Velocity (km/s)')
    # plt.title(f'Hernquist Fit for Galaxy {galaxy_id}')
    # plt.legend(fontsize=6, loc="lower right")
    # plt.grid()
    # plt.savefig(plot_path + f"disk-bulge-gas/{galaxy_id}_disk_gas_bulge_fit.png")
    # plt.close()
    
    
results_df = pd.DataFrame(results, columns=["GalaxyID", "M_b_fit", "a_fit", "ChiSq", "M_b_fit_bulge", "a_fit_bulge", "ChiSq_bulge"])
results_df.to_csv(os.path.join(data_path, "hern_fits.csv"), index=False)
print("Fitting complete. Results saved.")
# np.savetxt(os.path.join(data_path, "hern-failed.txt"), failed, fmt="%s")
print("Number of failed fits:", len(failed))
# Out:
# Fitting with lmfit took 0.0176 seconds
# Fitted parameters for galaxy NGC5371 using lmfit:
#   M_b = 3.38e+11 solar masses
#   a   = 10.72 kpc
#   chi-squared = 5220.8497
# Fitting with lmfit took 0.0162 seconds
# Fitted parameters for galaxy UGC05829 using lmfit:
#   M_b = 4.09e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 218.9158
# Fitting with lmfit took 0.0078 seconds
# Fitted parameters for galaxy NGC5005 using lmfit:
#   M_b = 3.04e+11 solar masses
#   a   = 7.39 kpc
#   chi-squared = 1667.2293
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0121 seconds
# Fitted parameters for galaxy NGC5005 using lmfit:
#   M_b = 1.50e+10 solar masses
#   a   = 0.41 kpc
#   chi-squared = 1970.0142
# Fitting with lmfit took 0.0074 seconds
# Fitted parameters for galaxy UGCA444 using lmfit:
#   M_b = 6.69e+09 solar masses
#   a   = 13.21 kpc
#   chi-squared = 133.6809
# Fitting with lmfit took 0.0061 seconds
# Fitted parameters for galaxy NGC1003 using lmfit:
#   M_b = 1.38e+10 solar masses
#   a   = 3.72 kpc
#   chi-squared = 364.9235
# Fitting with lmfit took 0.0073 seconds
# Fitted parameters for galaxy UGC07559 using lmfit:
#   M_b = 1.95e+10 solar masses
#   a   = 21.25 kpc
#   chi-squared = 1.6819
# Fitting with lmfit took 0.0079 seconds
# Fitted parameters for galaxy NGC0100 using lmfit:
#   M_b = 8.59e+09 solar masses
#   a   = 6.53 kpc
#   chi-squared = 165.7252
# Fitting with lmfit took 0.0119 seconds
# Fitted parameters for galaxy UGC07261 using lmfit:
#   M_b = 9.00e+09 solar masses
#   a   = 6.45 kpc
#   chi-squared = 61.3186
# Fitting with lmfit took 0.0153 seconds
# Fitted parameters for galaxy NGC6195 using lmfit:
#   M_b = 9.30e+11 solar masses
#   a   = 38.45 kpc
#   chi-squared = 4153.6219
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0148 seconds
# Fitted parameters for galaxy NGC6195 using lmfit:
#   M_b = 1.11e+11 solar masses
#   a   = 2.26 kpc
#   chi-squared = 1337.4330
# Fitting with lmfit took 0.0338 seconds
# Fitted parameters for galaxy UGC01281 using lmfit:
#   M_b = 3.35e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 60.5108
# Fitting with lmfit took 0.0065 seconds
# Fitted parameters for galaxy UGC05414 using lmfit:
#   M_b = 4.06e+10 solar masses
#   a   = 20.31 kpc
#   chi-squared = 13.6017
# Fitting with lmfit took 0.0228 seconds
# Fitted parameters for galaxy UGC08837 using lmfit:
#   M_b = 4.55e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 26.9999
# Fitting with lmfit took 0.0092 seconds
# Fitted parameters for galaxy UGC11820 using lmfit:
#   M_b = 1.95e+10 solar masses
#   a   = 14.00 kpc
#   chi-squared = 53.0099
# Fitting with lmfit took 0.0149 seconds
# Fitted parameters for galaxy UGC06667 using lmfit:
#   M_b = 2.90e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 107.5074
# Fitting with lmfit took 0.0092 seconds
# Fitted parameters for galaxy NGC4183 using lmfit:
#   M_b = 3.72e+10 solar masses
#   a   = 10.80 kpc
#   chi-squared = 525.8543
# Fitting with lmfit took 0.0130 seconds
# Fitted parameters for galaxy UGC08699 using lmfit:
#   M_b = 7.17e+10 solar masses
#   a   = 5.62 kpc
#   chi-squared = 3302.3339
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0123 seconds
# Fitted parameters for galaxy UGC08699 using lmfit:
#   M_b = 1.13e+10 solar masses
#   a   = 0.40 kpc
#   chi-squared = 5352.2656
# Fitting with lmfit took 0.0090 seconds
# Fitted parameters for galaxy F583-4 using lmfit:
#   M_b = 1.54e+10 solar masses
#   a   = 14.40 kpc
#   chi-squared = 29.5787
# Fitting with lmfit took 0.0100 seconds
# Fitted parameters for galaxy UGC07399 using lmfit:
#   M_b = 4.23e+09 solar masses
#   a   = 3.92 kpc
#   chi-squared = 6.4551
# Fitting with lmfit took 0.0181 seconds
# Fitted parameters for galaxy NGC2841 using lmfit:
#   M_b = 2.93e+11 solar masses
#   a   = 6.90 kpc
#   chi-squared = 18971.1585
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0144 seconds
# Fitted parameters for galaxy NGC2841 using lmfit:
#   M_b = 3.89e+10 solar masses
#   a   = 0.01 kpc
#   chi-squared = 0.4563
# Fitting with lmfit took 0.0111 seconds
# Fitted parameters for galaxy F567-2 using lmfit:
#   M_b = 2.94e+10 solar masses
#   a   = 25.14 kpc
#   chi-squared = 26.7707
# Fitting with lmfit took 0.0118 seconds
# Fitted parameters for galaxy NGC2403 using lmfit:
#   M_b = 2.10e+10 solar masses
#   a   = 3.90 kpc
#   chi-squared = 900.7827
# Fitting with lmfit took 0.0127 seconds
# Fitted parameters for galaxy NGC4010 using lmfit:
#   M_b = 8.12e+10 solar masses
#   a   = 14.74 kpc
#   chi-squared = 289.2748
# Fitting with lmfit took 0.0121 seconds
# Fitted parameters for galaxy F574-1 using lmfit:
#   M_b = 6.11e+10 solar masses
#   a   = 28.32 kpc
#   chi-squared = 42.6380
# Fitting with lmfit took 0.0100 seconds
# Fitted parameters for galaxy NGC0300 using lmfit:
#   M_b = 9.62e+09 solar masses
#   a   = 6.84 kpc
#   chi-squared = 93.7773
# Fitting with lmfit took 0.0133 seconds
# Fitted parameters for galaxy NGC3741 using lmfit:
#   M_b = 5.94e+08 solar masses
#   a   = 3.45 kpc
#   chi-squared = 41.1616
# Fitting with lmfit took 0.0102 seconds
# Fitted parameters for galaxy NGC4214 using lmfit:
#   M_b = 1.42e+09 solar masses
#   a   = 0.94 kpc
#   chi-squared = 151.8891
# Fitting with lmfit took 0.0121 seconds
# Fitted parameters for galaxy PGC51017 using lmfit:
#   M_b = 8.46e+08 solar masses
#   a   = 2.73 kpc
#   chi-squared = 9.3512
# Fitting with lmfit took 0.0123 seconds
# Fitted parameters for galaxy CamB using lmfit:
#   M_b = 9.27e+08 solar masses
#   a   = 4.76 kpc
#   chi-squared = 12.2448
# Fitting with lmfit took 0.0141 seconds
# Fitted parameters for galaxy UGC07866 using lmfit:
#   M_b = 3.76e+10 solar masses
#   a   = 30.11 kpc
#   chi-squared = 1.1321
# Fitting with lmfit took 0.0181 seconds
# Fitted parameters for galaxy F574-2 using lmfit:
#   M_b = 3.43e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 17.5879
# Fitting with lmfit took 0.0066 seconds
# Fitted parameters for galaxy NGC2915 using lmfit:
#   M_b = 9.24e+08 solar masses
#   a   = 1.03 kpc
#   chi-squared = 180.8324
# Fitting with lmfit took 0.0115 seconds
# Fitted parameters for galaxy UGC08490 using lmfit:
#   M_b = 2.75e+09 solar masses
#   a   = 1.93 kpc
#   chi-squared = 53.1502
# Fitting with lmfit took 0.0256 seconds
# Fitted parameters for galaxy UGC07524 using lmfit:
#   M_b = 4.71e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 67.2549
# Fitting with lmfit took 0.0083 seconds
# Fitted parameters for galaxy UGC05721 using lmfit:
#   M_b = 1.50e+09 solar masses
#   a   = 1.45 kpc
#   chi-squared = 80.4831
# Fitting with lmfit took 0.0092 seconds
# Fitted parameters for galaxy ESO563-G021 using lmfit:
#   M_b = 3.60e+11 solar masses
#   a   = 22.13 kpc
#   chi-squared = 2394.8364
# Fitting with lmfit took 0.0078 seconds
# Fitted parameters for galaxy UGC00191 using lmfit:
#   M_b = 1.97e+10 solar masses
#   a   = 11.04 kpc
#   chi-squared = 9.3859
# Fitting with lmfit took 0.0101 seconds
# Fitted parameters for galaxy ESO116-G012 using lmfit:
#   M_b = 1.72e+10 solar masses
#   a   = 7.48 kpc
#   chi-squared = 114.2688
# Fitting with lmfit took 0.0106 seconds
# Fitted parameters for galaxy NGC3521 using lmfit:
#   M_b = 8.98e+10 solar masses
#   a   = 2.66 kpc
#   chi-squared = 2160.2044
# Fitting with lmfit took 0.0133 seconds
# Fitted parameters for galaxy NGC5985 using lmfit:
#   M_b = 4.17e+11 solar masses
#   a   = 29.83 kpc
#   chi-squared = 1647.8425
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0092 seconds
# Fitted parameters for galaxy NGC5985 using lmfit:
#   M_b = 7.36e+09 solar masses
#   a   = 0.00 kpc
#   chi-squared = 0.0039
# Fitting with lmfit took 0.0156 seconds
# Fitted parameters for galaxy UGC05918 using lmfit:
#   M_b = 2.12e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 7.6100
# Fitting with lmfit took 0.0097 seconds
# Fitted parameters for galaxy UGC06930 using lmfit:
#   M_b = 4.72e+10 solar masses
#   a   = 15.03 kpc
#   chi-squared = 52.7696
# Fitting with lmfit took 0.0116 seconds
# Fitted parameters for galaxy NGC1090 using lmfit:
#   M_b = 1.06e+11 solar masses
#   a   = 8.57 kpc
#   chi-squared = 576.6668
# Fitting with lmfit took 0.0255 seconds
# Fitted parameters for galaxy UGC07323 using lmfit:
#   M_b = 1.26e+12 solar masses
#   a   = 100.00 kpc
#   chi-squared = 10.2565
# Fitting with lmfit took 0.0136 seconds
# Fitted parameters for galaxy UGC07125 using lmfit:
#   M_b = 3.71e+10 solar masses
#   a   = 22.41 kpc
#   chi-squared = 97.4349
# Fitting with lmfit took 0.0124 seconds
# Fitted parameters for galaxy UGC02259 using lmfit:
#   M_b = 1.53e+10 solar masses
#   a   = 11.59 kpc
#   chi-squared = 19.7772
# Fitting with lmfit took 0.0126 seconds
# Fitted parameters for galaxy NGC3893 using lmfit:
#   M_b = 5.34e+10 solar masses
#   a   = 2.73 kpc
#   chi-squared = 137.1529
# Fitting with lmfit took 0.0154 seconds
# Fitted parameters for galaxy NGC3726 using lmfit:
#   M_b = 1.03e+11 solar masses
#   a   = 6.66 kpc
#   chi-squared = 1143.7152
# Fitting with lmfit took 0.0178 seconds
# Fitted parameters for galaxy NGC2366 using lmfit:
#   M_b = 1.54e+10 solar masses
#   a   = 15.59 kpc
#   chi-squared = 54.4795
# Fitting with lmfit took 0.0146 seconds
# Fitted parameters for galaxy UGC04325 using lmfit:
#   M_b = 1.19e+11 solar masses
#   a   = 30.35 kpc
#   chi-squared = 60.3093
# Fitting with lmfit took 0.0153 seconds
# Fitted parameters for galaxy UGC12506 using lmfit:
#   M_b = 3.18e+11 solar masses
#   a   = 22.64 kpc
#   chi-squared = 1515.6337
# Fitting with lmfit took 0.0181 seconds
# Fitted parameters for galaxy UGC11455 using lmfit:
#   M_b = 5.73e+11 solar masses
#   a   = 18.45 kpc
#   chi-squared = 12151.8805
# Fitting with lmfit took 0.0164 seconds
# Fitted parameters for galaxy NGC1705 using lmfit:
#   M_b = 7.83e+08 solar masses
#   a   = 0.66 kpc
#   chi-squared = 60.9362
# Fitting with lmfit took 0.0166 seconds
# Fitted parameters for galaxy F563-V1 using lmfit:
#   M_b = 2.46e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 13.1294
# Fitting with lmfit took 0.0125 seconds
# Fitted parameters for galaxy F561-1 using lmfit:
#   M_b = 5.93e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 5.9670
# Fitting with lmfit took 0.0078 seconds
# Fitted parameters for galaxy UGC06818 using lmfit:
#   M_b = 6.50e+09 solar masses
#   a   = 7.28 kpc
#   chi-squared = 2.7259
# Fitting with lmfit took 0.0101 seconds
# Fitted parameters for galaxy UGC07089 using lmfit:
#   M_b = 3.49e+10 solar masses
#   a   = 18.07 kpc
#   chi-squared = 43.7384
# Fitting with lmfit took 0.0147 seconds
# Fitted parameters for galaxy UGC05253 using lmfit:
#   M_b = 1.29e+11 solar masses
#   a   = 15.36 kpc
#   chi-squared = 5593.5736
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0130 seconds
# Fitted parameters for galaxy UGC05253 using lmfit:
#   M_b = 7.94e+10 solar masses
#   a   = 1.19 kpc
#   chi-squared = 5224.5647
# Fitting with lmfit took 0.0147 seconds
# Fitted parameters for galaxy UGC04305 using lmfit:
#   M_b = 3.57e+10 solar masses
#   a   = 19.74 kpc
#   chi-squared = 76.1736
# Fitting with lmfit took 0.0162 seconds
# Fitted parameters for galaxy UGC06446 using lmfit:
#   M_b = 2.47e+10 solar masses
#   a   = 17.49 kpc
#   chi-squared = 44.0343
# Fitting with lmfit took 0.0152 seconds
# Fitted parameters for galaxy NGC3953 using lmfit:
#   M_b = 3.27e+11 solar masses
#   a   = 11.19 kpc
#   chi-squared = 189.4622
# Fitting with lmfit took 0.0146 seconds
# Fitted parameters for galaxy NGC6789 using lmfit:
#   M_b = 1.94e+10 solar masses
#   a   = 11.18 kpc
#   chi-squared = 6.1382
# Fitting with lmfit took 0.0101 seconds
# Fitted parameters for galaxy UGC07232 using lmfit:
#   M_b = 2.45e+09 solar masses
#   a   = 3.32 kpc
#   chi-squared = 6.4815
# Fitting with lmfit took 0.0137 seconds
# Fitted parameters for galaxy UGC03546 using lmfit:
#   M_b = 9.01e+10 solar masses
#   a   = 4.82 kpc
#   chi-squared = 5018.6310
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0104 seconds
# Fitted parameters for galaxy UGC03546 using lmfit:
#   M_b = 1.51e+10 solar masses
#   a   = 0.07 kpc
#   chi-squared = 197.2639
# Fitting with lmfit took 0.0079 seconds
# Fitted parameters for galaxy NGC6503 using lmfit:
#   M_b = 1.16e+10 solar masses
#   a   = 2.01 kpc
#   chi-squared = 1108.9565
# Fitting with lmfit took 0.0102 seconds
# Fitted parameters for galaxy UGC05005 using lmfit:
#   M_b = 4.49e+10 solar masses
#   a   = 26.03 kpc
#   chi-squared = 16.8740
# Fitting with lmfit took 0.0113 seconds
# Fitted parameters for galaxy UGC07690 using lmfit:
#   M_b = 1.81e+09 solar masses
#   a   = 1.36 kpc
#   chi-squared = 0.7789
# Fitting with lmfit took 0.0124 seconds
# Fitted parameters for galaxy UGC00634 using lmfit:
#   M_b = 2.53e+10 solar masses
#   a   = 14.24 kpc
#   chi-squared = 11.5347
# Fitting with lmfit took 0.0109 seconds
# Fitted parameters for galaxy DDO154 using lmfit:
#   M_b = 1.91e+09 solar masses
#   a   = 6.53 kpc
#   chi-squared = 9.4342
# Fitting with lmfit took 0.0117 seconds
# Fitted parameters for galaxy UGC07603 using lmfit:
#   M_b = 1.26e+09 solar masses
#   a   = 2.20 kpc
#   chi-squared = 25.1991
# Fitting with lmfit took 0.0162 seconds
# Fitted parameters for galaxy NGC3992 using lmfit:
#   M_b = 2.82e+11 solar masses
#   a   = 9.10 kpc
#   chi-squared = 1229.5917
# Fitting with lmfit took 0.0113 seconds
# Fitted parameters for galaxy NGC4088 using lmfit:
#   M_b = 1.57e+11 solar masses
#   a   = 7.75 kpc
#   chi-squared = 3238.9718
# Fitting with lmfit took 0.0088 seconds
# Fitted parameters for galaxy F579-V1 using lmfit:
#   M_b = 7.60e+10 solar masses
#   a   = 21.50 kpc
#   chi-squared = 67.1424
# Fitting with lmfit took 0.0081 seconds
# Fitted parameters for galaxy ESO444-G084 using lmfit:
#   M_b = 9.46e+08 solar masses
#   a   = 2.67 kpc
#   chi-squared = 36.2251
# Fitting with lmfit took 0.0210 seconds
# Fitted parameters for galaxy F565-V2 using lmfit:
#   M_b = 2.75e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 6.6409
# Fitting with lmfit took 0.0088 seconds
# Fitted parameters for galaxy UGC10310 using lmfit:
#   M_b = 1.24e+11 solar masses
#   a   = 40.32 kpc
#   chi-squared = 17.1645
# Fitting with lmfit took 0.0084 seconds
# Fitted parameters for galaxy NGC5055 using lmfit:
#   M_b = 7.57e+10 solar masses
#   a   = 3.89 kpc
#   chi-squared = 457.5369
# Fitting with lmfit took 0.0137 seconds
# Fitted parameters for galaxy NGC0801 using lmfit:
#   M_b = 3.56e+11 solar masses
#   a   = 7.33 kpc
#   chi-squared = 609.3896
# Fitting with lmfit took 0.0152 seconds
# Fitted parameters for galaxy F563-1 using lmfit:
#   M_b = 5.02e+10 solar masses
#   a   = 34.43 kpc
#   chi-squared = 13.7236
# Fitting with lmfit took 0.0173 seconds
# Fitted parameters for galaxy NGC6946 using lmfit:
#   M_b = 9.18e+10 solar masses
#   a   = 5.73 kpc
#   chi-squared = 8874.9698
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0152 seconds
# Fitted parameters for galaxy NGC6946 using lmfit:
#   M_b = 2.42e+09 solar masses
#   a   = 0.06 kpc
#   chi-squared = 50.7933
# Fitting with lmfit took 0.0151 seconds
# Fitted parameters for galaxy UGC06614 using lmfit:
#   M_b = 1.82e+11 solar masses
#   a   = 31.48 kpc
#   chi-squared = 998.0956
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0162 seconds
# Fitted parameters for galaxy UGC06614 using lmfit:
#   M_b = 5.13e+10 solar masses
#   a   = 0.82 kpc
#   chi-squared = 67.0380
# Fitting with lmfit took 0.0138 seconds
# Fitted parameters for galaxy NGC3769 using lmfit:
#   M_b = 1.84e+10 solar masses
#   a   = 2.55 kpc
#   chi-squared = 58.9953
# Fitting with lmfit took 0.0148 seconds
# Fitted parameters for galaxy NGC3917 using lmfit:
#   M_b = 1.40e+11 solar masses
#   a   = 20.71 kpc
#   chi-squared = 728.5801
# Fitting with lmfit took 0.0151 seconds
# Fitted parameters for galaxy UGC05999 using lmfit:
#   M_b = 1.56e+11 solar masses
#   a   = 51.14 kpc
#   chi-squared = 31.0632
# Fitting with lmfit took 0.0137 seconds
# Fitted parameters for galaxy NGC4085 using lmfit:
#   M_b = 5.06e+10 solar masses
#   a   = 6.13 kpc
#   chi-squared = 78.4185
# Fitting with lmfit took 0.0129 seconds
# Fitted parameters for galaxy NGC3198 using lmfit:
#   M_b = 6.44e+10 solar masses
#   a   = 8.56 kpc
#   chi-squared = 2241.9287
# Fitting with lmfit took 0.0071 seconds
# Fitted parameters for galaxy F568-3 using lmfit:
#   M_b = 2.89e+11 solar masses
#   a   = 68.75 kpc
#   chi-squared = 41.0210
# Fitting with lmfit took 0.0148 seconds
# Fitted parameters for galaxy NGC5033 using lmfit:
#   M_b = 7.23e+10 solar masses
#   a   = 4.63 kpc
#   chi-squared = 1817.1004
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0141 seconds
# Fitted parameters for galaxy NGC5033 using lmfit:
#   M_b = 1.23e+10 solar masses
#   a   = 0.31 kpc
#   chi-squared = 179.1964
# Fitting with lmfit took 0.0164 seconds
# Fitted parameters for galaxy UGC11557 using lmfit:
#   M_b = 6.83e+10 solar masses
#   a   = 14.74 kpc
#   chi-squared = 97.9973
# Fitting with lmfit took 0.0149 seconds
# Fitted parameters for galaxy UGC02885 using lmfit:
#   M_b = 5.34e+11 solar masses
#   a   = 21.74 kpc
#   chi-squared = 846.6994
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0123 seconds
# Fitted parameters for galaxy UGC02885 using lmfit:
#   M_b = 5.28e+10 solar masses
#   a   = 0.58 kpc
#   chi-squared = 384.4349
# Fitting with lmfit took 0.0300 seconds
# Fitted parameters for galaxy KK98-251 using lmfit:
#   M_b = 3.44e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 60.8464
# Fitting with lmfit took 0.0163 seconds
# Fitted parameters for galaxy NGC5907 using lmfit:
#   M_b = 2.50e+11 solar masses
#   a   = 9.78 kpc
#   chi-squared = 1374.2558
# Fitting with lmfit took 0.0120 seconds
# Fitted parameters for galaxy UGC06917 using lmfit:
#   M_b = 3.07e+10 solar masses
#   a   = 11.26 kpc
#   chi-squared = 23.9804
# Fitting with lmfit took 0.0153 seconds
# Fitted parameters for galaxy UGC09992 using lmfit:
#   M_b = 3.20e+09 solar masses
#   a   = 5.81 kpc
#   chi-squared = 0.4845
# Fitting with lmfit took 0.0144 seconds
# Fitted parameters for galaxy UGC04499 using lmfit:
#   M_b = 1.96e+10 solar masses
#   a   = 12.74 kpc
#   chi-squared = 6.8634
# Fitting with lmfit took 0.0065 seconds
# Fitted parameters for galaxy NGC0289 using lmfit:
#   M_b = 8.42e+10 solar masses
#   a   = 3.96 kpc
#   chi-squared = 1824.3613
# Fitting with lmfit took 0.0052 seconds
# Fitted parameters for galaxy UGC06983 using lmfit:
#   M_b = 2.36e+10 solar masses
#   a   = 9.66 kpc
#   chi-squared = 116.7919
# Fitting with lmfit took 0.0052 seconds
# Fitted parameters for galaxy UGC06973 using lmfit:
#   M_b = 1.52e+10 solar masses
#   a   = 0.32 kpc
#   chi-squared = 3.2071
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0076 seconds
# Fitted parameters for galaxy UGC06973 using lmfit:
#   M_b = 3.97e+09 solar masses
#   a   = 0.00 kpc
#   chi-squared = 0.0014
# Fitting with lmfit took 0.0248 seconds
# Fitted parameters for galaxy UGC02487 using lmfit:
#   M_b = 4.92e+11 solar masses
#   a   = 10.30 kpc
#   chi-squared = 1748.5493
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0111 seconds
# Fitted parameters for galaxy UGC02487 using lmfit:
#   M_b = 6.33e+10 solar masses
#   a   = 0.42 kpc
#   chi-squared = 4.1107
# Fitting with lmfit took 0.0056 seconds
# Fitted parameters for galaxy UGC09037 using lmfit:
#   M_b = 9.45e+10 solar masses
#   a   = 11.97 kpc
#   chi-squared = 88.4787
# Fitting with lmfit took 0.0057 seconds
# Fitted parameters for galaxy NGC4051 using lmfit:
#   M_b = 1.30e+11 solar masses
#   a   = 8.72 kpc
#   chi-squared = 1328.8332
# Fitting with lmfit took 0.0138 seconds
# Fitted parameters for galaxy F571-8 using lmfit:
#   M_b = 5.08e+09 solar masses
#   a   = 2.15 kpc
#   chi-squared = 251.3024
# Fitting with lmfit took 0.0106 seconds
# Fitted parameters for galaxy D564-8 using lmfit:
#   M_b = 2.67e+08 solar masses
#   a   = 3.38 kpc
#   chi-squared = 0.8115
# Fitting with lmfit took 0.0144 seconds
# Fitted parameters for galaxy UGC00891 using lmfit:
#   M_b = 5.41e+09 solar masses
#   a   = 8.76 kpc
#   chi-squared = 11.1597
# Fitting with lmfit took 0.0157 seconds
# Fitted parameters for galaxy NGC2998 using lmfit:
#   M_b = 2.34e+11 solar masses
#   a   = 11.42 kpc
#   chi-squared = 1277.9663
# Fitting with lmfit took 0.0136 seconds
# Fitted parameters for galaxy NGC0055 using lmfit:
#   M_b = 2.99e+10 solar masses
#   a   = 14.78 kpc
#   chi-squared = 82.0306
# Fitting with lmfit took 0.0158 seconds
# Fitted parameters for galaxy NGC2683 using lmfit:
#   M_b = 6.62e+10 solar masses
#   a   = 2.46 kpc
#   chi-squared = 1141.9315
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0090 seconds
# Fitted parameters for galaxy NGC2683 using lmfit:
#   M_b = 3.67e+09 solar masses
#   a   = 0.00 kpc
#   chi-squared = 0.0002
# Fitting with lmfit took 0.0253 seconds
# Fitted parameters for galaxy UGC12632 using lmfit:
#   M_b = 3.55e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 12.7752
# Fitting with lmfit took 0.0068 seconds
# Fitted parameters for galaxy F563-V2 using lmfit:
#   M_b = 3.37e+11 solar masses
#   a   = 67.57 kpc
#   chi-squared = 53.2364
# Fitting with lmfit took 0.0084 seconds
# Fitted parameters for galaxy NGC5585 using lmfit:
#   M_b = 9.11e+09 solar masses
#   a   = 5.78 kpc
#   chi-squared = 21.3499
# Fitting with lmfit took 0.0110 seconds
# Fitted parameters for galaxy NGC2976 using lmfit:
#   M_b = 4.51e+12 solar masses
#   a   = 100.00 kpc
#   chi-squared = 983.1146
# Fitting with lmfit took 0.0061 seconds
# Fitted parameters for galaxy NGC7814 using lmfit:
#   M_b = 3.66e+10 solar masses
#   a   = 5.86 kpc
#   chi-squared = 874.9286
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0058 seconds
# Fitted parameters for galaxy NGC7814 using lmfit:
#   M_b = 3.30e+10 solar masses
#   a   = 0.49 kpc
#   chi-squared = 102.3844
# Fitting with lmfit took 0.0057 seconds
# Fitted parameters for galaxy UGC05716 using lmfit:
#   M_b = 1.49e+10 solar masses
#   a   = 16.26 kpc
#   chi-squared = 16.6563
# Fitting with lmfit took 0.0057 seconds
# Fitted parameters for galaxy F571-V1 using lmfit:
#   M_b = 2.65e+10 solar masses
#   a   = 20.06 kpc
#   chi-squared = 21.4822
# Fitting with lmfit took 0.0097 seconds
# Fitted parameters for galaxy F583-1 using lmfit:
#   M_b = 2.67e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 114.4798
# Fitting with lmfit took 0.0065 seconds
# Fitted parameters for galaxy UGC11914 using lmfit:
#   M_b = 3.78e+11 solar masses
#   a   = 13.75 kpc
#   chi-squared = 5534.7927
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0051 seconds
# Fitted parameters for galaxy UGC11914 using lmfit:
#   M_b = 4.21e+10 solar masses
#   a   = 0.92 kpc
#   chi-squared = 2663.0299
# Fitting with lmfit took 0.0061 seconds
# Fitted parameters for galaxy NGC0891 using lmfit:
#   M_b = 7.19e+10 solar masses
#   a   = 4.22 kpc
#   chi-squared = 3317.3199
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0051 seconds
# Fitted parameters for galaxy NGC0891 using lmfit:
#   M_b = 1.17e+10 solar masses
#   a   = 0.18 kpc
#   chi-squared = 46.4188
# Fitting with lmfit took 0.0063 seconds
# Fitted parameters for galaxy DDO170 using lmfit:
#   M_b = 1.73e+10 solar masses
#   a   = 19.77 kpc
#   chi-squared = 23.5699
# Fitting with lmfit took 0.0056 seconds
# Fitted parameters for galaxy F568-V1 using lmfit:
#   M_b = 4.36e+10 solar masses
#   a   = 23.54 kpc
#   chi-squared = 27.1950
# Fitting with lmfit took 0.0055 seconds
# Fitted parameters for galaxy ESO079-G014 using lmfit:
#   M_b = 7.33e+11 solar masses
#   a   = 54.12 kpc
#   chi-squared = 233.6733
# Fitting with lmfit took 0.0067 seconds
# Fitted parameters for galaxy UGC06787 using lmfit:
#   M_b = 1.43e+11 solar masses
#   a   = 9.77 kpc
#   chi-squared = 13985.6105
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0055 seconds
# Fitted parameters for galaxy UGC06787 using lmfit:
#   M_b = 1.30e+10 solar masses
#   a   = 0.63 kpc
#   chi-squared = 1783.9483
# Fitting with lmfit took 0.0085 seconds
# Fitted parameters for galaxy D631-7 using lmfit:
#   M_b = 1.33e+09 solar masses
#   a   = 3.01 kpc
#   chi-squared = 46.7783
# Fitting with lmfit took 0.0064 seconds
# Fitted parameters for galaxy NGC2955 using lmfit:
#   M_b = 3.70e+11 solar masses
#   a   = 18.02 kpc
#   chi-squared = 2894.2158
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0138 seconds
# Fitted parameters for galaxy NGC2955 using lmfit:
#   M_b = 8.57e+10 solar masses
#   a   = 2.20 kpc
#   chi-squared = 5258.7695
# Fitting with lmfit took 0.0145 seconds
# Fitted parameters for galaxy UGC03580 using lmfit:
#   M_b = 2.60e+10 solar masses
#   a   = 4.51 kpc
#   chi-squared = 1975.8255
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0078 seconds
# Fitted parameters for galaxy UGC03580 using lmfit:
#   M_b = 1.45e+09 solar masses
#   a   = 0.58 kpc
#   chi-squared = 651.9128
# Fitting with lmfit took 0.0172 seconds
# Fitted parameters for galaxy NGC4100 using lmfit:
#   M_b = 7.92e+10 solar masses
#   a   = 5.46 kpc
#   chi-squared = 4402.6319
# Fitting with lmfit took 0.0182 seconds
# Fitted parameters for galaxy UGC06786 using lmfit:
#   M_b = 8.07e+10 solar masses
#   a   = 8.88 kpc
#   chi-squared = 10323.6338
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0137 seconds
# Fitted parameters for galaxy UGC06786 using lmfit:
#   M_b = 1.58e+10 solar masses
#   a   = 0.67 kpc
#   chi-squared = 1980.6879
# Fitting with lmfit took 0.0156 seconds
# Fitted parameters for galaxy UGC00128 using lmfit:
#   M_b = 6.30e+10 solar masses
#   a   = 26.44 kpc
#   chi-squared = 239.0884
# Fitting with lmfit took 0.0136 seconds
# Fitted parameters for galaxy NGC4068 using lmfit:
#   M_b = 6.47e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 11.0977
# Fitting with lmfit took 0.0117 seconds
# Fitted parameters for galaxy UGC00731 using lmfit:
#   M_b = 3.05e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 237.8894
# Fitting with lmfit took 0.0218 seconds
# Fitted parameters for galaxy UGC07608 using lmfit:
#   M_b = 3.27e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 10.5151
# Fitting with lmfit took 0.0062 seconds
# Fitted parameters for galaxy UGC05750 using lmfit:
#   M_b = 1.78e+11 solar masses
#   a   = 72.84 kpc
#   chi-squared = 58.3011
# Fitting with lmfit took 0.0060 seconds
# Fitted parameters for galaxy UGCA442 using lmfit:
#   M_b = 2.81e+09 solar masses
#   a   = 6.08 kpc
#   chi-squared = 72.2632
# Fitting with lmfit took 0.0135 seconds
# Fitted parameters for galaxy UGC04278 using lmfit:
#   M_b = 5.48e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 477.6529
# Fitting with lmfit took 0.0062 seconds
# Fitted parameters for galaxy UGC07151 using lmfit:
#   M_b = 1.51e+10 solar masses
#   a   = 6.50 kpc
#   chi-squared = 29.7413
# Fitting with lmfit took 0.0054 seconds
# Fitted parameters for galaxy NGC3972 using lmfit:
#   M_b = 1.28e+11 solar masses
#   a   = 19.36 kpc
#   chi-squared = 128.5412
# Fitting with lmfit took 0.0225 seconds
# Fitted parameters for galaxy F568-1 using lmfit:
#   M_b = 7.07e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 95.6384
# Fitting with lmfit took 0.0145 seconds
# Fitted parameters for galaxy NGC7793 using lmfit:
#   M_b = 2.30e+10 solar masses
#   a   = 4.79 kpc
#   chi-squared = 756.7556
# Fitting with lmfit took 0.0169 seconds
# Fitted parameters for galaxy NGC3877 using lmfit:
#   M_b = 4.08e+11 solar masses
#   a   = 26.21 kpc
#   chi-squared = 509.8967
# Fitting with lmfit took 0.0187 seconds
# Fitted parameters for galaxy NGC6674 using lmfit:
#   M_b = 3.80e+11 solar masses
#   a   = 10.02 kpc
#   chi-squared = 4387.5384
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0162 seconds
# Fitted parameters for galaxy NGC6674 using lmfit:
#   M_b = 1.37e+10 solar masses
#   a   = 0.01 kpc
#   chi-squared = 0.0083
# Fitting with lmfit took 0.0162 seconds
# Fitted parameters for galaxy NGC6015 using lmfit:
#   M_b = 5.90e+10 solar masses
#   a   = 5.71 kpc
#   chi-squared = 3568.4485
# Fitting with lmfit took 0.0114 seconds
# Fitted parameters for galaxy UGC12732 using lmfit:
#   M_b = 1.69e+11 solar masses
#   a   = 62.96 kpc
#   chi-squared = 100.1937
# Fitting with lmfit took 0.0083 seconds
# Fitted parameters for galaxy DDO168 using lmfit:
#   M_b = 2.79e+09 solar masses
#   a   = 4.41 kpc
#   chi-squared = 10.7754
# Fitting with lmfit took 0.0146 seconds
# Fitted parameters for galaxy NGC2903 using lmfit:
#   M_b = 4.88e+10 solar masses
#   a   = 2.26 kpc
#   chi-squared = 5102.6402
# Fitting with lmfit took 0.0140 seconds
# Fitted parameters for galaxy UGC02455 using lmfit:
#   M_b = 1.16e+10 solar masses
#   a   = 4.84 kpc
#   chi-squared = 50.1966
# Fitting with lmfit took 0.0170 seconds
# Fitted parameters for galaxy UGC02023 using lmfit:
#   M_b = 2.40e+11 solar masses
#   a   = 55.73 kpc
#   chi-squared = 18.8696
# Fitting with lmfit took 0.0244 seconds
# Fitted parameters for galaxy DDO064 using lmfit:
#   M_b = 5.33e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 82.3081
# Fitting with lmfit took 0.0158 seconds
# Fitted parameters for galaxy UGC05986 using lmfit:
#   M_b = 1.47e+10 solar masses
#   a   = 6.10 kpc
#   chi-squared = 306.1919
# Fitting with lmfit took 0.0109 seconds
# Fitted parameters for galaxy UGCA281 using lmfit:
#   M_b = 1.59e+09 solar masses
#   a   = 3.86 kpc
#   chi-squared = 14.3770
# Fitting with lmfit took 0.0125 seconds
# Fitted parameters for galaxy UGC06399 using lmfit:
#   M_b = 4.32e+10 solar masses
#   a   = 21.51 kpc
#   chi-squared = 19.0774
# Fitting with lmfit took 0.0098 seconds
# Fitted parameters for galaxy UGC09133 using lmfit:
#   M_b = 3.19e+11 solar masses
#   a   = 9.99 kpc
#   chi-squared = 21484.1253
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0069 seconds
# Fitted parameters for galaxy UGC09133 using lmfit:
#   M_b = 5.13e+10 solar masses
#   a   = 1.16 kpc
#   chi-squared = 5723.2150
# Fitting with lmfit took 0.0068 seconds
# Fitted parameters for galaxy NGC0024 using lmfit:
#   M_b = 1.27e+10 solar masses
#   a   = 3.95 kpc
#   chi-squared = 1191.6182
# Fitting with lmfit took 0.0061 seconds
# Fitted parameters for galaxy UGC08550 using lmfit:
#   M_b = 1.57e+09 solar masses
#   a   = 2.96 kpc
#   chi-squared = 50.8417
# Fitting with lmfit took 0.0067 seconds
# Fitted parameters for galaxy UGC02953 using lmfit:
#   M_b = 3.04e+11 solar masses
#   a   = 7.93 kpc
#   chi-squared = 80597.9071
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0058 seconds
# Fitted parameters for galaxy UGC02953 using lmfit:
#   M_b = 2.44e+10 solar masses
#   a   = 0.72 kpc
#   chi-squared = 13414.9275
# Fitting with lmfit took 0.0051 seconds
# Fitted parameters for galaxy NGC4138 using lmfit:
#   M_b = 2.75e+10 solar masses
#   a   = 1.12 kpc
#   chi-squared = 124.3816
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0074 seconds
# Fitted parameters for galaxy NGC4138 using lmfit:
#   M_b = 5.78e+09 solar masses
#   a   = 0.00 kpc
#   chi-squared = 0.0000
# Fitting with lmfit took 0.0059 seconds
# Fitted parameters for galaxy NGC0247 using lmfit:
#   M_b = 1.23e+11 solar masses
#   a   = 32.46 kpc
#   chi-squared = 115.2829
# Fitting with lmfit took 0.0064 seconds
# Fitted parameters for galaxy IC4202 using lmfit:
#   M_b = 9.70e+11 solar masses
#   a   = 55.38 kpc
#   chi-squared = 5419.3572
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0054 seconds
# Fitted parameters for galaxy IC4202 using lmfit:
#   M_b = 8.63e+09 solar masses
#   a   = 1.82 kpc
#   chi-squared = 400.6068
# Fitting with lmfit took 0.0057 seconds
# Fitted parameters for galaxy UGC08286 using lmfit:
#   M_b = 9.23e+09 solar masses
#   a   = 8.22 kpc
#   chi-squared = 60.5245
# Fitting with lmfit took 0.0104 seconds
# Fitted parameters for galaxy IC2574 using lmfit:
#   M_b = 2.31e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 111.2430
# Fitting with lmfit took 0.0130 seconds
# Fitted parameters for galaxy NGC4559 using lmfit:
#   M_b = 3.94e+10 solar masses
#   a   = 6.82 kpc
#   chi-squared = 222.9136
# Fitting with lmfit took 0.0111 seconds
# Fitted parameters for galaxy UGC01230 using lmfit:
#   M_b = 5.44e+10 solar masses
#   a   = 22.87 kpc
#   chi-squared = 36.7656
# Fitting with lmfit took 0.0160 seconds
# Fitted parameters for galaxy UGC07577 using lmfit:
#   M_b = 2.17e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 6.8534
# Fitting with lmfit took 0.0175 seconds
# Fitted parameters for galaxy UGC06628 using lmfit:
#   M_b = 1.62e+11 solar masses
#   a   = 43.88 kpc
#   chi-squared = 4.2518
# Fitting with lmfit took 0.0143 seconds
# Fitted parameters for galaxy NGC4013 using lmfit:
#   M_b = 4.95e+10 solar masses
#   a   = 1.02 kpc
#   chi-squared = 2227.2393
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0057 seconds
# Fitted parameters for galaxy NGC4013 using lmfit:
#   M_b = 1.27e+10 solar masses
#   a   = 0.09 kpc
#   chi-squared = 0.9426
# Fitting with lmfit took 0.0077 seconds
# Fitted parameters for galaxy UGC03205 using lmfit:
#   M_b = 1.75e+11 solar masses
#   a   = 11.70 kpc
#   chi-squared = 15404.3126
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0054 seconds
# Fitted parameters for galaxy UGC03205 using lmfit:
#   M_b = 2.02e+10 solar masses
#   a   = 1.03 kpc
#   chi-squared = 3544.7744
# Fitting with lmfit took 0.0059 seconds
# Fitted parameters for galaxy NGC7331 using lmfit:
#   M_b = 1.71e+11 solar masses
#   a   = 3.27 kpc
#   chi-squared = 1830.9461
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0095 seconds
# Fitted parameters for galaxy NGC7331 using lmfit:
#   M_b = 7.14e+09 solar masses
#   a   = 0.00 kpc
#   chi-squared = 0.0009
# Fitting with lmfit took 0.0173 seconds
# Fitted parameters for galaxy UGC02916 using lmfit:
#   M_b = 4.98e+11 solar masses
#   a   = 47.54 kpc
#   chi-squared = 1274.2318
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0155 seconds
# Fitted parameters for galaxy UGC02916 using lmfit:
#   M_b = 2.51e+10 solar masses
#   a   = 1.96 kpc
#   chi-squared = 3688.1016
# Fitting with lmfit took 0.0098 seconds
# Fitted parameters for galaxy UGC06923 using lmfit:
#   M_b = 9.17e+09 solar masses
#   a   = 4.51 kpc
#   chi-squared = 4.1813
# Fitting with lmfit took 0.0103 seconds
# Fitted parameters for galaxy UGC04483 using lmfit:
#   M_b = 7.63e+08 solar masses
#   a   = 3.34 kpc
#   chi-squared = 3.5448
# Fitting with lmfit took 0.0111 seconds
# Fitted parameters for galaxy NGC4217 using lmfit:
#   M_b = 7.72e+10 solar masses
#   a   = 14.04 kpc
#   chi-squared = 2198.8659
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0113 seconds
# Fitted parameters for galaxy NGC4217 using lmfit:
#   M_b = 2.83e+10 solar masses
#   a   = 2.28 kpc
#   chi-squared = 2501.2390
# Fitting with lmfit took 0.0138 seconds
# Fitted parameters for galaxy NGC3109 using lmfit:
#   M_b = 2.23e+10 solar masses
#   a   = 28.21 kpc
#   chi-squared = 51.0016
# Fitting with lmfit took 0.0240 seconds
# Fitted parameters for galaxy UGC05764 using lmfit:
#   M_b = 3.74e+11 solar masses
#   a   = 100.00 kpc
#   chi-squared = 25.7725
# Fitting with lmfit took 0.0067 seconds
# Fitted parameters for galaxy NGC3949 using lmfit:
#   M_b = 6.10e+10 solar masses
#   a   = 3.84 kpc
#   chi-squared = 291.9901
# Fitting with lmfit took 0.0057 seconds
# Fitted parameters for galaxy D512-2 using lmfit:
#   M_b = 1.52e+09 solar masses
#   a   = 5.51 kpc
#   chi-squared = 2.6731
# Fitting with lmfit took 0.0056 seconds
# Fitted parameters for galaxy NGC4389 using lmfit:
#   M_b = 6.45e+10 solar masses
#   a   = 8.98 kpc
#   chi-squared = 43.2716
# Fitting with lmfit took 0.0076 seconds
# Fitted parameters for galaxy NGC4157 using lmfit:
#   M_b = 1.26e+11 solar masses
#   a   = 5.43 kpc
#   chi-squared = 4698.4161
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0112 seconds
# Fitted parameters for galaxy NGC4157 using lmfit:
#   M_b = 1.31e+09 solar masses
#   a   = 0.00 kpc
#   chi-squared = 0.0001
# Fitting with lmfit took 0.0054 seconds
# Fitted parameters for galaxy DDO161 using lmfit:
#   M_b = 1.17e+10 solar masses
#   a   = 11.18 kpc
#   chi-squared = 115.4850
# Fitting complete. Results saved.
# Number of failed fits: 0

# %%
def phi(M_b, a):
    G = 4.30091e-6  # [kpc * (km/s)^2/ solar mass]

    def phi_func(r, th):
        return -G * M_b / (r + a)

    return phi_func

# %%
bulge_data = pd.read_csv(data_path + "hernquist_fits_disk_gas_bulge.csv")

bulge_ids = bulge_data["GalaxyID"].values

for bul in bulge_ids:
    sub = bulge_data[bulge_data["GalaxyID"] == bul]
    M_b_fit = sub["M_b_fit"].values[0]
    a_fit = sub["a_fit"].values[0]
    M_b_fit_bulge = sub["M_b_fit_bulge"].values[0]
    a_fit_bulge = sub["a_fit_bulge"].values[0]
    
    ri = np.geomspace(0.1, 200, 200)
    phi_dg = np.abs(np.array([phi(M_b_fit, a_fit)(r, 0) for r in ri]))
    phi_b  = np.abs(np.array([phi(M_b_fit_bulge, a_fit_bulge)(r, 0) for r in ri]))

    phi_total = phi_dg + phi_b

    percent_diff = 100 * ( np.abs((phi_total - phi_dg)) / np.abs(phi_total) )

    fig, axs = plt.subplots(2, 1, figsize=(6, 4), sharex=True, gridspec_kw={'height_ratios': [3, 1]})


    axs[0].plot(ri, phi_dg, label='Disk+Gas Potential', color='C0')
    axs[0].plot(ri, phi_b, label='Bulge Potential', color='C1')
    axs[0].plot(ri, phi_total, label='Total Baryonic Potential', color='k', linestyle='--')
    axs[0].set_ylabel('-Potential (km^2/s^2)')
    axs[0].set_title(f'Gravitational Potential for Galaxy {bul}')
    axs[0].legend(fontsize=6, loc="lower left")
    axs[0].grid()
    axs[0].set_xscale('log')
    axs[0].set_yscale('log')

    axs[1].plot(ri, percent_diff, label='Percent Difference', color='k')
    axs[1].set_xlabel('Radius (kpc)')
    axs[1].set_ylabel('Diff (%)')
    axs[1].grid()
    axs[1].set_xscale('log')
    # axs[1].set_yscale('log')

    plt.tight_layout()
    plt.savefig(plot_path + f"disk-bulge-gas/{bul}_potential_comparison.png")
    plt.close()

# %%
bulge_data.columns
# Out:
# Index(['GalaxyID', 'M_b_fit', 'a_fit', 'ChiSq', 'M_b_fit_bulge', 'a_fit_bulge',
#        'ChiSq_bulge'],
#       dtype='object')

# %%
# plot the chisqr values for disk+gas vs bulge fits
plt.figure(figsize=(6,4))

chi2 = bulge_data["ChiSq_bulge"].values
# chi2 = np.where(chi2 > 100, np.nan, chi2)  # Replace zero values with a small number for log scale

plt.hist(chi2, bins=30, color='C1', alpha=0.7)
plt.xlabel('Chi-Squared Value (Bulge Fit)')
plt.ylabel('Number of Galaxies')
plt.title('Distribution of Chi-Squared Values for Bulge Fits')
plt.grid()
# plt.xscale('log')
plt.show()

# %%
# plot Mb and a for disk gas and bulge fits
bulge_data = pd.read_csv(data_path + "hernquist_fits_disk_gas_bulge.csv")
bulge_data_log = pd.read_csv(data_path + "hernquist_fits_disk_gas_bulge_log.csv")

plt.figure(figsize=(6,4))

plt.scatter(bulge_data["M_b_fit_bulge"].values, bulge_data["a_fit_bulge"].values, color='k', marker='*', alpha=0.8)
plt.scatter(bulge_data_log["M_b_fit_bulge"].values, bulge_data_log["a_fit_bulge"].values, color='C1', alpha=0.4)
plt.xlabel('M_b_fit_bulge')
plt.ylabel('a_fit_bulge')
plt.title('M_b vs a for Bulge Fits')
plt.grid()
plt.xscale('log')
# plt.yscale('log')
plt.show()

# %%
plt.hist(bulge_data["M_b_fit_bulge"].values, bins=30, color='C0', alpha=0.7)
plt.hist(bulge_data_log["M_b_fit_bulge"].values, bins=30, color='C1', alpha=0.7)
plt.xlabel('M_b_fit_bulge')
plt.ylabel('Number of Galaxies')
plt.title('Distribution of M_b_fit_bulge')
plt.grid()
# plt.xscale('log')
plt.show()

# %%
plt.hist(bulge_data["a_fit_bulge"].values, bins=30, color='C0', alpha=0.7)
plt.hist(bulge_data_log["a_fit_bulge"].values, bins=30, color='C1', alpha=0.7)
plt.xlabel('a_fit_bulge')
plt.ylabel('Number of Galaxies')
plt.title('Distribution of a_fit_bulge')
plt.grid()
# plt.xscale('log')
plt.show()

# %%
print(len(bulge_data))
print(len(bulge_data_log))
# Out:
# 32
# 32

# %%
max_a = bulge_data["a_fit_bulge"].values.max()

gid_max_a = bulge_data[bulge_data["a_fit_bulge"] == max_a]["GalaxyID"].values[0]

print(f"Galaxy with largest a_fit_bulge: {gid_max_a} with a_fit_bulge = {max_a}")
# Out:
# Galaxy with largest a_fit_bulge: NGC4217 with a_fit_bulge = 2.2754076229727467

# %% [markdown]
# # Plot the chi squared results

# %%
plot_path = os.getcwd() + "/plots/fits/"
data_path = os.getcwd() + "/data/fit_data/"

data = pd.read_csv(os.path.join(data_path, "hern_fits.csv"))
data2 = pd.read_csv(os.path.join(data_path, "hern_fits_test.csv"))
# failed = np.loadtxt(os.path.join(data_path, "failed_fits_gamma.txt"), dtype=str).tolist()
# print("Number of galaxies with failed fits:", len(failed))

sub = data[data["ChiSq"] < 100]
sub2 = data2[data2["ChiSq"] < 100]

plt.figure(figsize=(6,4))
plt.hist(sub["ChiSq"], bins=30, color='C0', alpha=0.7, label='Old')
plt.hist(sub2["ChiSq"], bins=30, color='C1', alpha=0.7, label='New')
plt.legend()  
plt.xlabel('Reduced Chi-Squared')
plt.ylabel('Number of Galaxies')
plt.title('Distribution of Reduced Chi-Squared for Hernquist Fits')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(data["ChiSq"], bins=20, color='C0', alpha=0.7, label='With Bulge')  
plt.hist(data2["ChiSq"], bins=20, color='C1', alpha=0.7, label='Disk + Gas Only')
plt.legend()
plt.xlabel('Chi-Squared')
plt.ylabel('Number of Galaxies')
plt.title('Distribution of Chi-Squared for Hernquist Fits')
plt.grid()
plt.show()

# %%
# scatter of M_b and a fits

plt.figure(figsize=(6,4))
plt.scatter(data["M_b_fit"], data["a_fit"], color='C0', alpha=0.7, label='Old')
plt.scatter(data2["M_b_fit"], data2["a_fit"], color='C1', alpha=0.4, label='New')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Fitted Baryonic Mass M_b [solar masses]')
plt.ylabel('Fitted Scale Radius a [kpc]')
plt.title('Scatter Plot of Hernquist Fit Parameters')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Check the cluster at high mass

# %% [markdown]
# # Mass-to-Light Ratio

# %%
# path = os.getcwd() + "/data/fit_data/"

# results = []

# for galaxy_id in galaxy_ids:
#     g_disk, e_disk = Gamma_disk(galaxy_id)
#     g_bulg, e_bulg = Gamma_bulge(galaxy_id)
    
#     results.append([galaxy_id, g_disk, e_disk, g_bulg, e_bulg])
    
# results_df = pd.DataFrame(results, columns=["GalaxyID", "Gamma_disk", "Error_disk", "Gamma_bulge", "Error_bulge"])
# results_df.to_csv(os.path.join(path, "gamma_fits.csv"), index=False)

# %%
data = pd.read_csv(data_path + "gamma_fits.csv")

plt.figure(figsize=(6,4))
plt.hist(data["Gamma_disk"], bins=20, color='C0', alpha=0.7)
# plt.hist(data["Gamma_bulge"], bins=30, color='C1', alpha=0.7)
plt.xlabel('Gamma Fit Values')
plt.ylabel('Number of Galaxies')
plt.title('Distribution of Gamma Fit Values for Disk and Bulge')
plt.legend(['Gamma Disk', 'Gamma Bulge'])
plt.grid()
plt.show()

# %%
len(data)
# Out:
# 175

# %%
plt.figure(figsize=(6,4))

plt.errorbar(data["GalaxyID"].index, data["Gamma_disk"], yerr=data["Error_disk"], fmt='o', label='Gamma Disk', color='C0', alpha=0.7, zorder=3)
plt.errorbar(data["GalaxyID"].index, data["Gamma_bulge"], yerr=data["Error_bulge"], fmt='o', label='Gamma Bulge', color='C1', alpha=0.7, zorder=0)
plt.ylabel('Gamma Fit Values')
plt.xlabel('Galaxy Index')
plt.title('Gamma Disk Fit Values with Error Bars')
plt.legend()
plt.show()

# %% [markdown]
# # Compare M_b from fits and M_b from rotation curve data

# %%
hfit = pd.read_csv(data_path + "hern_fits.csv")
dfit = pd.read_csv(data_path + "dehnen_fits.csv")

results = []

for galaxy_id in galaxy_ids:
    try:
        dfh = hfit[hfit["GalaxyID"] == galaxy_id]
        dfd = dfit[dfit["GalaxyID"] == galaxy_id]
        M_b_fit_h = np.log10(dfh["M_b_fit"].values[0])
        M_b_fit_d = np.log10(dfd["M_b_fit"].values[0])
        M_b, err_Mb = get_Mb_data(galaxy_id)
        M_b = np.log10(M_b)
    except:
        continue
    
    results.append((galaxy_id, M_b_fit_h, M_b_fit_d, M_b))
    
results_df = pd.DataFrame(results, columns=["GalaxyID", "log_M_b_fit_hern", "log_M_b_fit_dehnen", "log_M_b"])
results_df.to_csv(os.path.join(data_path, "M_b_comparison.csv"), index=False)

# %%
data = pd.read_csv(os.path.join(data_path, "M_b_comparison.csv"))

idx = np.arange(len(data))

plt.figure(figsize=(12,4))
plt.scatter(idx, data["log_M_b"], label='Computed M_b', color='k', alpha=0.7)
plt.scatter(idx, data["log_M_b_fit_hern"], label='Fitted M_b_fit (Hernquist)', color='C3', alpha=0.7)
plt.scatter(idx, data["log_M_b_fit_dehnen"], label='Fitted M_b_fit (Dehnen)', color='C4', alpha=0.7)
plt.xlabel('Galaxy Index')
plt.ylabel('Log Baryonic Mass [solar masses]')
plt.title('Comparison of Computed and Fitted Baryonic Masses')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# The fitted Masses are consistently higher than the computed. This may be due to the fact that I neglected to include the bulge mass in the computed mass.

# %%
gid_bulge = []
gid_nobulge = []

for galaxy_id in galaxy_ids:
    df, _, _ = get_rc_data(galaxy_id)
    bul = df["Vbul"].values[0]
    if np.sum(bul) > 0:
        gid_bulge.append(galaxy_id)
    else:
        gid_nobulge.append(galaxy_id)
print("Galaxies with bulge:", len(gid_bulge))
print("Galaxies without bulge:", len(gid_nobulge))
# Out:
# Galaxies with bulge: 32
# Galaxies without bulge: 143

# %%
# for galaxies with bulge

data = pd.read_csv(os.path.join(data_path, "M_b_comparison.csv"))

data = data[~data["GalaxyID"].isin(gid_bulge)]

idx = np.arange(len(data))

plt.figure(figsize=(12,4))
plt.scatter(idx, data["log_M_b"], label='Computed M_b', color='k', alpha=0.7)
plt.scatter(idx, data["log_M_b_fit_hern"], label='Fitted M_b_fit (Hernquist)', color='C3', alpha=0.7)
plt.scatter(idx, data["log_M_b_fit_dehnen"], label='Fitted M_b_fit (Dehnen)', color='C4', alpha=0.7)
plt.xlabel('Galaxy Index')
plt.ylabel('Log Baryonic Mass [solar masses]')
plt.title('Computed and Fitted Baryonic Masses for Galaxies without Bulge')
plt.legend()
plt.grid()
plt.show()

# %%
# for galaxies without bulge
data = pd.read_csv(os.path.join(data_path, "M_b_comparison.csv"))

# data = data[data["GalaxyID"].isin(gid_nobulge)]

# data = data[(data["log_M_b_fit_hern"] < 13) & (data["log_M_b_fit_dehnen"] < 13)]

idx = np.arange(len(data))

plt.figure(figsize=(12,4))
plt.scatter(idx, data["log_M_b"], label='Computed M_b', color='k', alpha=0.7)
plt.scatter(idx, data["log_M_b_fit_hern"], label='Fitted M_b_fit (Hernquist)', color='C3', alpha=0.7)
plt.scatter(idx, data["log_M_b_fit_dehnen"], label='Fitted M_b_fit (Dehnen)', color='C4', alpha=0.7)
plt.xlabel('Galaxy Index')
plt.ylabel('Log Baryonic Mass [solar masses]')
plt.title('Computed and Fitted Baryonic Masses for Galaxies without Bulge')
plt.legend()
plt.grid()
plt.ylim(7,13)
plt.show()

# %% [markdown]
# Fitted M_b is systematically larger, even for galaxies without a bulge componenet.

# %% [markdown]
# # Checking new log generated data with no failed galaxies

# %%
data_path = os.getcwd() + "/data/fit_data/"

df = pd.read_csv(data_path + "hern_fits.csv")
dfd = pd.read_csv(data_path + "dehnen_fits.csv")

df.head()
# Out:
#    GalaxyID       M_b_fit       a_fit        ChiSq  M_b_fit_bulge  \
# 0   NGC5371  3.379071e+11   10.718281  5220.849667            NaN
# 1  UGC05829  4.094936e+11  100.000000   218.915833            NaN
# 2   NGC5005  3.038745e+11    7.392096  1667.229288   1.502302e+10
# 3   UGCA444  6.685526e+09   13.210223   133.680930            NaN
# 4   NGC1003  1.379919e+10    3.716879   364.923466            NaN
#
#    a_fit_bulge  ChiSq_bulge
# 0          NaN          NaN
# 1          NaN          NaN
# 2     0.407524  1970.014208
# 3          NaN          NaN
# 4          NaN          NaN

# %%
plt.figure(figsize=(6,4))

plt.scatter(df["M_b_fit"].values, df["a_fit"].values, color='C0', alpha=0.6)
plt.scatter(dfd["M_b_fit"].values, dfd["a_fit"].values, color='C1', alpha=0.6)
plt.xlabel('Fitted Baryonic Mass M_b [solar masses]')
plt.ylabel('Fitted Scale Radius a [kpc]')
plt.title('Hernquist and Dehnen Fit Parameters with Log Scale')
plt.xscale('log')
plt.yscale('log')
plt.grid()
plt.show()

# %%
data = pd.read_csv(os.path.join(data_path, "M_b_comparison.csv"))

# data = data[data['log_M_b_fit'] < 20]

idx = np.arange(len(data))

plt.figure(figsize=(12,4))
plt.scatter(idx, data["log_M_b"], label='Computed M_b', color='k', alpha=0.7)
plt.scatter(idx, data["log_M_b_fit_hern"], label='Fitted M_b_fit (Hernquist)', color='C3', alpha=0.7)
plt.scatter(idx, data["log_M_b_fit_dehnen"], label='Fitted M_b_fit (Dehnen)', color='C4', alpha=0.7)
plt.xlabel('Galaxy Index')
plt.ylabel('Log Baryonic Mass [solar masses]')
plt.title('Comparison of Computed and Fitted Baryonic Masses')
plt.legend()
plt.grid()
plt.show()

# %%
# hist of the differences between computed and fitted M_b values
data = pd.read_csv(os.path.join(data_path, "M_b_comparison.csv"))
# data = data[(data["log_M_b_fit_hern"] < 20) & (data["log_M_b_fit_dehnen"] < 20)]
print("Number of galaxies in comparison:", len(data))
data["M_b_diff_hern"] = data["log_M_b_fit_hern"] - data["log_M_b"]
data["M_b_diff_dehnen"] = data["log_M_b_fit_dehnen"] - data["log_M_b"]

plt.figure(figsize=(6,4))
plt.hist(data["M_b_diff_hern"], bins=30, color='C0', alpha=0.7, label='Hernquist')
plt.hist(data["M_b_diff_dehnen"], bins=30, color='C1', alpha=0.7, label='Dehnen')
plt.axvline(0.5, color='k', linestyle='--', label='0.5 dex')
plt.xlabel('Difference in Log Baryonic Mass (Fitted - Computed)')
plt.ylabel('Number of Galaxies')
plt.title('Log M_b differences')
plt.legend()
plt.grid()
plt.show()
# Out:
# Number of galaxies in comparison: 175

# %%
# hist of the differences between computed and fitted M_b values
data = pd.read_csv(os.path.join(data_path, "M_b_comparison.csv"))

# no bulge 

data = data[~data["GalaxyID"].isin(gid_bulge)]

data = data[(data["log_M_b_fit_hern"] < 20) & (data["log_M_b_fit_dehnen"] < 20)]
print("Number of galaxies in comparison:", len(data))
data["M_b_diff_hern"] = data["log_M_b_fit_hern"] - data["log_M_b"]
data["M_b_diff_dehnen"] = data["log_M_b_fit_dehnen"] - data["log_M_b"]

plt.figure(figsize=(6,4))
plt.hist(data["M_b_diff_hern"], bins=30, color='C0', alpha=0.5, label='Hernquist')
plt.hist(data["M_b_diff_dehnen"], bins=30, color='C1', alpha=0.5, label='Dehnen')
plt.axvline(0.5, color='k', linestyle='--', label='0.5 dex')
plt.xlabel('Difference in Log Baryonic Mass (Fitted - Computed)')
plt.ylabel('Number of Galaxies')
plt.title('Log M_b differences')
plt.legend()
plt.grid()
plt.show()
# Out:
# Number of galaxies in comparison: 143

# %%
len(data[data["M_b_diff_hern"] <= 0.5])
len(data[data["M_b_diff_dehnen"] <= 0.5])

print("Number of galaxies with Hernquist M_b fit within 0.5 dex of computed M_b:", len(data[data["M_b_diff_hern"] <= 0.5]))
print("Number of galaxies with Dehnen M_b fit within 0.5 dex of computed M_b:", len(data[data["M_b_diff_dehnen"] <= 0.5]))
# Out:
# Number of galaxies with Hernquist M_b fit within 0.5 dex of computed M_b: 68
# Number of galaxies with Dehnen M_b fit within 0.5 dex of computed M_b: 86

# %% [markdown]
# # Dehnen Fits

# %%
plot_path = os.getcwd() + "/plots/fits/"
data_path = os.getcwd() + "/data/fit_data/"

gamma_data = pd.read_csv(data_path + "gamma_fits.csv")

results = []
failed = []

for galaxy_id in galaxy_ids: 
    gamma_s, gamma_b = gamma_data[gamma_data["GalaxyID"] == galaxy_id][["Gamma_disk", "Gamma_bulge"]].values[0]
    try:
        fitter = DehnenFit(galaxy_id, gamma_star=gamma_s, gamma_bulge=gamma_b, method="lmfit")
        M_b_fit, a_fit, gamma_fit = fitter.M_b_fit, fitter.a_fit, fitter.gamma_fit
        chisqr = fitter.error
        
        M_b_fit_b, a_fit_b, gamma_fit_b = fitter.M_b_fit_bulge, fitter.a_fit_bulge, fitter.gamma_fit_bulge
        chisqr_b = fitter.error_bulge
    except Exception as e:
        failed.append(galaxy_id)
        print(f"Error fitting galaxy {galaxy_id}. Skipping...")
        continue
    
    results.append([galaxy_id, M_b_fit, a_fit, gamma_fit, chisqr, M_b_fit_b, a_fit_b, gamma_fit_b, chisqr_b])
    
    # r_vals = fitter.r_vals
    # rmax = r_vals.max() * 2 # kpc
    # ri = np.geomspace(0.1, rmax, 100)
    
    # vc_dg_data = fitter.vc_disk_gas
    # vc_bulge_data = fitter.vc_bulge
    
    # vc_dg_model = fitter.vc(ri, M_b=M_b_fit, a=a_fit, gamma=gamma_fit)
    # vc_bulge_model = fitter.vc(ri, M_b=M_b_fit_b, a=a_fit_b, gamma=gamma_fit_b)
    
    
    # plt.figure(figsize=(6,4))

    # plt.scatter(r_vals, vc_dg_data, label='Disk+Gas', color='C0', s=10)
    # plt.plot(ri, vc_dg_model, label='Disk+Gas Dehnen', color='C0', alpha=0.7)
    # plt.scatter(r_vals, vc_bulge_data, label='Bulge', color='C1', s=10)
    # plt.plot(ri, vc_bulge_model, label='Bulge Dehnen', color='C1', alpha=0.7)
    # plt.xlabel('Radius (kpc)')
    # plt.ylabel('Velocity (km/s)')
    # plt.title(f'Dehnen Fit for Galaxy {galaxy_id}')
    # plt.legend(fontsize=6, loc="lower right")
    # plt.grid()
    # # plt.savefig(plot_path + f"disk-bulge-gas/{galaxy_id}_disk_gas_bulge_fit_Dehnen.png")
    # plt.show()
    
    
results_df = pd.DataFrame(results, columns=["GalaxyID", "M_b_fit", "a_fit", "gamma_fit", "ChiSq", "M_b_fit_bulge", "a_fit_bulge", "gamma_fit_bulge", "ChiSq_bulge"])
results_df.to_csv(os.path.join(data_path, "dehnen_fits_min.csv"), index=False)
print("Fitting complete. Results saved.")
# np.savetxt(os.path.join(data_path, "dehnen-failed.txt"), failed, fmt="%s")
print("Number of failed fits:", len(failed))
# Out:
# Fitting with lmfit took 0.0160 seconds
# Fitted parameters for galaxy NGC5371 using lmfit:
#   M_b = 3.99e+11 solar masses
#   a   = 18.76 kpc
#   gamma = 1.42
#   chi-squared = 4703.1967
# Fitting with lmfit took 0.0552 seconds
# Fitted parameters for galaxy UGC05829 using lmfit:
#   M_b = 6.40e+12 solar masses
#   a   = 100.00 kpc
#   gamma = 0.12
#   chi-squared = 16.6812
# Fitting with lmfit took 0.0175 seconds
# Fitted parameters for galaxy NGC5005 using lmfit:
#   M_b = 2.05e+11 solar masses
#   a   = 2.95 kpc
#   gamma = 0.05
#   chi-squared = 364.3185
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0173 seconds
# Fitted parameters for galaxy NGC5005 using lmfit:
#   M_b = 1.49e+10 solar masses
#   a   = 0.25 kpc
#   gamma = 0.00
#   chi-squared = 1750.4356
# Fitting with lmfit took 0.0231 seconds
# Fitted parameters for galaxy UGCA444 using lmfit:
#   M_b = 9.17e+08 solar masses
#   a   = 1.95 kpc
#   gamma = 0.00
#   chi-squared = 63.4906
# Fitting with lmfit took 0.0190 seconds
# Fitted parameters for galaxy NGC1003 using lmfit:
#   M_b = 1.29e+10 solar masses
#   a   = 1.99 kpc
#   gamma = 0.00
#   chi-squared = 250.4128
# Fitting with lmfit took 0.0154 seconds
# Fitted parameters for galaxy UGC07559 using lmfit:
#   M_b = 3.76e+09 solar masses
#   a   = 6.42 kpc
#   gamma = 0.73
#   chi-squared = 1.4066
# Fitting with lmfit took 0.0297 seconds
# Fitted parameters for galaxy NGC0100 using lmfit:
#   M_b = 5.77e+09 solar masses
#   a   = 2.53 kpc
#   gamma = 0.00
#   chi-squared = 38.9536
# Fitting with lmfit took 0.0293 seconds
# Fitted parameters for galaxy UGC07261 using lmfit:
#   M_b = 5.59e+09 solar masses
#   a   = 2.40 kpc
#   gamma = 0.00
#   chi-squared = 37.4732
# Fitting with lmfit took 0.0264 seconds
# Fitted parameters for galaxy NGC6195 using lmfit:
#   M_b = 4.92e+11 solar masses
#   a   = 12.62 kpc
#   gamma = 0.00
#   chi-squared = 1540.9452
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0231 seconds
# Fitted parameters for galaxy NGC6195 using lmfit:
#   M_b = 1.06e+11 solar masses
#   a   = 1.27 kpc
#   gamma = 0.00
#   chi-squared = 884.2838
# Fitting with lmfit took 0.0212 seconds
# Fitted parameters for galaxy UGC01281 using lmfit:
#   M_b = 7.20e+09 solar masses
#   a   = 6.88 kpc
#   gamma = 0.34
#   chi-squared = 45.1141
# Fitting with lmfit took 0.0225 seconds
# Fitted parameters for galaxy UGC05414 using lmfit:
#   M_b = 6.12e+09 solar masses
#   a   = 3.18 kpc
#   gamma = 0.00
#   chi-squared = 1.7115
# Fitting with lmfit took 0.0277 seconds
# Fitted parameters for galaxy UGC08837 using lmfit:
#   M_b = 3.85e+10 solar masses
#   a   = 14.15 kpc
#   gamma = 0.39
#   chi-squared = 9.4328
# Fitting with lmfit took 0.0167 seconds
# Fitted parameters for galaxy UGC11820 using lmfit:
#   M_b = 2.94e+10 solar masses
#   a   = 22.53 kpc
#   gamma = 1.15
#   chi-squared = 48.9146
# Fitting with lmfit took 0.0413 seconds
# Fitted parameters for galaxy UGC06667 using lmfit:
#   M_b = 7.40e+10 solar masses
#   a   = 18.90 kpc
#   gamma = 0.00
#   chi-squared = 18.9733
# Fitting with lmfit took 0.0208 seconds
# Fitted parameters for galaxy NGC4183 using lmfit:
#   M_b = 2.77e+10 solar masses
#   a   = 4.57 kpc
#   gamma = 0.00
#   chi-squared = 376.7226
# Fitting with lmfit took 0.0190 seconds
# Fitted parameters for galaxy UGC08699 using lmfit:
#   M_b = 5.50e+10 solar masses
#   a   = 2.36 kpc
#   gamma = 0.00
#   chi-squared = 1612.7755
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0206 seconds
# Fitted parameters for galaxy UGC08699 using lmfit:
#   M_b = 1.11e+10 solar masses
#   a   = 0.23 kpc
#   gamma = 0.00
#   chi-squared = 4107.8148
# Fitting with lmfit took 0.0209 seconds
# Fitted parameters for galaxy F583-4 using lmfit:
#   M_b = 4.98e+09 solar masses
#   a   = 3.36 kpc
#   gamma = 0.00
#   chi-squared = 2.8298
# Fitting with lmfit took 0.0117 seconds
# Fitted parameters for galaxy UGC07399 using lmfit:
#   M_b = 6.04e+09 solar masses
#   a   = 7.34 kpc
#   gamma = 1.34
#   chi-squared = 3.8169
# Fitting with lmfit took 0.0173 seconds
# Fitted parameters for galaxy NGC2841 using lmfit:
#   M_b = 2.81e+11 solar masses
#   a   = 3.88 kpc
#   gamma = 0.00
#   chi-squared = 14809.7170
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0817 seconds
# Fitted parameters for galaxy NGC2841 using lmfit:
#   M_b = 3.89e+10 solar masses
#   a   = 0.00 kpc
#   gamma = 0.00
#   chi-squared = 0.4563
# Fitting with lmfit took 0.0257 seconds
# Fitted parameters for galaxy F567-2 using lmfit:
#   M_b = 1.48e+11 solar masses
#   a   = 100.00 kpc
#   gamma = 1.28
#   chi-squared = 22.7439
# Fitting with lmfit took 0.0125 seconds
# Fitted parameters for galaxy NGC2403 using lmfit:
#   M_b = 1.78e+10 solar masses
#   a   = 2.03 kpc
#   gamma = 0.23
#   chi-squared = 225.3074
# Fitting with lmfit took 0.0159 seconds
# Fitted parameters for galaxy NGC4010 using lmfit:
#   M_b = 3.88e+10 solar masses
#   a   = 4.53 kpc
#   gamma = 0.00
#   chi-squared = 72.0971
# Fitting with lmfit took 0.0114 seconds
# Fitted parameters for galaxy F574-1 using lmfit:
#   M_b = 9.07e+10 solar masses
#   a   = 40.34 kpc
#   gamma = 1.09
#   chi-squared = 41.6177
# Fitting with lmfit took 0.0180 seconds
# Fitted parameters for galaxy NGC0300 using lmfit:
#   M_b = 7.22e+09 solar masses
#   a   = 3.11 kpc
#   gamma = 0.12
#   chi-squared = 69.2731
# Fitting with lmfit took 0.0309 seconds
# Fitted parameters for galaxy NGC3741 using lmfit:
#   M_b = 9.37e+09 solar masses
#   a   = 100.00 kpc
#   gamma = 1.76
#   chi-squared = 9.5364
# Fitting with lmfit took 0.0169 seconds
# Fitted parameters for galaxy NGC4214 using lmfit:
#   M_b = 1.27e+09 solar masses
#   a   = 0.47 kpc
#   gamma = 0.00
#   chi-squared = 79.2965
# Fitting with lmfit took 0.0177 seconds
# Fitted parameters for galaxy PGC51017 using lmfit:
#   M_b = 5.52e+08 solar masses
#   a   = 1.03 kpc
#   gamma = 0.00
#   chi-squared = 2.4762
# Fitting with lmfit took 0.0164 seconds
# Fitted parameters for galaxy CamB using lmfit:
#   M_b = 2.78e+08 solar masses
#   a   = 1.11 kpc
#   gamma = 0.00
#   chi-squared = 4.9061
# Fitting with lmfit took 0.0197 seconds
# Fitted parameters for galaxy UGC07866 using lmfit:
#   M_b = 2.98e+09 solar masses
#   a   = 5.08 kpc
#   gamma = 0.61
#   chi-squared = 0.5360
# Fitting with lmfit took 0.0191 seconds
# Fitted parameters for galaxy F574-2 using lmfit:
#   M_b = 6.10e+11 solar masses
#   a   = 100.00 kpc
#   gamma = 0.79
#   chi-squared = 9.7869
# Fitting with lmfit took 0.0196 seconds
# Fitted parameters for galaxy NGC2915 using lmfit:
#   M_b = 1.49e+09 solar masses
#   a   = 6.51 kpc
#   gamma = 2.00
#   chi-squared = 104.3222
# Fitting with lmfit took 0.0152 seconds
# Fitted parameters for galaxy UGC08490 using lmfit:
#   M_b = 2.42e+09 solar masses
#   a   = 0.95 kpc
#   gamma = 0.00
#   chi-squared = 11.9352
# Fitting with lmfit took 0.0221 seconds
# Fitted parameters for galaxy UGC07524 using lmfit:
#   M_b = 6.42e+11 solar masses
#   a   = 100.00 kpc
#   gamma = 0.89
#   chi-squared = 47.5297
# Fitting with lmfit took 0.0117 seconds
# Fitted parameters for galaxy UGC05721 using lmfit:
#   M_b = 1.33e+09 solar masses
#   a   = 0.98 kpc
#   gamma = 0.60
#   chi-squared = 69.3113
# Fitting with lmfit took 0.0159 seconds
# Fitted parameters for galaxy ESO563-G021 using lmfit:
#   M_b = 2.74e+11 solar masses
#   a   = 11.01 kpc
#   gamma = 0.32
#   chi-squared = 1613.4901
# Fitting with lmfit took 0.0130 seconds
# Fitted parameters for galaxy UGC00191 using lmfit:
#   M_b = 1.39e+10 solar masses
#   a   = 6.65 kpc
#   gamma = 0.71
#   chi-squared = 5.2949
# Fitting with lmfit took 0.0184 seconds
# Fitted parameters for galaxy ESO116-G012 using lmfit:
#   M_b = 1.07e+10 solar masses
#   a   = 2.72 kpc
#   gamma = 0.00
#   chi-squared = 29.7863
# Fitting with lmfit took 0.0158 seconds
# Fitted parameters for galaxy NGC3521 using lmfit:
#   M_b = 7.92e+10 solar masses
#   a   = 1.56 kpc
#   gamma = 0.34
#   chi-squared = 1617.8426
# Fitting with lmfit took 0.0241 seconds
# Fitted parameters for galaxy NGC5985 using lmfit:
#   M_b = 2.62e+11 solar masses
#   a   = 11.25 kpc
#   gamma = 0.00
#   chi-squared = 713.8108
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0247 seconds
# Fitted parameters for galaxy NGC5985 using lmfit:
#   M_b = 7.36e+09 solar masses
#   a   = 0.00 kpc
#   gamma = 0.00
#   chi-squared = 0.0039
# Fitting with lmfit took 0.0115 seconds
# Fitted parameters for galaxy UGC05918 using lmfit:
#   M_b = 1.24e+10 solar masses
#   a   = 12.67 kpc
#   gamma = 0.46
#   chi-squared = 3.4239
# Fitting with lmfit took 0.0123 seconds
# Fitted parameters for galaxy UGC06930 using lmfit:
#   M_b = 5.07e+10 solar masses
#   a   = 16.92 kpc
#   gamma = 1.07
#   chi-squared = 52.4085
# Fitting with lmfit took 0.0129 seconds
# Fitted parameters for galaxy NGC1090 using lmfit:
#   M_b = 9.19e+10 solar masses
#   a   = 5.26 kpc
#   gamma = 0.51
#   chi-squared = 309.6986
# Fitting with lmfit took 0.0173 seconds
# Fitted parameters for galaxy UGC07323 using lmfit:
#   M_b = 1.21e+11 solar masses
#   a   = 21.59 kpc
#   gamma = 0.76
#   chi-squared = 6.1408
# Fitting with lmfit took 0.0384 seconds
# Fitted parameters for galaxy UGC07125 using lmfit:
#   M_b = 1.54e+11 solar masses
#   a   = 100.00 kpc
#   gamma = 1.41
#   chi-squared = 78.8711
# Fitting with lmfit took 0.0256 seconds
# Fitted parameters for galaxy UGC02259 using lmfit:
#   M_b = 7.51e+09 solar masses
#   a   = 3.65 kpc
#   gamma = 0.00
#   chi-squared = 3.7871
# Fitting with lmfit took 0.0129 seconds
# Fitted parameters for galaxy NGC3893 using lmfit:
#   M_b = 5.02e+10 solar masses
#   a   = 1.50 kpc
#   gamma = 0.00
#   chi-squared = 82.3491
# Fitting with lmfit took 0.0204 seconds
# Fitted parameters for galaxy NGC3726 using lmfit:
#   M_b = 9.58e+10 solar masses
#   a   = 3.63 kpc
#   gamma = 0.00
#   chi-squared = 856.6672
# Fitting with lmfit took 0.0165 seconds
# Fitted parameters for galaxy NGC2366 using lmfit:
#   M_b = 4.24e+09 solar masses
#   a   = 3.40 kpc
#   gamma = 0.00
#   chi-squared = 3.3910
# Fitting with lmfit took 0.0255 seconds
# Fitted parameters for galaxy UGC04325 using lmfit:
#   M_b = 1.56e+10 solar masses
#   a   = 4.40 kpc
#   gamma = 0.00
#   chi-squared = 17.9875
# Fitting with lmfit took 0.0157 seconds
# Fitted parameters for galaxy UGC12506 using lmfit:
#   M_b = 2.38e+11 solar masses
#   a   = 9.50 kpc
#   gamma = 0.00
#   chi-squared = 380.1084
# Fitting with lmfit took 0.0178 seconds
# Fitted parameters for galaxy UGC11455 using lmfit:
#   M_b = 4.26e+11 solar masses
#   a   = 7.70 kpc
#   gamma = 0.00
#   chi-squared = 6682.9516
# Fitting with lmfit took 0.0114 seconds
# Fitted parameters for galaxy NGC1705 using lmfit:
#   M_b = 7.28e+08 solar masses
#   a   = 0.34 kpc
#   gamma = 0.00
#   chi-squared = 32.0012
# Fitting with lmfit took 0.0307 seconds
# Fitted parameters for galaxy F563-V1 using lmfit:
#   M_b = 1.09e+10 solar masses
#   a   = 8.17 kpc
#   gamma = 0.00
#   chi-squared = 3.2210
# Fitting with lmfit took 0.0442 seconds
# Fitted parameters for galaxy F561-1 using lmfit:
#   M_b = 5.76e+11 solar masses
#   a   = 100.00 kpc
#   gamma = 1.01
#   chi-squared = 5.9296
# Fitting with lmfit took 0.0173 seconds
# Fitted parameters for galaxy UGC06818 using lmfit:
#   M_b = 5.11e+09 solar masses
#   a   = 4.90 kpc
#   gamma = 0.73
#   chi-squared = 2.0623
# Fitting with lmfit took 0.0250 seconds
# Fitted parameters for galaxy UGC07089 using lmfit:
#   M_b = 1.31e+10 solar masses
#   a   = 4.79 kpc
#   gamma = 0.00
#   chi-squared = 3.6920
# Fitting with lmfit took 0.0153 seconds
# Fitted parameters for galaxy UGC05253 using lmfit:
#   M_b = 9.21e+10 solar masses
#   a   = 6.00 kpc
#   gamma = 0.00
#   chi-squared = 732.8428
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0144 seconds
# Fitted parameters for galaxy UGC05253 using lmfit:
#   M_b = 7.73e+10 solar masses
#   a   = 1.02 kpc
#   gamma = 0.82
#   chi-squared = 4992.5321
# Fitting with lmfit took 0.0195 seconds
# Fitted parameters for galaxy UGC04305 using lmfit:
#   M_b = 7.41e+09 solar masses
#   a   = 3.95 kpc
#   gamma = 0.13
#   chi-squared = 38.9377
# Fitting with lmfit took 0.0167 seconds
# Fitted parameters for galaxy UGC06446 using lmfit:
#   M_b = 8.64e+10 solar masses
#   a   = 55.65 kpc
#   gamma = 1.28
#   chi-squared = 35.7310
# Fitting with lmfit took 0.0242 seconds
# Fitted parameters for galaxy NGC3953 using lmfit:
#   M_b = 2.61e+11 solar masses
#   a   = 5.98 kpc
#   gamma = 0.31
#   chi-squared = 165.5246
# Fitting with lmfit took 0.0180 seconds
# Fitted parameters for galaxy NGC6789 using lmfit:
#   M_b = 4.73e+08 solar masses
#   a   = 0.66 kpc
#   gamma = 0.00
#   chi-squared = 0.7851
# Fitting with lmfit took 0.0189 seconds
# Fitted parameters for galaxy UGC07232 using lmfit:
#   M_b = 5.45e+08 solar masses
#   a   = 0.65 kpc
#   gamma = 0.00
#   chi-squared = 2.7557
# Fitting with lmfit took 0.0235 seconds
# Fitted parameters for galaxy UGC03546 using lmfit:
#   M_b = 7.71e+10 solar masses
#   a   = 2.23 kpc
#   gamma = 0.00
#   chi-squared = 1997.0960
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0180 seconds
# Fitted parameters for galaxy UGC03546 using lmfit:
#   M_b = 1.51e+10 solar masses
#   a   = 0.05 kpc
#   gamma = 0.00
#   chi-squared = 193.7559
# Fitting with lmfit took 0.0158 seconds
# Fitted parameters for galaxy NGC6503 using lmfit:
#   M_b = 1.10e+10 solar masses
#   a   = 1.10 kpc
#   gamma = 0.00
#   chi-squared = 799.9838
# Fitting with lmfit took 0.0223 seconds
# Fitted parameters for galaxy UGC05005 using lmfit:
#   M_b = 3.32e+10 solar masses
#   a   = 16.05 kpc
#   gamma = 0.68
#   chi-squared = 7.8951
# Fitting with lmfit took 0.0101 seconds
# Fitted parameters for galaxy UGC07690 using lmfit:
#   M_b = 1.68e+09 solar masses
#   a   = 0.99 kpc
#   gamma = 0.63
#   chi-squared = 0.4555
# Fitting with lmfit took 0.0161 seconds
# Fitted parameters for galaxy UGC00634 using lmfit:
#   M_b = 1.87e+10 solar masses
#   a   = 6.16 kpc
#   gamma = 0.00
#   chi-squared = 6.6425
# Fitting with lmfit took 0.0149 seconds
# Fitted parameters for galaxy DDO154 using lmfit:
#   M_b = 1.13e+09 solar masses
#   a   = 2.56 kpc
#   gamma = 0.19
#   chi-squared = 5.8240
# Fitting with lmfit took 0.0162 seconds
# Fitted parameters for galaxy UGC07603 using lmfit:
#   M_b = 9.50e+08 solar masses
#   a   = 0.94 kpc
#   gamma = 0.00
#   chi-squared = 12.7812
# Fitting with lmfit took 0.0296 seconds
# Fitted parameters for galaxy NGC3992 using lmfit:
#   M_b = 2.71e+11 solar masses
#   a   = 5.28 kpc
#   gamma = 0.00
#   chi-squared = 1099.1861
# Fitting with lmfit took 0.0206 seconds
# Fitted parameters for galaxy NGC4088 using lmfit:
#   M_b = 1.33e+11 solar masses
#   a   = 3.71 kpc
#   gamma = 0.00
#   chi-squared = 2262.6567
# Fitting with lmfit took 0.0144 seconds
# Fitted parameters for galaxy F579-V1 using lmfit:
#   M_b = 4.19e+10 solar masses
#   a   = 9.78 kpc
#   gamma = 0.52
#   chi-squared = 28.1377
# Fitting with lmfit took 0.0131 seconds
# Fitted parameters for galaxy ESO444-G084 using lmfit:
#   M_b = 6.69e+08 solar masses
#   a   = 1.07 kpc
#   gamma = 0.00
#   chi-squared = 17.2702
# Fitting with lmfit took 0.0164 seconds
# Fitted parameters for galaxy F565-V2 using lmfit:
#   M_b = 7.02e+10 solar masses
#   a   = 31.95 kpc
#   gamma = 0.64
#   chi-squared = 1.2465
# Fitting with lmfit took 0.0121 seconds
# Fitted parameters for galaxy UGC10310 using lmfit:
#   M_b = 1.88e+10 solar masses
#   a   = 6.98 kpc
#   gamma = 0.17
#   chi-squared = 7.7452
# Fitting with lmfit took 0.0278 seconds
# Fitted parameters for galaxy NGC5055 using lmfit:
#   M_b = 7.32e+10 solar masses
#   a   = 3.13 kpc
#   gamma = 0.74
#   chi-squared = 403.2596
# Fitting with lmfit took 0.0132 seconds
# Fitted parameters for galaxy NGC0801 using lmfit:
#   M_b = 3.37e+11 solar masses
#   a   = 5.60 kpc
#   gamma = 0.73
#   chi-squared = 536.0744
# Fitting with lmfit took 0.0258 seconds
# Fitted parameters for galaxy F563-1 using lmfit:
#   M_b = 5.53e+10 solar masses
#   a   = 38.00 kpc
#   gamma = 1.03
#   chi-squared = 13.6038
# Fitting with lmfit took 0.0214 seconds
# Fitted parameters for galaxy NGC6946 using lmfit:
#   M_b = 7.74e+10 solar masses
#   a   = 2.68 kpc
#   gamma = 0.00
#   chi-squared = 4425.6781
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0227 seconds
# Fitted parameters for galaxy NGC6946 using lmfit:
#   M_b = 2.42e+09 solar masses
#   a   = 0.04 kpc
#   gamma = 0.00
#   chi-squared = 45.8649
# Fitting with lmfit took 0.0261 seconds
# Fitted parameters for galaxy UGC06614 using lmfit:
#   M_b = 1.33e+11 solar masses
#   a   = 13.14 kpc
#   gamma = 0.00
#   chi-squared = 633.1335
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0255 seconds
# Fitted parameters for galaxy UGC06614 using lmfit:
#   M_b = 5.12e+10 solar masses
#   a   = 0.53 kpc
#   gamma = 0.00
#   chi-squared = 63.2757
# Fitting with lmfit took 0.0227 seconds
# Fitted parameters for galaxy NGC3769 using lmfit:
#   M_b = 1.75e+10 solar masses
#   a   = 1.42 kpc
#   gamma = 0.00
#   chi-squared = 38.9287
# Fitting with lmfit took 0.0182 seconds
# Fitted parameters for galaxy NGC3917 using lmfit:
#   M_b = 6.82e+10 solar masses
#   a   = 6.47 kpc
#   gamma = 0.00
#   chi-squared = 347.6404
# Fitting with lmfit took 0.0235 seconds
# Fitted parameters for galaxy UGC05999 using lmfit:
#   M_b = 3.27e+11 solar masses
#   a   = 100.00 kpc
#   gamma = 1.18
#   chi-squared = 26.7043
# Fitting with lmfit took 0.0192 seconds
# Fitted parameters for galaxy NGC4085 using lmfit:
#   M_b = 3.08e+10 solar masses
#   a   = 2.25 kpc
#   gamma = 0.00
#   chi-squared = 33.7013
# Fitting with lmfit took 0.0099 seconds
# Fitted parameters for galaxy NGC3198 using lmfit:
#   M_b = 6.13e+10 solar masses
#   a   = 7.15 kpc
#   gamma = 0.83
#   chi-squared = 2189.8475
# Fitting with lmfit took 0.0227 seconds
# Fitted parameters for galaxy F568-3 using lmfit:
#   M_b = 7.18e+10 solar masses
#   a   = 19.46 kpc
#   gamma = 0.52
#   chi-squared = 4.9038
# Fitting with lmfit took 0.0293 seconds
# Fitted parameters for galaxy NGC5033 using lmfit:
#   M_b = 6.51e+10 solar masses
#   a   = 2.27 kpc
#   gamma = 0.00
#   chi-squared = 933.7743
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0203 seconds
# Fitted parameters for galaxy NGC5033 using lmfit:
#   M_b = 1.23e+10 solar masses
#   a   = 0.19 kpc
#   gamma = 0.00
#   chi-squared = 165.8042
# Fitting with lmfit took 0.0135 seconds
# Fitted parameters for galaxy UGC11557 using lmfit:
#   M_b = 3.62e+10 solar masses
#   a   = 6.11 kpc
#   gamma = 0.42
#   chi-squared = 33.1985
# Fitting with lmfit took 0.0108 seconds
# Fitted parameters for galaxy UGC02885 using lmfit:
#   M_b = 4.30e+11 solar masses
#   a   = 10.44 kpc
#   gamma = 0.21
#   chi-squared = 269.3652
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0199 seconds
# Fitted parameters for galaxy UGC02885 using lmfit:
#   M_b = 5.27e+10 solar masses
#   a   = 0.37 kpc
#   gamma = 0.00
#   chi-squared = 358.2697
# Fitting with lmfit took 0.0234 seconds
# Fitted parameters for galaxy KK98-251 using lmfit:
#   M_b = 5.02e+09 solar masses
#   a   = 4.52 kpc
#   gamma = 0.00
#   chi-squared = 17.2213
# Fitting with lmfit took 0.0187 seconds
# Fitted parameters for galaxy NGC5907 using lmfit:
#   M_b = 2.33e+11 solar masses
#   a   = 5.33 kpc
#   gamma = 0.00
#   chi-squared = 926.3546
# Fitting with lmfit took 0.0517 seconds
# Fitted parameters for galaxy UGC06917 using lmfit:
#   M_b = 2.29e+11 solar masses
#   a   = 100.00 kpc
#   gamma = 1.55
#   chi-squared = 4.4518
# Fitting with lmfit took 0.0152 seconds
# Fitted parameters for galaxy UGC09992 using lmfit:
#   M_b = 3.29e+09 solar masses
#   a   = 6.02 kpc
#   gamma = 1.02
#   chi-squared = 0.4836
# Fitting with lmfit took 0.0121 seconds
# Fitted parameters for galaxy UGC04499 using lmfit:
#   M_b = 2.24e+10 solar masses
#   a   = 14.91 kpc
#   gamma = 1.06
#   chi-squared = 6.7306
# Fitting with lmfit took 0.0329 seconds
# Fitted parameters for galaxy NGC0289 using lmfit:
#   M_b = 8.77e+10 solar masses
#   a   = 5.45 kpc
#   gamma = 1.33
#   chi-squared = 1798.2858
# Fitting with lmfit took 0.0379 seconds
# Fitted parameters for galaxy UGC06983 using lmfit:
#   M_b = 1.26e+11 solar masses
#   a   = 100.00 kpc
#   gamma = 1.72
#   chi-squared = 42.2779
# Fitting with lmfit took 0.0321 seconds
# Fitted parameters for galaxy UGC06973 using lmfit:
#   M_b = 1.51e+10 solar masses
#   a   = 0.21 kpc
#   gamma = 0.00
#   chi-squared = 3.1794
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0532 seconds
# Fitted parameters for galaxy UGC06973 using lmfit:
#   M_b = 3.97e+09 solar masses
#   a   = 0.00 kpc
#   gamma = 2.00
#   chi-squared = 0.0013
# Fitting with lmfit took 0.0300 seconds
# Fitted parameters for galaxy UGC02487 using lmfit:
#   M_b = 4.74e+11 solar masses
#   a   = 5.92 kpc
#   gamma = 0.00
#   chi-squared = 1441.7015
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0296 seconds
# Fitted parameters for galaxy UGC02487 using lmfit:
#   M_b = 6.33e+10 solar masses
#   a   = 0.28 kpc
#   gamma = 0.00
#   chi-squared = 4.0808
# Fitting with lmfit took 0.0203 seconds
# Fitted parameters for galaxy UGC09037 using lmfit:
#   M_b = 1.03e+11 solar masses
#   a   = 15.06 kpc
#   gamma = 1.18
#   chi-squared = 81.2801
# Fitting with lmfit took 0.0265 seconds
# Fitted parameters for galaxy NGC4051 using lmfit:
#   M_b = 8.13e+11 solar masses
#   a   = 100.00 kpc
#   gamma = 1.71
#   chi-squared = 902.0945
# Fitting with lmfit took 0.0150 seconds
# Fitted parameters for galaxy F571-8 using lmfit:
#   M_b = 4.33e+09 solar masses
#   a   = 0.99 kpc
#   gamma = 0.00
#   chi-squared = 88.4756
# Fitting with lmfit took 0.0224 seconds
# Fitted parameters for galaxy D564-8 using lmfit:
#   M_b = 1.59e+08 solar masses
#   a   = 1.22 kpc
#   gamma = 0.00
#   chi-squared = 0.1554
# Fitting with lmfit took 0.0223 seconds
# Fitted parameters for galaxy UGC00891 using lmfit:
#   M_b = 3.24e+09 solar masses
#   a   = 3.20 kpc
#   gamma = 0.00
#   chi-squared = 5.5271
# Fitting with lmfit took 0.0195 seconds
# Fitted parameters for galaxy NGC2998 using lmfit:
#   M_b = 1.81e+11 solar masses
#   a   = 4.68 kpc
#   gamma = 0.02
#   chi-squared = 238.3914
# Fitting with lmfit took 0.0249 seconds
# Fitted parameters for galaxy NGC0055 using lmfit:
#   M_b = 1.70e+10 solar masses
#   a   = 5.15 kpc
#   gamma = 0.00
#   chi-squared = 23.3896
# Fitting with lmfit took 0.0212 seconds
# Fitted parameters for galaxy NGC2683 using lmfit:
#   M_b = 6.52e+10 solar masses
#   a   = 1.48 kpc
#   gamma = 0.00
#   chi-squared = 1019.7621
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0384 seconds
# Fitted parameters for galaxy NGC2683 using lmfit:
#   M_b = 3.67e+09 solar masses
#   a   = 0.00 kpc
#   gamma = 0.00
#   chi-squared = 0.0002
# Fitting with lmfit took 0.0356 seconds
# Fitted parameters for galaxy UGC12632 using lmfit:
#   M_b = 3.88e+11 solar masses
#   a   = 100.00 kpc
#   gamma = 0.97
#   chi-squared = 12.1647
# Fitting with lmfit took 0.0250 seconds
# Fitted parameters for galaxy F563-V2 using lmfit:
#   M_b = 3.11e+10 solar masses
#   a   = 8.75 kpc
#   gamma = 0.21
#   chi-squared = 15.2724
# Fitting with lmfit took 0.0127 seconds
# Fitted parameters for galaxy NGC5585 using lmfit:
#   M_b = 9.87e+09 solar masses
#   a   = 6.68 kpc
#   gamma = 1.08
#   chi-squared = 19.1213
# Fitting with lmfit took 0.0246 seconds
# Fitted parameters for galaxy NGC2976 using lmfit:
#   M_b = 6.90e+10 solar masses
#   a   = 4.47 kpc
#   gamma = 0.00
#   chi-squared = 300.0968
# Fitting with lmfit took 0.0180 seconds
# Fitted parameters for galaxy NGC7814 using lmfit:
#   M_b = 3.04e+10 solar masses
#   a   = 2.69 kpc
#   gamma = 0.00
#   chi-squared = 325.8748
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0207 seconds
# Fitted parameters for galaxy NGC7814 using lmfit:
#   M_b = 3.25e+10 solar masses
#   a   = 0.29 kpc
#   gamma = 0.00
#   chi-squared = 61.4022
# Fitting with lmfit took 0.0181 seconds
# Fitted parameters for galaxy UGC05716 using lmfit:
#   M_b = 3.42e+10 solar masses
#   a   = 40.45 kpc
#   gamma = 1.30
#   chi-squared = 13.0579
# Fitting with lmfit took 0.0218 seconds
# Fitted parameters for galaxy F571-V1 using lmfit:
#   M_b = 1.29e+10 solar masses
#   a   = 6.29 kpc
#   gamma = 0.00
#   chi-squared = 9.2669
# Fitting with lmfit took 0.0224 seconds
# Fitted parameters for galaxy F583-1 using lmfit:
#   M_b = 5.05e+11 solar masses
#   a   = 100.00 kpc
#   gamma = 0.77
#   chi-squared = 50.4254
# Fitting with lmfit took 0.0215 seconds
# Fitted parameters for galaxy UGC11914 using lmfit:
#   M_b = 1.44e+11 solar masses
#   a   = 3.64 kpc
#   gamma = 0.00
#   chi-squared = 631.5657
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0151 seconds
# Fitted parameters for galaxy UGC11914 using lmfit:
#   M_b = 3.95e+10 solar masses
#   a   = 0.54 kpc
#   gamma = 0.20
#   chi-squared = 2038.7972
# Fitting with lmfit took 0.0210 seconds
# Fitted parameters for galaxy NGC0891 using lmfit:
#   M_b = 6.33e+10 solar masses
#   a   = 2.09 kpc
#   gamma = 0.00
#   chi-squared = 1995.2158
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0169 seconds
# Fitted parameters for galaxy NGC0891 using lmfit:
#   M_b = 1.17e+10 solar masses
#   a   = 0.11 kpc
#   gamma = 0.00
#   chi-squared = 44.4902
# Fitting with lmfit took 0.0757 seconds
# Fitted parameters for galaxy DDO170 using lmfit:
#   M_b = 8.27e+09 solar masses
#   a   = 6.15 kpc
#   gamma = 0.00
#   chi-squared = 11.8789
# Fitting with lmfit took 0.0192 seconds
# Fitted parameters for galaxy F568-V1 using lmfit:
#   M_b = 4.28e+10 solar masses
#   a   = 23.04 kpc
#   gamma = 0.99
#   chi-squared = 27.1820
# Fitting with lmfit took 0.0180 seconds
# Fitted parameters for galaxy ESO079-G014 using lmfit:
#   M_b = 9.33e+11 solar masses
#   a   = 65.66 kpc
#   gamma = 1.04
#   chi-squared = 232.0457
# Fitting with lmfit took 0.0121 seconds
# Fitted parameters for galaxy UGC06787 using lmfit:
#   M_b = 1.09e+11 solar masses
#   a   = 4.07 kpc
#   gamma = 0.00
#   chi-squared = 3655.5066
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0111 seconds
# Fitted parameters for galaxy UGC06787 using lmfit:
#   M_b = 1.23e+10 solar masses
#   a   = 0.34 kpc
#   gamma = 0.00
#   chi-squared = 709.0039
# Fitting with lmfit took 0.0128 seconds
# Fitted parameters for galaxy D631-7 using lmfit:
#   M_b = 1.07e+09 solar masses
#   a   = 1.35 kpc
#   gamma = 0.00
#   chi-squared = 19.6850
# Fitting with lmfit took 0.0250 seconds
# Fitted parameters for galaxy NGC2955 using lmfit:
#   M_b = 2.51e+11 solar masses
#   a   = 7.02 kpc
#   gamma = 0.00
#   chi-squared = 510.3358
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0188 seconds
# Fitted parameters for galaxy NGC2955 using lmfit:
#   M_b = 8.10e+10 solar masses
#   a   = 1.19 kpc
#   gamma = 0.00
#   chi-squared = 3511.0579
# Fitting with lmfit took 0.0197 seconds
# Fitted parameters for galaxy UGC03580 using lmfit:
#   M_b = 2.08e+10 solar masses
#   a   = 1.96 kpc
#   gamma = 0.00
#   chi-squared = 320.7140
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0175 seconds
# Fitted parameters for galaxy UGC03580 using lmfit:
#   M_b = 1.35e+09 solar masses
#   a   = 0.31 kpc
#   gamma = 0.00
#   chi-squared = 355.6662
# Fitting with lmfit took 0.0184 seconds
# Fitted parameters for galaxy NGC4100 using lmfit:
#   M_b = 7.40e+10 solar masses
#   a   = 2.98 kpc
#   gamma = 0.00
#   chi-squared = 3751.7463
# Fitting with lmfit took 0.0178 seconds
# Fitted parameters for galaxy UGC06786 using lmfit:
#   M_b = 6.49e+10 solar masses
#   a   = 3.98 kpc
#   gamma = 0.00
#   chi-squared = 4995.1556
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0176 seconds
# Fitted parameters for galaxy UGC06786 using lmfit:
#   M_b = 1.51e+10 solar masses
#   a   = 0.35 kpc
#   gamma = 0.00
#   chi-squared = 790.9603
# Fitting with lmfit took 0.0136 seconds
# Fitted parameters for galaxy UGC00128 using lmfit:
#   M_b = 6.00e+10 solar masses
#   a   = 23.57 kpc
#   gamma = 0.91
#   chi-squared = 237.0985
# Fitting with lmfit took 0.0180 seconds
# Fitted parameters for galaxy NGC4068 using lmfit:
#   M_b = 5.90e+09 solar masses
#   a   = 3.88 kpc
#   gamma = 0.12
#   chi-squared = 0.4275
# Fitting with lmfit took 0.0488 seconds
# Fitted parameters for galaxy UGC00731 using lmfit:
#   M_b = 2.46e+12 solar masses
#   a   = 100.00 kpc
#   gamma = 0.23
#   chi-squared = 36.0904
# Fitting with lmfit took 0.0358 seconds
# Fitted parameters for galaxy UGC07608 using lmfit:
#   M_b = 7.85e+11 solar masses
#   a   = 100.00 kpc
#   gamma = 0.75
#   chi-squared = 1.9852
# Fitting with lmfit took 0.0178 seconds
# Fitted parameters for galaxy UGC05750 using lmfit:
#   M_b = 4.13e+10 solar masses
#   a   = 16.11 kpc
#   gamma = 0.22
#   chi-squared = 16.8673
# Fitting with lmfit took 0.0150 seconds
# Fitted parameters for galaxy UGCA442 using lmfit:
#   M_b = 1.71e+09 solar masses
#   a   = 2.19 kpc
#   gamma = 0.00
#   chi-squared = 39.0414
# Fitting with lmfit took 0.0224 seconds
# Fitted parameters for galaxy UGC04278 using lmfit:
#   M_b = 7.24e+11 solar masses
#   a   = 100.00 kpc
#   gamma = 0.91
#   chi-squared = 470.1683
# Fitting with lmfit took 0.0110 seconds
# Fitted parameters for galaxy UGC07151 using lmfit:
#   M_b = 9.11e+09 solar masses
#   a   = 2.91 kpc
#   gamma = 0.40
#   chi-squared = 17.4923
# Fitting with lmfit took 0.0092 seconds
# Fitted parameters for galaxy NGC3972 using lmfit:
#   M_b = 6.61e+10 solar masses
#   a   = 9.09 kpc
#   gamma = 0.61
#   chi-squared = 110.3128
# Fitting with lmfit took 0.0315 seconds
# Fitted parameters for galaxy F568-1 using lmfit:
#   M_b = 1.05e+12 solar masses
#   a   = 100.00 kpc
#   gamma = 0.85
#   chi-squared = 69.9388
# Fitting with lmfit took 0.0157 seconds
# Fitted parameters for galaxy NGC7793 using lmfit:
#   M_b = 1.65e+10 solar masses
#   a   = 2.64 kpc
#   gamma = 0.58
#   chi-squared = 499.4381
# Fitting with lmfit took 0.0443 seconds
# Fitted parameters for galaxy NGC3877 using lmfit:
#   M_b = 1.88e+12 solar masses
#   a   = 93.56 kpc
#   gamma = 1.25
#   chi-squared = 464.1855
# Fitting with lmfit took 0.0207 seconds
# Fitted parameters for galaxy NGC6674 using lmfit:
#   M_b = 3.48e+11 solar masses
#   a   = 5.10 kpc
#   gamma = 0.00
#   chi-squared = 2362.7809
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0193 seconds
# Fitted parameters for galaxy NGC6674 using lmfit:
#   M_b = 1.37e+10 solar masses
#   a   = 0.01 kpc
#   gamma = 0.00
#   chi-squared = 0.0082
# Fitting with lmfit took 0.0266 seconds
# Fitted parameters for galaxy NGC6015 using lmfit:
#   M_b = 5.11e+10 solar masses
#   a   = 2.71 kpc
#   gamma = 0.00
#   chi-squared = 1755.6668
# Fitting with lmfit took 0.0296 seconds
# Fitted parameters for galaxy UGC12732 using lmfit:
#   M_b = 2.68e+11 solar masses
#   a   = 100.00 kpc
#   gamma = 1.15
#   chi-squared = 83.7733
# Fitting with lmfit took 0.0276 seconds
# Fitted parameters for galaxy DDO168 using lmfit:
#   M_b = 1.56e+09 solar masses
#   a   = 1.51 kpc
#   gamma = 0.00
#   chi-squared = 3.2086
# Fitting with lmfit took 0.0262 seconds
# Fitted parameters for galaxy NGC2903 using lmfit:
#   M_b = 4.70e+10 solar masses
#   a   = 1.75 kpc
#   gamma = 0.69
#   chi-squared = 4957.2632
# Fitting with lmfit took 0.0224 seconds
# Fitted parameters for galaxy UGC02455 using lmfit:
#   M_b = 6.29e+09 solar masses
#   a   = 1.63 kpc
#   gamma = 0.00
#   chi-squared = 12.3043
# Fitting with lmfit took 0.0352 seconds
# Fitted parameters for galaxy UGC02023 using lmfit:
#   M_b = 7.33e+09 solar masses
#   a   = 3.74 kpc
#   gamma = 0.00
#   chi-squared = 6.3417
# Fitting with lmfit took 0.0315 seconds
# Fitted parameters for galaxy DDO064 using lmfit:
#   M_b = 1.31e+10 solar masses
#   a   = 5.75 kpc
#   gamma = 0.00
#   chi-squared = 18.8192
# Fitting with lmfit took 0.0309 seconds
# Fitted parameters for galaxy UGC05986 using lmfit:
#   M_b = 1.05e+10 solar masses
#   a   = 2.50 kpc
#   gamma = 0.00
#   chi-squared = 175.4888
# Fitting with lmfit took 0.0277 seconds
# Fitted parameters for galaxy UGCA281 using lmfit:
#   M_b = 3.27e+08 solar masses
#   a   = 0.71 kpc
#   gamma = 0.00
#   chi-squared = 3.6726
# Fitting with lmfit took 0.0171 seconds
# Fitted parameters for galaxy UGC06399 using lmfit:
#   M_b = 1.23e+10 solar masses
#   a   = 4.94 kpc
#   gamma = 0.04
#   chi-squared = 2.9297
# Fitting with lmfit took 0.0249 seconds
# Fitted parameters for galaxy UGC09133 using lmfit:
#   M_b = 2.80e+11 solar masses
#   a   = 4.76 kpc
#   gamma = 0.00
#   chi-squared = 6098.3631
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0268 seconds
# Fitted parameters for galaxy UGC09133 using lmfit:
#   M_b = 4.89e+10 solar masses
#   a   = 0.63 kpc
#   gamma = 0.00
#   chi-squared = 2838.2246
# Fitting with lmfit took 0.0302 seconds
# Fitted parameters for galaxy NGC0024 using lmfit:
#   M_b = 9.56e+09 solar masses
#   a   = 1.66 kpc
#   gamma = 0.00
#   chi-squared = 439.8857
# Fitting with lmfit took 0.0217 seconds
# Fitted parameters for galaxy UGC08550 using lmfit:
#   M_b = 1.13e+09 solar masses
#   a   = 1.23 kpc
#   gamma = 0.00
#   chi-squared = 46.2932
# Fitting with lmfit took 0.0170 seconds
# Fitted parameters for galaxy UGC02953 using lmfit:
#   M_b = 2.58e+11 solar masses
#   a   = 3.62 kpc
#   gamma = 0.00
#   chi-squared = 30699.0508
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0128 seconds
# Fitted parameters for galaxy UGC02953 using lmfit:
#   M_b = 2.30e+10 solar masses
#   a   = 0.38 kpc
#   gamma = 0.00
#   chi-squared = 6555.7334
# Fitting with lmfit took 0.0117 seconds
# Fitted parameters for galaxy NGC4138 using lmfit:
#   M_b = 2.72e+10 solar masses
#   a   = 0.70 kpc
#   gamma = 0.00
#   chi-squared = 115.8410
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0322 seconds
# Fitted parameters for galaxy NGC4138 using lmfit:
#   M_b = 5.78e+09 solar masses
#   a   = 0.00 kpc
#   gamma = 0.00
#   chi-squared = 0.0000
# Fitting with lmfit took 0.0210 seconds
# Fitted parameters for galaxy NGC0247 using lmfit:
#   M_b = 5.10e+10 solar masses
#   a   = 11.54 kpc
#   gamma = 0.40
#   chi-squared = 64.7078
# Fitting with lmfit took 0.0313 seconds
# Fitted parameters for galaxy IC4202 using lmfit:
#   M_b = 3.33e+11 solar masses
#   a   = 13.84 kpc
#   gamma = 0.00
#   chi-squared = 2405.2621
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0229 seconds
# Fitted parameters for galaxy IC4202 using lmfit:
#   M_b = 8.27e+09 solar masses
#   a   = 1.01 kpc
#   gamma = 0.00
#   chi-squared = 260.5124
# Fitting with lmfit took 0.0113 seconds
# Fitted parameters for galaxy UGC08286 using lmfit:
#   M_b = 5.25e+09 solar masses
#   a   = 2.84 kpc
#   gamma = 0.00
#   chi-squared = 21.7096
# Fitting with lmfit took 0.0347 seconds
# Fitted parameters for galaxy IC2574 using lmfit:
#   M_b = 6.17e+11 solar masses
#   a   = 100.00 kpc
#   gamma = 0.65
#   chi-squared = 20.5167
# Fitting with lmfit took 0.0125 seconds
# Fitted parameters for galaxy NGC4559 using lmfit:
#   M_b = 3.39e+10 solar masses
#   a   = 4.04 kpc
#   gamma = 0.43
#   chi-squared = 128.2483
# Fitting with lmfit took 0.0101 seconds
# Fitted parameters for galaxy UGC01230 using lmfit:
#   M_b = 4.62e+10 solar masses
#   a   = 16.67 kpc
#   gamma = 0.77
#   chi-squared = 28.0061
# Fitting with lmfit took 0.0132 seconds
# Fitted parameters for galaxy UGC07577 using lmfit:
#   M_b = 1.10e+09 solar masses
#   a   = 2.67 kpc
#   gamma = 0.00
#   chi-squared = 1.6110
# Fitting with lmfit took 0.0186 seconds
# Fitted parameters for galaxy UGC06628 using lmfit:
#   M_b = 5.31e+11 solar masses
#   a   = 100.00 kpc
#   gamma = 1.11
#   chi-squared = 2.4602
# Fitting with lmfit took 0.0135 seconds
# Fitted parameters for galaxy NGC4013 using lmfit:
#   M_b = 4.95e+10 solar masses
#   a   = 0.67 kpc
#   gamma = 0.00
#   chi-squared = 2211.7287
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0104 seconds
# Fitted parameters for galaxy NGC4013 using lmfit:
#   M_b = 1.27e+10 solar masses
#   a   = 0.06 kpc
#   gamma = 0.00
#   chi-squared = 0.9411
# Fitting with lmfit took 0.0236 seconds
# Fitted parameters for galaxy UGC03205 using lmfit:
#   M_b = 1.38e+11 solar masses
#   a   = 5.15 kpc
#   gamma = 0.00
#   chi-squared = 7919.6011
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0195 seconds
# Fitted parameters for galaxy UGC03205 using lmfit:
#   M_b = 1.93e+10 solar masses
#   a   = 0.55 kpc
#   gamma = 0.00
#   chi-squared = 2105.1244
# Fitting with lmfit took 0.0278 seconds
# Fitted parameters for galaxy NGC7331 using lmfit:
#   M_b = 1.65e+11 solar masses
#   a   = 1.89 kpc
#   gamma = 0.00
#   chi-squared = 1379.8931
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0577 seconds
# Fitted parameters for galaxy NGC7331 using lmfit:
#   M_b = 7.14e+09 solar masses
#   a   = 0.00 kpc
#   gamma = 0.02
#   chi-squared = 0.0009
# Fitting with lmfit took 0.0264 seconds
# Fitted parameters for galaxy UGC02916 using lmfit:
#   M_b = 2.25e+11 solar masses
#   a   = 15.28 kpc
#   gamma = 0.19
#   chi-squared = 220.2259
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0139 seconds
# Fitted parameters for galaxy UGC02916 using lmfit:
#   M_b = 2.33e+10 solar masses
#   a   = 1.03 kpc
#   gamma = 0.00
#   chi-squared = 2180.8635
# Fitting with lmfit took 0.0349 seconds
# Fitted parameters for galaxy UGC06923 using lmfit:
#   M_b = 2.24e+10 solar masses
#   a   = 15.74 kpc
#   gamma = 1.49
#   chi-squared = 0.0811
# Fitting with lmfit took 0.0286 seconds
# Fitted parameters for galaxy UGC04483 using lmfit:
#   M_b = 1.97e+08 solar masses
#   a   = 0.70 kpc
#   gamma = 0.00
#   chi-squared = 0.0815
# Fitting with lmfit took 0.0254 seconds
# Fitted parameters for galaxy NGC4217 using lmfit:
#   M_b = 5.05e+10 solar masses
#   a   = 5.37 kpc
#   gamma = 0.00
#   chi-squared = 1405.1904
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0155 seconds
# Fitted parameters for galaxy NGC4217 using lmfit:
#   M_b = 2.68e+10 solar masses
#   a   = 1.24 kpc
#   gamma = 0.00
#   chi-squared = 1877.2962
# Fitting with lmfit took 0.0248 seconds
# Fitted parameters for galaxy NGC3109 using lmfit:
#   M_b = 3.36e+09 solar masses
#   a   = 4.37 kpc
#   gamma = 0.00
#   chi-squared = 11.1600
# Fitting with lmfit took 0.0126 seconds
# Fitted parameters for galaxy UGC05764 using lmfit:
#   M_b = 3.66e+09 solar masses
#   a   = 3.73 kpc
#   gamma = 0.00
#   chi-squared = 8.1972
# Fitting with lmfit took 0.0120 seconds
# Fitted parameters for galaxy NGC3949 using lmfit:
#   M_b = 5.12e+10 solar masses
#   a   = 1.88 kpc
#   gamma = 0.00
#   chi-squared = 207.1049
# Fitting with lmfit took 0.0127 seconds
# Fitted parameters for galaxy D512-2 using lmfit:
#   M_b = 8.41e+08 solar masses
#   a   = 1.91 kpc
#   gamma = 0.00
#   chi-squared = 1.2661
# Fitting with lmfit took 0.0129 seconds
# Fitted parameters for galaxy NGC4389 using lmfit:
#   M_b = 3.69e+10 solar masses
#   a   = 4.18 kpc
#   gamma = 0.51
#   chi-squared = 32.8688
# Fitting with lmfit took 0.0306 seconds
# Fitted parameters for galaxy NGC4157 using lmfit:
#   M_b = 1.16e+11 solar masses
#   a   = 2.86 kpc
#   gamma = 0.00
#   chi-squared = 3323.9113
# Bulge component detected, performing separate fit for bulge...
# Fitting with lmfit took 0.0760 seconds
# Fitted parameters for galaxy NGC4157 using lmfit:
#   M_b = 1.31e+09 solar masses
#   a   = 0.00 kpc
#   gamma = 2.00
#   chi-squared = 0.0001
# Fitting with lmfit took 0.0172 seconds
# Fitted parameters for galaxy DDO161 using lmfit:
#   M_b = 6.68e+09 solar masses
#   a   = 3.78 kpc
#   gamma = 0.00
#   chi-squared = 37.3376
# Fitting complete. Results saved.
# Number of failed fits: 0

# %%
galaxy_mb_passed = ['NGC5371', 'NGC5005', 'NGC1003', 'NGC0100', 'UGC07261', 'NGC6195',
       'NGC4183', 'UGC08699', 'F583-4', 'NGC2841', 'NGC2403', 'NGC0300',
       'NGC4214', 'PGC51017', 'NGC2915', 'UGC08490', 'UGC05721',
       'ESO563-G021', 'ESO116-G012', 'NGC3521', 'NGC1090', 'NGC3893',
       'NGC3726', 'UGC12506', 'UGC11455', 'NGC1705', 'UGC06818',
       'UGC05253', 'UGC03546', 'NGC6503', 'UGC07690', 'UGC00634',
       'DDO154', 'UGC07603', 'NGC3992', 'NGC4088', 'ESO444-G084',
       'NGC5055', 'NGC0801', 'NGC6946', 'UGC06614', 'NGC3769', 'NGC4085',
       'NGC3198', 'NGC5033', 'UGC02885', 'NGC5907', 'NGC0289', 'UGC06973',
       'UGC02487', 'UGC09037', 'F571-8', 'D564-8', 'NGC2998', 'NGC2683',
       'NGC5585', 'NGC7814', 'UGC11914', 'NGC0891', 'UGC06787', 'D631-7',
       'NGC2955', 'UGC03580', 'NGC4100', 'UGC06786', 'NGC6674', 'NGC6015',
       'DDO168', 'NGC2903', 'UGC02455', 'UGC05986', 'UGCA281', 'UGC09133',
       'NGC0024', 'UGC08550', 'UGC02953', 'NGC4138', 'NGC4559', 'NGC4013',
       'UGC03205', 'NGC7331', 'UGC02916', 'NGC4217', 'NGC3949', 'D512-2',
       'NGC4157']

# %%
data_path = os.getcwd() + "/data/fit_data/"

dfh = pd.read_csv(data_path + "hern_fits.csv")
# dfht = pd.read_csv(data_path + "hern_fits_test.csv")
dfd = pd.read_csv(data_path + "dehnen_fits_min.csv")
# dfdt = pd.read_csv(data_path + "dehnen-fits-test.csv")

plt.figure(figsize=(6,4))
plt.scatter(dfh["M_b_fit"].values, dfh["a_fit"].values, color='C0', alpha=0.4, label='Hernquist Fit')
# plt.scatter(dfht["M_b_fit"].values, dfht["a_fit"].values, color='C3', alpha=0.4, label='Hernquist Fit (Test)')
plt.scatter(dfd["M_b_fit"].values, dfd["a_fit"].values, color='C1', alpha=0.4, label='Dehnen Fit')
# plt.scatter(dfdt["M_b_fit"].values, dfdt["a_fit"].values, color='C2', alpha=0.4, label='Dehnen Fit (Test)')
plt.xlabel('Fitted Baryonic Mass M_b [solar masses]')
plt.ylabel('Fitted Scale Radius a [kpc]')
plt.title('Comparison of Hernquist and Dehnen Fit Parameters')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.scatter(dfh["M_b_fit_bulge"].values, dfh["a_fit_bulge"].values, color='C0', alpha=0.6, label='Hernquist Fit')
plt.scatter(dfd["M_b_fit_bulge"].values, dfd["a_fit_bulge"].values, color='C1', alpha=0.6, label='Dehnen Fit')
plt.xlabel('Fitted Baryonic Mass M_b [solar masses]')
plt.ylabel('Fitted Scale Radius a [kpc]')
plt.title('Comparison of Hernquist and Dehnen Fit Parameters')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.grid()
plt.show()

# %%
# df without nan values
dfh_clean = dfh.dropna(subset=["M_b_fit", "a_fit"])
dfd_clean = dfd.dropna(subset=["M_b_fit", "a_fit"])

print("Hern length:", len(dfh_clean))
print("Dehnen length:", len(dfd_clean))
# Out:
# Hern length: 175
# Dehnen length: 144

# %%
dfh = pd.read_csv(data_path + "hern_fits.csv")
dfd = pd.read_csv(data_path + "dehnen_fits.csv")

plt.figure(figsize=(6,4))

# subh = dfh[dfh["ChiSq"] < 100]
# subd = dfd[dfd["ChiSq"] < 100]

subh = dfh[dfh["GalaxyID"].isin(galaxy_mb_passed)]
subd = dfd[dfd["GalaxyID"].isin(galaxy_mb_passed)]

subh = subh[subh["ChiSq"] < 200]
subd = subd[subd["ChiSq"] < 200]

plt.hist(subh["ChiSq"].values, bins=30, color='C0', density=False, alpha=0.7, label='Hernquist Fit')
plt.hist(subd["ChiSq"].values, bins=30, color='C1', density=False, alpha=0.4, label='Dehnen Fit')
plt.xlabel('Chi-Squared')
plt.ylabel('Number of Galaxies')
plt.title('Comparison of Chi-Squared for Hernquist and Dehnen Fits')
plt.legend()
plt.grid()
plt.show()

# %%
dfh = pd.read_csv(data_path + "hern_fits.csv")
dfd = pd.read_csv(data_path + "dehnen_fits.csv")

plt.figure(figsize=(6,4))

# subh = dfh[dfh["ChiSq"] < 100]
# subd = dfd[dfd["ChiSq"] < 100]

subh = dfh[dfh["GalaxyID"].isin(galaxy_mb_passed)]
subd = dfd[dfd["GalaxyID"].isin(galaxy_mb_passed)]

for i, gid in enumerate(galaxy_mb_passed):
    
    chi_h = subh[subh["GalaxyID"] == gid]["ChiSq"].values[0]
    chi_d = subd[subd["GalaxyID"] == gid]["ChiSq"].values[0]
    diff = chi_h - chi_d
    if i == 0:
        print(f"Galaxy {gid}: Chi-Hernquist = {chi_h:.2f}, Chi-Dehnen = {chi_d:.2f}, Difference = {diff:.2f}")
    plt.scatter(i, diff, color='k', alpha=0.7)
    
    
plt.axhline(0, color='k', linestyle='--')
plt.xlabel('Galaxy Index')
plt.ylabel('Difference in Chi-Squared (Hernquist - Dehnen)')
plt.title('Difference in Chi-Squared between Dehnen and Hernquist Fits')
plt.ylim(-100, 100)
plt.grid()
plt.show()
# Out:
# Galaxy NGC5371: Chi-Hernquist = 5220.85, Chi-Dehnen = 4703.20, Difference = 517.65

# %%
dfh = pd.read_csv(data_path + "hern_fits.csv")
dfd = pd.read_csv(data_path + "dehnen_fits_min.csv")

plt.figure(figsize=(6,4))

subh = dfh[dfh["ChiSq_bulge"] < 100]
subd = dfd[dfd["ChiSq_bulge"] < 100]

plt.hist(subh["ChiSq_bulge"].values, bins=20, color='C0', density=False, alpha=0.7, label='Hernquist Fit')
plt.hist(subd["ChiSq_bulge"].values, bins=20, color='C1', density=False, alpha=0.4, label='Dehnen Fit')
plt.xlabel('Chi-Squared')
plt.ylabel('Number of Galaxies')
plt.title('Comparison of Chi-Squared for Hernquist and Dehnen Fits')
plt.legend()
plt.grid()
plt.show()

# %%
data_path = os.getcwd() + "/data/fit_data/"

dfh = pd.read_csv(data_path + "dehnen_fits.csv")
# dfht = pd.read_csv(data_path + "hern_fits_test.csv")
dfd = pd.read_csv(data_path + "dehnen_fits_min.csv")
# dfdt = pd.read_csv(data_path + "dehnen-fits-test.csv")

plt.figure(figsize=(6,4))
plt.scatter(dfh["M_b_fit"].values, dfh["gamma_fit"].values, color='C0', alpha=0.4, label='Dehnen Fit')
plt.scatter(dfd["M_b_fit"].values, dfd["gamma_fit"].values, color='C3', alpha=0.4, label='Dehnen Fit (min)')
# plt.scatter(dfd["M_b_fit"].values, dfd["gamma_fit"].values, color='C1', alpha=0.4, label='Dehnen Fit')
# plt.scatter(dfdt["M_b_fit"].values, dfdt["a_fit"].values, color='C2', alpha=0.4, label='Dehnen Fit (Test)')
plt.xlabel('Fitted Baryonic Mass M_b [solar masses]')
plt.ylabel('Shape paramater gamma')
plt.title('Comparison of Hernquist and Dehnen Fit Parameters')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.grid()
plt.show()

# %%
dfh = pd.read_csv(data_path + "hern_fits.csv")
# dfht = pd.read_csv(data_path + "hern_fits_test.csv")
dfd = pd.read_csv(data_path + "dehnen_fits.csv")
# dfdt = pd.read_csv(data_path + "dehnen-fits-test.csv")

plt.figure(figsize=(6,4))
# plt.scatter(dfh["M_b_fit_bulge"].values, dfh["gamma_fit_bulge"].values, color='C0', alpha=0.4, label='Hernquist Fit')
plt.scatter(dfd["M_b_fit_bulge"].values, dfd["gamma_fit_bulge"].values, color='C3', alpha=0.4, label='Dehnen Fit')
# plt.scatter(dfd["M_b_fit"].values, dfd["gamma_fit"].values, color='C1', alpha=0.4, label='Dehnen Fit')
# plt.scatter(dfdt["M_b_fit"].values, dfdt["a_fit"].values, color='C2', alpha=0.4, label='Dehnen Fit (Test)')
plt.xlabel('Fitted Baryonic Mass M_b [solar masses]')
plt.ylabel('Shape paramater gamma')
plt.title('Comparison of Hernquist and Dehnen Fit Parameters')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.grid()
plt.show()

# %%
np.log10(2)
# Out:
# np.float64(0.3010299956639812)

# %%
# dfh['gamma_fit'].hist(bins=10, color='C0', alpha=0.7)
dfd['gamma_fit'].hist(bins=10, color='C1', alpha=0.7)
# Out:
# <Axes: >

# %%
plt.scatter(range(len(dfd)), dfd['gamma_fit'].values, color='C0', alpha=0.7)

# %% [markdown]
# # Comparison Fits Hern and Dehnen

# %%
G = 4.30091e-6  # [kpc * (km/s)^2 / solar mass]

# Hernquist model for circular velocity for fitting
def hernquist_model(r, log_M_b=10, log_a=1):
    """
    Circular velocity squared for Hernquist profile.
    Takes:
        r : radius [kpc] (or array of radii)
        log_M_b : log10 of total baryonic mass [solar masses]
        log_a : log10 of scale radius [kpc]
    Returns:
        Vc : circular velocity at radius r [km/s]
    """
    Mb = 10**log_M_b  # convert log10(M_b) to M_b in solar masses
    a = 10**log_a  # convert log10(a) to a in kpc
    vc = np.sqrt(G * Mb * r) / (r + a)
    return vc

# Dehnen model for circular velocity for fitting
def dehnen_model(r, log_M_b=10, log_a=1, gamma=1):
    """
    Circular velocity squared for Dehnen profile.
    Takes:
        r : radius [kpc] (or array of radii)
        log_M_b : log10 of total baryonic mass [solar masses]
        log_a : log10 of scale radius [kpc]
        gamma : inner slope parameter
    Returns:
        Vc : circular velocity at radius r [km/s]
    """
    Mb = 10**log_M_b  # convert log10(M_b) to M_b in solar masses
    a = 10**log_a  # convert log10(a) to a in kpc
    vcsq = G * Mb * ((r ** (2 - gamma)) / (r + a) ** (3 - gamma))
    return np.sqrt(vcsq)

# %%
def vc_disk_gas(data, gamma_star=0.5):
    """
    Total baryonic circular velocity.
    Takes:
        data : dataframe with columns 'Vdisk', 'Vbul', 'Vgas'
        gamma_star : mass-to-light ratio scaling factor for disk
    Returns:
        vc_baryons : total baryonic circular velocity [km/s]
        radii : radius [kpc]
    """
    radii = data["Rad"].values
    vc_disk_sq = gamma_star * data["Vdisk"] ** 2
    vc_gas_sq = data["Vgas"] ** 2

    vc_baryons = np.sqrt(vc_disk_sq + vc_gas_sq)

    return radii, vc_baryons

def vc_bulge(data, gamma_bulge=0.7):
    """
    Bulge circular velocity.
    Takes:
        data : dataframe with columns 'Vbul'
        gamma_bulge : mass-to-light ratio scaling factor for bulge
    Returns:
        vc_bulge : bulge circular velocity [km/s]
        radii : radius [kpc]
    """
    radii = data["Rad"].values
    vc_bulge = np.sqrt(gamma_bulge * data["Vbul"] ** 2)

    return radii, vc_bulge

# %%
data_path = os.getcwd() + "/../data/fit_data/"
dfh = pd.read_csv(data_path + "hern_fits.csv")
dfd = pd.read_csv(data_path + "dehnen_fits.csv")
# print("Hernquist fit data length:", len(dfh))
# print("Dehnen fit data length:", len(dfd))
# # drop nans
# dfh = dfh.dropna(subset=["M_b_fit", "a_fit"])
# dfd = dfd.dropna(subset=["M_b_fit", "a_fit"])
# print("Hernquist fit data length after dropping NaNs:", len(dfh))
# print("Dehnen fit data length after dropping NaNs:", len(dfd))
# # no bulge 
# dfh = dfh[~dfh["GalaxyID"].isin(gid_bulge)]
# dfd = dfd[~dfd["GalaxyID"].isin(gid_bulge)]
# print("Hernquist fit data length without bulge galaxies:", len(dfh))
# print("Dehnen fit data length without bulge galaxies:", len(dfd))

print("Hernquist fit data length:", len(dfh))
print("Dehnen fit data length:", len(dfd))
# Out:
# Hernquist fit data length: 175
# Dehnen fit data length: 175

# %%
# galaxy IDs in both fits
galaxy_ids_fit = set(dfh["GalaxyID"].values) & set(dfd["GalaxyID"].values)
print("Number of unique galaxies in fits:", len(galaxy_ids_fit))
# Out:
# Number of unique galaxies in fits: 175

# %%
galaxy_ids_fit = list(galaxy_ids_fit)

# %%
galaxy_id_fit = ['NGC5371', 'NGC5005', 'NGC1003', 'NGC0100', 'UGC07261', 'NGC6195',
       'NGC4183', 'UGC08699', 'F583-4', 'NGC2841', 'NGC2403', 'NGC0300',
       'NGC4214', 'PGC51017', 'NGC2915', 'UGC08490', 'UGC05721',
       'ESO563-G021', 'ESO116-G012', 'NGC3521', 'NGC1090', 'NGC3893',
       'NGC3726', 'UGC12506', 'UGC11455', 'NGC1705', 'UGC06818',
       'UGC05253', 'UGC03546', 'NGC6503', 'UGC07690', 'UGC00634',
       'DDO154', 'UGC07603', 'NGC3992', 'NGC4088', 'ESO444-G084',
       'NGC5055', 'NGC0801', 'NGC6946', 'UGC06614', 'NGC3769', 'NGC4085',
       'NGC3198', 'NGC5033', 'UGC02885', 'NGC5907', 'NGC0289', 'UGC06973',
       'UGC02487', 'UGC09037', 'F571-8', 'D564-8', 'NGC2998', 'NGC2683',
       'NGC5585', 'NGC7814', 'UGC11914', 'NGC0891', 'UGC06787', 'D631-7',
       'NGC2955', 'UGC03580', 'NGC4100', 'UGC06786', 'NGC6674', 'NGC6015',
       'DDO168', 'NGC2903', 'UGC02455', 'UGC05986', 'UGCA281', 'UGC09133',
       'NGC0024', 'UGC08550', 'UGC02953', 'NGC4138', 'NGC4559', 'NGC4013',
       'UGC03205', 'NGC7331', 'UGC02916', 'NGC4217', 'NGC3949', 'D512-2',
       'NGC4157']

type(galaxy_id_fit)
# Out:
# list

# %%
gravo_list = ["DDO154", "ESO444-G084", "F568-V1", "F574-1", "NGC0300", "NGC3109", "UGC00128", "UGC06446", "UGC06667", "UGC08286", "NGC4376", "NGC4396", "NGC7320", "UGC04169"]

gamma_data = pd.read_csv(data_path + "gamma_fits.csv")

# %%
plot_path = os.getcwd() + "/../plots/fits/gravo/"

for galaxy_id in gravo_list:
    print(f"Plotting galaxy {galaxy_id}...")
    try:
        gamma_s = gamma_data[gamma_data["GalaxyID"] == galaxy_id]["Gamma_disk"].values[0]
        gamma_d = gamma_data[gamma_data["GalaxyID"] == galaxy_id]["Gamma_bulge"].values[0]
        data, _, _ = get_rc_data(galaxy_id)
        r_vals, vc_baryons = vc_disk_gas(data, gamma_star=gamma_s)
        
        bulge = False
        if np.sum(data["Vbul"].values) > 0:
            _, vc_bul = vc_bulge(data, gamma_bulge=gamma_d)
            bulge = True
        
        subh = dfh[dfh["GalaxyID"] == galaxy_id]
        subd = dfd[dfd["GalaxyID"] == galaxy_id]
        
        log_M_b_h = np.log10(subh["M_b_fit"].values[0])
        log_a_h = np.log10(subh["a_fit"].values[0])
        
        log_M_b_d = np.log10(subd["M_b_fit"].values[0])
        log_a_d = np.log10(subd["a_fit"].values[0])
        gamma_d = subd["gamma_fit"].values[0]
        
        ri = np.geomspace(0.1, r_vals.max() * 2, 100)
        vc_h = hernquist_model(ri, log_M_b=log_M_b_h, log_a=log_a_h)
        vc_d = dehnen_model(ri, log_M_b=log_M_b_d, log_a=log_a_d, gamma=gamma_d)
        
        if bulge:
            log_M_b_h_b = np.log10(subh["M_b_fit_bulge"].values[0])
            log_a_h_b = np.log10(subh["a_fit_bulge"].values[0])
            log_M_b_d_b = np.log10(subd["M_b_fit_bulge"].values[0])
            log_a_d_b = np.log10(subd["a_fit_bulge"].values[0])
            gamma_d_b = subd["gamma_fit_bulge"].values[0]
            vc_d_b = dehnen_model(ri, log_M_b=log_M_b_d_b, log_a=log_a_d_b, gamma=gamma_d_b)
            vc_h_b = hernquist_model(ri, log_M_b=log_M_b_h_b, log_a=log_a_h_b)

        ymax = max(vc_baryons.max(), vc_h.max(), vc_d.max()) * 1.2
        
        plt.figure(figsize=(6,4))
        plt.scatter(r_vals, vc_baryons, label='Baryonic Data', color='k', s=10)
        plt.plot(ri, vc_h, label='Hernquist Disk + Gas', color='C0', alpha=0.7)
        plt.plot(ri, vc_d, label='Dehnen Disk + Gas', color='C1', alpha=0.7)
        if bulge:
            plt.scatter(r_vals, vc_bul, label='Bulge Data', color='grey', s=10)
            plt.plot(ri, vc_h_b, label='Hernquist Bulge', color='C0', linestyle='--', alpha=0.7)
            plt.plot(ri, vc_d_b, label='Dehnen Bulge', color='C1', linestyle='--', alpha=0.7)
        plt.xlabel('Radius (kpc)')
        plt.ylabel('Circular Velocity (km/s)')
        plt.title(f'Galaxy {galaxy_id} - Hernquist vs Dehnen Fit')
        plt.legend(fontsize=6)
        plt.ylim(0, ymax)
        plt.grid()
        plt.savefig(plot_path + f"{galaxy_id}_rc_fits.png")
        plt.close()
        # plt.show()
    except Exception as e:
        print(f"Error plotting galaxy {galaxy_id}: {e}")
        continue
# Out:
# Plotting galaxy DDO154...
# Plotting galaxy ESO444-G084...
# Plotting galaxy F568-V1...
# Plotting galaxy F574-1...
# Plotting galaxy NGC0300...
# Plotting galaxy NGC3109...
# Plotting galaxy UGC00128...
# Plotting galaxy UGC06446...
# Plotting galaxy UGC06667...
# Plotting galaxy UGC08286...
# Plotting galaxy NGC4376...
# Error plotting galaxy NGC4376: index 0 is out of bounds for axis 0 with size 0
# Plotting galaxy NGC4396...
# Error plotting galaxy NGC4396: index 0 is out of bounds for axis 0 with size 0
# Plotting galaxy NGC7320...
# Error plotting galaxy NGC7320: index 0 is out of bounds for axis 0 with size 0
# Plotting galaxy UGC04169...
# Error plotting galaxy UGC04169: index 0 is out of bounds for axis 0 with size 0

# %%
def phi_hern(M_b, a):
    G = 4.30091e-6  # [kpc * (km/s)^2/ solar mass]

    def phi_func(r, th):
        return -G * M_b / (r + a)

    return phi_func

def phi_dehen(M_b, a, gamma):
    G = 4.30091e-6  # [kpc * (km/s)^2/ solar mass]

    def phi_func(r, th):
        prefactor = - (G * M_b) / (a * (2 - gamma))
        return prefactor * ( 1 - (( r / (r+a) )**(2-gamma)) )

    return phi_func

# %%
for galaxy_id in gravo_list:
    gamma_s = gamma_data[gamma_data["GalaxyID"] == galaxy_id]["Gamma_disk"].values[0]
    data, _, _ = get_rc_data(galaxy_id)
    r_vals, vc_baryons = vc_disk_gas(data, gamma_star=gamma_s)
    
    subh = dfh[dfh["GalaxyID"] == galaxy_id]
    subd = dfd[dfd["GalaxyID"] == galaxy_id]
    
    M_b_h = subh["M_b_fit"].values[0]
    a_h = subh["a_fit"].values[0]
    
    M_b_d = subd["M_b_fit"].values[0]
    a_d = subd["a_fit"].values[0]
    gamma_d = subd["gamma_fit"].values[0]
    
    phi_H = phi_hern(M_b_h, a_h)
    phi_D = phi_dehen(M_b_d, a_d, gamma_d)

    ri = np.geomspace(0.1, 100, 100)

    phi_H_vals = np.abs(np.array([phi_H(r, 0) for r in ri]))
    phi_D_vals = np.abs(np.array([phi_D(r, 0) for r in ri]))
    percent_diff = 100 * ( np.abs((phi_H_vals - phi_D_vals)) / np.abs(phi_H_vals) )

    # plt.figure(figsize=(6,4))
    fig, axs = plt.subplots(2, 1, figsize=(6, 4), sharex=True, gridspec_kw={'height_ratios': [3, 1]})

    axs[0].plot(ri, phi_H_vals, label='Hernquist Potential', color='C0')
    axs[0].plot(ri, phi_D_vals, label='Dehnen Potential', color='C1')
    axs[0].set_ylabel('Potential (km^2/s^2)')
    axs[0].set_title(f'Gravitational Potential for Galaxy {galaxy_id}')
    axs[0].grid()
    axs[0].legend()
    axs[1].plot(ri, percent_diff, label='Percent Difference', color='C3')
    axs[1].set_xlabel('Radius (kpc)')
    axs[1].set_ylabel('Percent Difference (%)')
    plt.grid()
    axs[0].set_xscale('log')
    axs[0].set_yscale('log')
    axs[1].set_xscale('log')
    axs[1].set_ylim(0, 100)
    plt.tight_layout()
    plt.savefig(plot_path + f"{galaxy_id}_potential_fits.png")
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 for galaxy_id in gravo_list:
# ----> 2     gamma_s = gamma_data[gamma_data["GalaxyID"] == galaxy_id]["Gamma_disk"].values[0]
#       3     data, _, _ = get_rc_data(galaxy_id)
#       4     r_vals, vc_baryons = vc_disk_gas(data, gamma_star=gamma_s)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# # BIC Between Hern and Dehnen

# %%
data_path = os.getcwd() + "/data/fit_data/"

dfh = pd.read_csv(data_path + "hern_fits.csv")
dfd = pd.read_csv(data_path + "dehnen_fits.csv")

# BIC criterion 
def BIC(galaxy_id):
    df, _, _ = get_rc_data(galaxy_id)
    N = len(df)
    chi2_h = dfh[dfh["GalaxyID"] == galaxy_id]["ChiSq"].values[0]
    chi2_d = dfd[dfd["GalaxyID"] == galaxy_id]["ChiSq"].values[0]
    k_h = 2  # M_b, a
    k_d = 3  # M_b, a, gamma
    
    bic_h = chi2_h + k_h * np.log(N)
    bic_d = chi2_d + k_d * np.log(N)
    return bic_h, bic_d

bic_results = []
for galaxy_id in galaxy_ids:
    bic_h, bic_d = BIC(galaxy_id)
    delta_bic = bic_h - bic_d # positive means Dehnen is better, negative means Hernquist is better
    bic_results.append((galaxy_id, bic_h, bic_d, delta_bic))
    
bic_df = pd.DataFrame(bic_results, columns=["GalaxyID", "BIC_Hernquist", "BIC_Dehnen", "Delta_BIC"])
bic_df.to_csv(os.path.join(data_path, "bic_comparison.csv"), index=False)

# %%
plt.figure(figsize=(6,4))
plt.scatter(range(len(bic_df)), bic_df["Delta_BIC"], color='C0', alpha=0.6)
plt.axhline(0, color='k', linestyle='--')
plt.axhline(2, color='C1', linestyle='--', label='Negligible')
plt.axhline(6, color='C2', linestyle='--', label='Positive')
plt.axhline(10, color='C3', linestyle='--', label='Strong')
plt.xlabel('Galaxy Index')
plt.ylabel('Delta BIC (Dehnen - Hernquist)')
plt.title('BIC Comparison of Dehnen and Hernquist Fits')
plt.yscale('symlog', linthresh=2)
# plt.yscale('log')
plt.legend()
plt.grid()
plt.show()

# %%
len(bic_df[bic_df["Delta_BIC"] < 0])
# Out:
# 18

# %%
# print galaxy IDs where Hernquist is preferred (Delta_BIC < 0)
hern_preferred = bic_df[bic_df["Delta_BIC"] < 0]["GalaxyID"].values
print("Galaxies where Hernquist fit is preferred:", hern_preferred)
# Out:
# Galaxies where Hernquist fit is preferred: ['UGC07559' 'F574-1' 'UGC07866' 'UGC06930' 'F561-1' 'UGC06818' 'UGC07690'
#  'F563-1' 'UGC09992' 'UGC04499' 'UGC06973' 'D564-8' 'UGC12632' 'NGC5585'
#  'F568-V1' 'ESO079-G014' 'UGC00128' 'UGC06628']

# %% [markdown]
# UGC07559: cut by length
# UGC07866: cut by length
# UGC06930: 9 points bad shape, probabaly cut
# UGC06818: cut by length
# UGC07690: cut by length
# UGC09992: cut by length
# UGC04499: 9 points no turndown
# UGC06973: Hernquist actually appears better for Disk+Gas and Bulge...
# UGC12632: Only linearly rising
# UGC00128: Bad shape, poor fit
# UGC06628: cut by legnth
# F574-1: rising
# F561-1: cut by length
# F563-1: rising
# F568-V1: cut by length
# D564-8: Dehen looks better but this will be cut anyhow.
# NGC5585: Very slightly better...
# ESO079-G014: only rising
