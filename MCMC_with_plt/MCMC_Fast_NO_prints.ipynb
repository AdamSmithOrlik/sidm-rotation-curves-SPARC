# %%
import importlib
import MCMC_Final_NO_prints 

importlib.reload(MCMC_Final_NO_prints)
# Out:
# <module 'MCMC_Final_NO_prints' from '/home/asorlik/Desktop/darkmatter/explore/sidm-rotation-curves-SPARC/MCMC_with_plt/MCMC_Final_NO_prints.py'>

# %%
files = ['DDO170']

for f in files:
    MCMC_Final_NO_prints.MCMC(f, nsteps=10)
# Out:
# Data for DDO170 could be loaded.
# 100%|██████████| 10/10 [01:30<00:00,  9.00s/it]
