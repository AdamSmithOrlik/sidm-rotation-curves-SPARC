# %%
import importlib
import Jeans_PLOT_of_MCMC_paras

importlib.reload(Jeans_PLOT_of_MCMC_paras)
# Out:
# <module 'Jeans_PLOT_of_MCMC_paras' from '/home/Altan/Explore/sidm-rotation-curves-SPARC-main/MCMCFinal/Jeans_PLOT_of_MCMC_paras.py'>

# %%
jeans_plt = Jeans_PLOT_of_MCMC_paras.Jeans_MCMC_plot

# %%
jeans_plt('DDO170')
# Out:
# DDO170 Fit-Results
# r1:   11.455 kpc
# M200: 2.54e+10 M_sun
# c:    12.823
