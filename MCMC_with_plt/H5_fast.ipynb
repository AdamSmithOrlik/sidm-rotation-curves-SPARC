# %%
import importlib
import CornerPlots_H5

importlib.reload(CornerPlots_H5)
# Out:
# <module 'CornerPlots_H5' from '/home/asorlik/Desktop/darkmatter/explore/sidm-rotation-curves-SPARC/MCMC_with_plt/CornerPlots_H5.py'>

# %%
cplot = CornerPlots_H5.corner_plot

# %%
CornerPlots_H5.corner_plot('DDO170')
# Out:
# Number of Iterations: 10
# Shape of chain: (10, 8, 3)
# Generating corner plot for 3 parameters...

# %%
cplot('DDO170')
# Out:
# Number of Iterations: 10
# Shape of chain: (10, 8, 3)
# Generating corner plot for 3 parameters...
